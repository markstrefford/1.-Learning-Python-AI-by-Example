# %% [markdown]
# # LDA with Gensim

# %% [markdown]
# * Start by importing python libraries that we'll be using

# %%
# %load_ext autoreload
# %autoreload 2

import sqlite3
import string
import logging

from gensim import corpora, utils, models, similarities
from collections import defaultdict

import nltk
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# * Let's set up some basic config

# %%
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

punctuation = set(string.punctuation)
stoplist = set(stopwords.words('english'))

frequency = defaultdict(int)

stemmer = SnowballStemmer("english")
lemma = WordNetLemmatizer()

dictionary = corpora.Dictionary()

# %% [markdown]
# ### Create a class for our content

# %% [markdown]
# This class will use the database that we created when we downloaded content from Wikipedia

# %%
class ContentStore:
    def __init__(self, db_file):
        """
        Intialise the crawl_wikipedia class, set up a
        lightweight database for storing content for later use
        :param db_file:
        """
        self.categories = []
        # Connect to the DB db
        self.conn = sqlite3.connect(db_file)
        self.cursor = self.conn.cursor()

    def get_page_urls(self):
        """
        Retrieve a list of urls from the database
        :return: list of urls
        """
        return [row for row in self.cursor.execute("SELECT url FROM content")]
    
    def get_page_ids(self):
        """
        Retrieve a list of page ids from the database
        :return: list of page id tuples
        """
        return [row for row in self.cursor.execute("SELECT pageid FROM content")]   
    
    def get_page_by_id(self, pageid):
        """
        Retrieve the page with the specified pageid
        Note that this is of the format (pageid, ) for SQLite3 to work, for example
        to get the page with the id of 1 in our database, set pageid to ('1', )
        :return: string
        """
        return str(self.cursor.execute("SELECT content FROM content WHERE pageid=?", pageid).fetchone()).lower()
    
    def get_page_url_by_id(self, pageid):
        """
        Retrieve the page with the specified pageid
        Note that this is of the format (pageid, ) for SQLite3 to work, for example
        to get the page with the id of 1 in our database, set pageid to ('1', )
        :return: string
        """
        return str(self.cursor.execute("SELECT url FROM content WHERE pageid=?", pageid).fetchone())
    
    def get_cleaned_text(self, text):
        """
        Return the page with stopwords, digits, punctuation and single character words removed
        :return: string
        """
        # Remove numbers
        text = ''.join(char for char in text if not char.isdigit())
        # Remove stop words
        text = ' '.join([word for word in text.split() if word not in stoplist])
        # Remove punctuation
        text = ''.join(char for char in text if char not in punctuation)
        # Remove single character words
        text = ' '.join([word for word in text.split() if len(word) > 1])
        return text
        
    def __iter__(self):
        for pageid in self.get_page_ids():
            page = self.get_page_by_id(pageid)
            yield self.get_cleaned_text(page).split()
        
#     def __iter__(self):
#         self.pageids = self.get_page_ids()
#         self.idx = 0
#         return self
    
#     def __next__(self):
#         if self.idx <= len(self.pageids):
#             pageid = self.pageids(self.idx)
#             page = dictionary.doc2bow(self.get_cleaned_page_by_id(pageid))
#             self.idx += 1
#             return page
#         else:
#             raise StopIteration

# %% [markdown]
# ### Remove punctuation from text

# %%
def remove_punctuation(text):
    """
    Remove punctuation from text by checking each character against a set of punctation characters
    :return: string
    """
    return ''.join(char for char in text if char not in punctuation)

# %% [markdown]
# ### Remove numbers from text

# %%
def remove_numbers(text):
    """
    Remove numbers from text as they aren't of value to our model
    :return: string
    """
    return ''.join(char for char in text if not char.isdigit())

# %% [markdown]
# ### Remove stop words from text

# %%
def remove_stop_words(text):
    """
    Remove common words as they won't add any value to our model
    :return: string
    """
    return ' '.join([word for word in text.split() if word not in stoplist])

# %% [markdown]
# ### Remove single character words

# %%
def remove_single_characters(text):
    """
    Remove any remaining single-character words
    :return: string
    """
    return ' '.join([word for word in text.split() if len(word) > 1])

# %% [markdown]
# ### Lemmatize our document

# %%
def lemmatize(text):
    return text

# %% [markdown]
# ### Stemmatize our document

# %%
def stemmatize(text):
    return text

# %% [markdown]
# ### Exploring and cleaning our content
#
# * Access our database of Wikipedia content and get a list of all of the pages IDs

# %%
content = ContentStore('../content.db')
page_ids = content.get_page_ids()

# %% [markdown]
# * Let's view a page from our database

# %%
page = content.get_page_by_id(page_ids[0])
print(page)
# Out:
# ('    \'\'\'artificial intelligence\'\'\' (\'\'\'ai\'\'\'), sometimes called \'\'\'machine intelligence\'\'\', is s, such as "learning" and "problem solving". the scope of ai is disputed: as machines become increasingly capable, tasks considered as requiring "intelligence" are often removed from the definition, a phenomenon known as the .\n\n\nartificial intelligence was founded as an academic discipline in 1956, and in the years since has experienced several waves of optimism, followed by disappointment and the loss of funding (known as an " s), or deep philosophical differences. subfields have also been based on social factors (particular institutions or the work of particular researchers).\n\nthe traditional problems (or goals) of ai research include and many others.\n\n\nthe field was founded on the claim that .\n\nin the twenty-first century, ai techniques have experienced a resurgence following concurrent advances in , helping to solve many challenging problems in computer science. == history ==  thought-capable .\n\nthe study of mechanical or "artificial neurons". the field of ai research was born at agreed, writing, "within a generation\xa0... the problem of creating \'artificial intelligence\' will substantially be solved".\n\nthey failed to recognize the difficulty of some of the remaining tasks. progress slowed and in 1974, in response to the criticism of ", a period when obtaining funding for ai projects was difficult.\n\n\nin the early 1980s, ai research was revived by the commercial success of market in 1987, ai once again fell into disrepute, and a second, longer-lasting hiatus began.\n\nin the late 1990s and early 21st century, ai began to be used for logistics, on 11 may 1997. in 2011, a \'\' , this marked the completion of a significant milestone in the development of artificial intelligence as go is an extremely complex game, more so than chess.\n\naccording to jack clark, 2015 was a landmark year for artificial intelligence, with the number of software projects that use ai within google increased from a "sporadic usage" in 2012 to more than 2,700 projects. clark also presents factual data indicating that error rates in image processing tasks have fallen significantly since 2011.{{cite web\n |url         = https://www.bloomberg.com/news/articles/2015-12-08/why-2015-was-a-breakthrough-year-in-artificial-intelligence\n |title       = why 2015 was a breakthrough year in artificial intelligence\n |last        = clark\n |first       = jack\n |website     = bloomberg news\n |date        = 8 december 2015\n |access-date = 23 november 2016\n |quote       = after a half-decade of quiet breakthroughs in artificial intelligence, 2015 has been a landmark year. computers are smarter and learning faster than ever.\n |deadurl     = no\n |archiveurl  = https://web.archive.org/web/20161123053855/https://www.bloomberg.com/news/articles/2015-12-08/why-2015-was-a-breakthrough-year-in-artificial-intelligence\n |archivedate = 23 november 2016\n |df          = dmy-all\n}} he attributes this to an increase in affordable , due to a rise in cloud computing infrastructure and to an increase in research tools and datasets. other cited examples include microsoft\'s development of a skype system that can automatically translate from one language to another and facebook\'s system that can describe images to blind people. in a 2017 survey, one in five companies reported they had "incorporated ai in some offerings or processes". == basics ==\n\n\na typical ai perceives its environment and takes actions that maximize its chance of successfully achieving its goals. an ai\'s intended to possess desired traits. such systems can still be benchmarked if the non-goal system is framed as a system whose "goal" is to successfully accomplish its narrow classification task.lindenbaum, m., markovitch, s., & rusakov, d. (2004). selective sampling for nearest neighbor classifiers. machine learning, 54(2), 125–152.\n\nai often revolves around the use of :  ...

# %% [markdown]
# * Now let's remove punctuation

# %%
page = remove_punctuation(page)
print(page)
# Out:
#     artificial intelligence ai sometimes called machine intelligence is s such as learning and problem solving the scope of ai is disputed as machines become increasingly capable tasks considered as requiring intelligence are often removed from the definition a phenomenon known as the nnnartificial intelligence was founded as an academic discipline in 1956 and in the years since has experienced several waves of optimism followed by disappointment and the loss of funding known as an  s or deep philosophical differences subfields have also been based on social factors particular institutions or the work of particular researchersnnthe traditional problems or goals of ai research include and many othersnnnthe field was founded on the claim that nnin the twentyfirst century ai techniques have experienced a resurgence following concurrent advances in  helping to solve many challenging problems in computer science  history   thoughtcapable nnthe study of mechanical or artificial neurons the field of ai research was born at agreed writing within a generationxa0 the problem of creating artificial intelligence will substantially be solvednnthey failed to recognize the difficulty of some of the remaining tasks progress slowed and in 1974 in response to the criticism of  a period when obtaining funding for ai projects was difficultnnnin the early 1980s ai research was revived by the commercial success of market in 1987 ai once again fell into disrepute and a second longerlasting hiatus begannnin the late 1990s and early 21st century ai began to be used for logistics on 11 may 1997 in 2011 a   this marked the completion of a significant milestone in the development of artificial intelligence as go is an extremely complex game more so than chessnnaccording to jack clark 2015 was a landmark year for artificial intelligence with the number of software projects that use ai within google increased from a sporadic usage in 2012 to more than 2700 projects clark also presents factual data indicating that error rates in image processing tasks have fallen significantly since 2011cite webn url          httpswwwbloombergcomnewsarticles20151208why2015wasabreakthroughyearinartificialintelligencen title        why 2015 was a breakthrough year in artificial intelligencen last         clarkn first        jackn website      bloomberg newsn date         8 december 2015n accessdate  23 november 2016n quote        after a halfdecade of quiet breakthroughs in artificial intelligence 2015 has been a landmark year computers are smarter and learning faster than evern deadurl      non archiveurl   httpswebarchiveorgweb20161123053855httpswwwbloombergcomnewsarticles20151208why2015wasabreakthroughyearinartificialintelligencen archivedate  23 november 2016n df           dmyalln he attributes this to an increase in affordable  due to a rise in cloud computing infrastructure and to an increase in research tools and datasets other cited examples include microsofts development of a skype system that can automatically translate from one language to another and facebooks system that can describe images to blind people in a 2017 survey one in five companies reported they had incorporated ai in some offerings or processes  basics nnna typical ai perceives its environment and takes actions that maximize its chance of successfully achieving its goals an ais intended to possess desired traits such systems can still be benchmarked if the nongoal system is framed as a system whose goal is to successfully accomplish its narrow classification tasklindenbaum m markovitch s  rusakov d 2004 selective sampling for nearest neighbor classifiers machine learning 542 125–152nnai often revolves around the use of   if someone has a threat that is two in a row take the remaining square otherwisen if a move forks to create two threats at once play that move otherwisen take the center square if it is free otherwisen if your opponent has played in a corner take the opposite corner otherwisen take  ...

# %% [markdown]
# * Remove numbers

# %%
page = remove_numbers(page)
print(page)
# Out:
#     artificial intelligence ai sometimes called machine intelligence is s such as learning and problem solving the scope of ai is disputed as machines become increasingly capable tasks considered as requiring intelligence are often removed from the definition a phenomenon known as the nnnartificial intelligence was founded as an academic discipline in  and in the years since has experienced several waves of optimism followed by disappointment and the loss of funding known as an  s or deep philosophical differences subfields have also been based on social factors particular institutions or the work of particular researchersnnthe traditional problems or goals of ai research include and many othersnnnthe field was founded on the claim that nnin the twentyfirst century ai techniques have experienced a resurgence following concurrent advances in  helping to solve many challenging problems in computer science  history   thoughtcapable nnthe study of mechanical or artificial neurons the field of ai research was born at agreed writing within a generationxa the problem of creating artificial intelligence will substantially be solvednnthey failed to recognize the difficulty of some of the remaining tasks progress slowed and in  in response to the criticism of  a period when obtaining funding for ai projects was difficultnnnin the early s ai research was revived by the commercial success of market in  ai once again fell into disrepute and a second longerlasting hiatus begannnin the late s and early st century ai began to be used for logistics on  may  in  a   this marked the completion of a significant milestone in the development of artificial intelligence as go is an extremely complex game more so than chessnnaccording to jack clark  was a landmark year for artificial intelligence with the number of software projects that use ai within google increased from a sporadic usage in  to more than  projects clark also presents factual data indicating that error rates in image processing tasks have fallen significantly since cite webn url          httpswwwbloombergcomnewsarticleswhywasabreakthroughyearinartificialintelligencen title        why  was a breakthrough year in artificial intelligencen last         clarkn first        jackn website      bloomberg newsn date          december n accessdate   november n quote        after a halfdecade of quiet breakthroughs in artificial intelligence  has been a landmark year computers are smarter and learning faster than evern deadurl      non archiveurl   httpswebarchiveorgwebhttpswwwbloombergcomnewsarticleswhywasabreakthroughyearinartificialintelligencen archivedate   november n df           dmyalln he attributes this to an increase in affordable  due to a rise in cloud computing infrastructure and to an increase in research tools and datasets other cited examples include microsofts development of a skype system that can automatically translate from one language to another and facebooks system that can describe images to blind people in a  survey one in five companies reported they had incorporated ai in some offerings or processes  basics nnna typical ai perceives its environment and takes actions that maximize its chance of successfully achieving its goals an ais intended to possess desired traits such systems can still be benchmarked if the nongoal system is framed as a system whose goal is to successfully accomplish its narrow classification tasklindenbaum m markovitch s  rusakov d  selective sampling for nearest neighbor classifiers machine learning  –nnai often revolves around the use of   if someone has a threat that is two in a row take the remaining square otherwisen if a move forks to create two threats at once play that move otherwisen take the center square if it is free otherwisen if your opponent has played in a corner take the opposite corner otherwisen take an empty corner if one exists otherwisen take any empty squarennmany ai algorithms are capable of learning from data they can enh ...

# %% [markdown]
# * And stop words

# %%
page = remove_stop_words(page)
print(page)
# Out:
# artificial intelligence ai sometimes called machine intelligence learning problem solving scope ai disputed machines become increasingly capable tasks considered requiring intelligence often removed definition phenomenon known nnnartificial intelligence founded academic discipline years since experienced several waves optimism followed disappointment loss funding known deep philosophical differences subfields also based social factors particular institutions work particular researchersnnthe traditional problems goals ai research include many othersnnnthe field founded claim nnin twentyfirst century ai techniques experienced resurgence following concurrent advances helping solve many challenging problems computer science history thoughtcapable nnthe study mechanical artificial neurons field ai research born agreed writing within generationxa problem creating artificial intelligence substantially solvednnthey failed recognize difficulty remaining tasks progress slowed response criticism period obtaining funding ai projects difficultnnnin early ai research revived commercial success market ai fell disrepute second longerlasting hiatus begannnin late early st century ai began used logistics may marked completion significant milestone development artificial intelligence go extremely complex game chessnnaccording jack clark landmark year artificial intelligence number software projects use ai within google increased sporadic usage projects clark also presents factual data indicating error rates image processing tasks fallen significantly since cite webn url httpswwwbloombergcomnewsarticleswhywasabreakthroughyearinartificialintelligencen title breakthrough year artificial intelligencen last clarkn first jackn website bloomberg newsn date december n accessdate november n quote halfdecade quiet breakthroughs artificial intelligence landmark year computers smarter learning faster evern deadurl non archiveurl httpswebarchiveorgwebhttpswwwbloombergcomnewsarticleswhywasabreakthroughyearinartificialintelligencen archivedate november n df dmyalln attributes increase affordable due rise cloud computing infrastructure increase research tools datasets cited examples include microsofts development skype system automatically translate one language another facebooks system describe images blind people survey one five companies reported incorporated ai offerings processes basics nnna typical ai perceives environment takes actions maximize chance successfully achieving goals ais intended possess desired traits systems still benchmarked nongoal system framed system whose goal successfully accomplish narrow classification tasklindenbaum markovitch rusakov selective sampling nearest neighbor classifiers machine learning –nnai often revolves around use someone threat two row take remaining square otherwisen move forks create two threats play move otherwisen take center square free otherwisen opponent played corner take opposite corner otherwisen take empty corner one exists otherwisen take empty squarennmany ai algorithms capable learning data enhance learning new avoid combinatorial explosion would ensue every possible route ponderously considered turncite journaln first p en last hartn author nilsson n jauthor raphael bn title correction formal basis heuristic determination minimum cost pathsn journal newslettern issue n pages –n year n doin nnthe earliest easiest understand approach ai symbolism formal logic otherwise healthy adult fever may learn comparing desired output altering strengths connections internal neurons reinforce connections seemed useful four main approaches overlap evolutionary systems example neural nets learn make inferences generalize make analogies systems implicitly explicitly use multiple approaches alongside many ai nonai algorithms learning algorithms work basis strategies algorithms inferences worked well past likely continue working well future inferences obvious since sun rose every morning last days probably rise tomorro ...

# %%
page = remove_single_characters(page)
print(page)
# Out:
# artificial intelligence ai sometimes called machine intelligence learning problem solving scope ai disputed machines become increasingly capable tasks considered requiring intelligence often removed definition phenomenon known nnnartificial intelligence founded academic discipline years since experienced several waves optimism followed disappointment loss funding known deep philosophical differences subfields also based social factors particular institutions work particular researchersnnthe traditional problems goals ai research include many othersnnnthe field founded claim nnin twentyfirst century ai techniques experienced resurgence following concurrent advances helping solve many challenging problems computer science history thoughtcapable nnthe study mechanical artificial neurons field ai research born agreed writing within generationxa problem creating artificial intelligence substantially solvednnthey failed recognize difficulty remaining tasks progress slowed response criticism period obtaining funding ai projects difficultnnnin early ai research revived commercial success market ai fell disrepute second longerlasting hiatus begannnin late early st century ai began used logistics may marked completion significant milestone development artificial intelligence go extremely complex game chessnnaccording jack clark landmark year artificial intelligence number software projects use ai within google increased sporadic usage projects clark also presents factual data indicating error rates image processing tasks fallen significantly since cite webn url httpswwwbloombergcomnewsarticleswhywasabreakthroughyearinartificialintelligencen title breakthrough year artificial intelligencen last clarkn first jackn website bloomberg newsn date december accessdate november quote halfdecade quiet breakthroughs artificial intelligence landmark year computers smarter learning faster evern deadurl non archiveurl httpswebarchiveorgwebhttpswwwbloombergcomnewsarticleswhywasabreakthroughyearinartificialintelligencen archivedate november df dmyalln attributes increase affordable due rise cloud computing infrastructure increase research tools datasets cited examples include microsofts development skype system automatically translate one language another facebooks system describe images blind people survey one five companies reported incorporated ai offerings processes basics nnna typical ai perceives environment takes actions maximize chance successfully achieving goals ais intended possess desired traits systems still benchmarked nongoal system framed system whose goal successfully accomplish narrow classification tasklindenbaum markovitch rusakov selective sampling nearest neighbor classifiers machine learning –nnai often revolves around use someone threat two row take remaining square otherwisen move forks create two threats play move otherwisen take center square free otherwisen opponent played corner take opposite corner otherwisen take empty corner one exists otherwisen take empty squarennmany ai algorithms capable learning data enhance learning new avoid combinatorial explosion would ensue every possible route ponderously considered turncite journaln first en last hartn author nilsson jauthor raphael bn title correction formal basis heuristic determination minimum cost pathsn journal newslettern issue pages –n year doin nnthe earliest easiest understand approach ai symbolism formal logic otherwise healthy adult fever may learn comparing desired output altering strengths connections internal neurons reinforce connections seemed useful four main approaches overlap evolutionary systems example neural nets learn make inferences generalize make analogies systems implicitly explicitly use multiple approaches alongside many ai nonai algorithms learning algorithms work basis strategies algorithms inferences worked well past likely continue working well future inferences obvious since sun rose every morning last days probably rise tomorrow morning well ...

# %% [markdown]
# ### Now build a model using gensim
#
# * Start by building a dictionary of all words found in the cleaned content

# %%
dictionary = corpora.Dictionary(content)
# Out:
# 2018-08-19 10:48:08,127 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2018-08-19 10:48:13,606 : INFO : built Dictionary(28094 unique tokens: ['aaai', 'abandoned', 'abduction', 'ability', 'able']...) from 2284 documents (total 1154234 corpus positions)

# %% [markdown]
# * Ignore words that appear in less than 20 documents or more than 10% documents

# %%
dictionary.filter_extremes(no_below=20, no_above=0.1)
# Out:
# 2018-08-19 10:48:13,654 : INFO : discarding 22661 tokens: [('abandoned', 8), ('ability', 429), ('able', 457), ('academic', 233), ('accelerating', 15), ('accepts', 15), ('accomplishn', 8), ('according', 323), ('achievementsn', 8), ('acknowledge', 15)]...
# 2018-08-19 10:48:13,655 : INFO : keeping 5433 tokens which were in no less than 20 and no more than 228 (=10.0%) documents
# 2018-08-19 10:48:13,662 : INFO : resulting dictionary: Dictionary(5433 unique tokens: ['aaai', 'abduction', 'abstract', 'academy', 'accepted']...)

# %% [markdown]
# * Now create a corpus

# %%
corpus = [dictionary.doc2bow(text) for text in content]

# %%
lda = models.LdaModel(corpus, id2word=dictionary, num_topics=100)
# Out:
# 2018-08-19 10:48:18,550 : INFO : using symmetric alpha at 0.01
# 2018-08-19 10:48:18,551 : INFO : using symmetric eta at 0.01
# 2018-08-19 10:48:18,553 : INFO : using serial LDA version on this node
# 2018-08-19 10:48:18,618 : INFO : running online (single-pass) LDA training, 100 topics, 1 passes over the supplied corpus of 2284 documents, updating model once every 2000 documents, evaluating perplexity every 2284 documents, iterating 50x with a convergence threshold of 0.001000
# 2018-08-19 10:48:18,619 : WARNING : too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2018-08-19 10:48:18,620 : INFO : PROGRESS: pass 0, at document #2000/2284
# 2018-08-19 10:48:21,796 : INFO : merging changes from 2000 documents into a model of 2284 documents
# 2018-08-19 10:48:21,865 : INFO : topic #9 (0.010): 0.081*"fuzzy" + 0.012*"interval" + 0.008*"ppxa–" + 0.005*"uncertainty" + 0.005*"membership" + 0.005*"no" + 0.005*"evolving" + 0.005*"scopecol" + 0.004*"trans" + 0.004*"stylewidth"
# 2018-08-19 10:48:21,866 : INFO : topic #81 (0.010): 0.005*"simulation" + 0.005*"genesis" + 0.004*"situated" + 0.004*"collective" + 0.004*"neuron" + 0.004*"node" + 0.004*"mathcal" + 0.003*"nodes" + 0.003*"neurons" + 0.003*"dl"
# 2018-08-19 10:48:21,867 : INFO : topic #35 (0.010): 0.022*"stylewidth" + 0.022*"scopecol" + 0.005*"dataset" + 0.005*"speech" + 0.004*"database" + 0.004*"music" + 0.004*"on" + 0.003*"sensor" + 0.003*"intuition" + 0.003*"news"
# 2018-08-19 10:48:21,868 : INFO : topic #91 (0.010): 0.007*"robotics" + 0.006*"depth" + 0.006*"–n" + 0.006*"intel" + 0.005*"collective" + 0.005*"camera" + 0.005*"matrix" + 0.004*"stylewidth" + 0.004*"variables" + 0.004*"scopecol"
# 2018-08-19 10:48:21,869 : INFO : topic #23 (0.010): 0.009*"scopecol" + 0.007*"stylewidth" + 0.006*"frame" + 0.004*"kinect" + 0.004*"camera" + 0.004*"smart" + 0.003*"depth" + 0.003*"tilde" + 0.003*"sensors" + 0.003*"element"
# 2018-08-19 10:48:21,870 : INFO : topic diff=12.331515, rho=1.000000
# 2018-08-19 10:48:22,440 : INFO : -9.864 per-word bound, 931.9 perplexity estimate based on a held-out corpus of 284 documents with 60405 words
# 2018-08-19 10:48:22,441 : INFO : PROGRESS: pass 0, at document #2284/2284
# /root/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1023: RuntimeWarning: divide by zero encountered in log
#   diff = np.log(self.expElogbeta)
# 2018-08-19 10:48:22,877 : INFO : merging changes from 284 documents into a model of 2284 documents
# 2018-08-19 10:48:22,950 : INFO : topic #72 (0.010): 0.029*"color" + 0.019*"moments" + 0.016*"recurrent" + 0.008*"rnn" + 0.008*"weights" + 0.007*"units" + 0.007*"lstm" + 0.007*"weight" + 0.007*"sequence" + 0.007*"retrieval"
# 2018-08-19 10:48:22,952 : INFO : topic #54 (0.010): 0.024*"satisfied" + 0.022*"moment" + 0.022*"tilde" + 0.020*"swarm" + 0.017*"stylewidth" + 0.016*"em" + 0.013*"previous" + 0.012*"colspan" + 0.010*"ideas" + 0.009*"entropy"
# 2018-08-19 10:48:22,953 : INFO : topic #27 (0.010): 0.023*"tree" + 0.022*"local" + 0.016*"message" + 0.014*"domains" + 0.013*"vertex" + 0.012*"law" + 0.011*"chi" + 0.009*"messages" + 0.009*"cdot" + 0.009*"edge"
# 2018-08-19 10:48:22,954 : INFO : topic #18 (0.010): 0.010*"enterprise" + 0.008*"conditions" + 0.007*"satisfied" + 0.006*"facts" + 0.006*"stylewidth" + 0.006*"desired" + 0.006*"prior" + 0.006*"usage" + 0.006*"recently" + 0.005*"activity"
# 2018-08-19 10:48:22,955 : INFO : topic #97 (0.010): 0.023*"industrial" + 0.015*"acquisition" + 0.012*"rationality" + 0.011*"principle" + 0.007*"false" + 0.007*"safety" + 0.006*"publisher" + 0.006*"isbn" + 0.006*"newell" + 0.006*"location"
# 2018-08-19 10:48:22,957 : INFO : topic diff=inf, rho=0.707107

# %%
lda.print_topics(20)
# Out:
# 2018-08-19 10:48:22,987 : INFO : topic #55 (0.010): 0.015*"fuzzy" + 0.007*"neurons" + 0.007*"transparent" + 0.007*"opaque" + 0.007*"advantages" + 0.007*"nnas" + 0.006*"medical" + 0.006*"trained" + 0.005*"learned" + 0.005*"complicated"
# 2018-08-19 10:48:22,990 : INFO : topic #97 (0.010): 0.023*"industrial" + 0.015*"acquisition" + 0.012*"rationality" + 0.011*"principle" + 0.007*"false" + 0.007*"safety" + 0.006*"publisher" + 0.006*"isbn" + 0.006*"newell" + 0.006*"location"
# 2018-08-19 10:48:22,991 : INFO : topic #87 (0.010): 0.012*"appearance" + 0.011*"students" + 0.008*"male" + 0.008*"female" + 0.007*"aligncenter" + 0.007*"stylewidth" + 0.006*"scopecol" + 0.006*"emotions" + 0.006*"enhance" + 0.006*"cognition"
# 2018-08-19 10:48:22,993 : INFO : topic #21 (0.010): 0.026*"legal" + 0.022*"cloud" + 0.016*"robotics" + 0.010*"law" + 0.009*"services" + 0.008*"access" + 0.007*"service" + 0.006*"corporation" + 0.005*"uncertain" + 0.005*"potential"
# 2018-08-19 10:48:22,994 : INFO : topic #79 (0.010): 0.025*"aligncenter" + 0.022*"neuron" + 0.019*"neurons" + 0.015*"potential" + 0.014*"tomas" + 0.014*"sun" + 0.011*"spike" + 0.010*"connectivity" + 0.009*"victor" + 0.008*"autonomic"
# 2018-08-19 10:48:22,996 : INFO : topic #9 (0.010): 0.137*"fuzzy" + 0.022*"interval" + 0.015*"ppxa–" + 0.010*"truth" + 0.009*"membership" + 0.008*"uncertainty" + 0.008*"no" + 0.008*"evolving" + 0.007*"trans" + 0.007*"np"
# 2018-08-19 10:48:22,998 : INFO : topic #27 (0.010): 0.023*"tree" + 0.022*"local" + 0.016*"message" + 0.014*"domains" + 0.013*"vertex" + 0.012*"law" + 0.011*"chi" + 0.009*"messages" + 0.009*"cdot" + 0.009*"edge"
# 2018-08-19 10:48:23,000 : INFO : topic #99 (0.010): 0.042*"games" + 0.022*"player" + 0.019*"players" + 0.015*"strategies" + 0.009*"economic" + 0.009*"knowledgebased" + 0.007*"play" + 0.006*"strategy" + 0.005*"moves" + 0.005*"normal"
# 2018-08-19 10:48:23,001 : INFO : topic #57 (0.010): 0.023*"held" + 0.022*"united" + 0.020*"chip" + 0.015*"statesn" + 0.015*"massachusetts" + 0.009*"announced" + 0.009*"ibm" + 0.008*"neurons" + 0.007*"biology" + 0.006*"society"
# 2018-08-19 10:48:23,003 : INFO : topic #14 (0.010): 0.027*"genesis" + 0.016*"neurons" + 0.016*"simulation" + 0.010*"neuron" + 0.007*"nervous" + 0.006*"neuronal" + 0.006*"graphical" + 0.006*"latest" + 0.006*"script" + 0.006*"parallel"
# 2018-08-19 10:48:23,004 : INFO : topic #39 (0.010): 0.013*"phys" + 0.011*"optimization" + 0.008*"ask" + 0.008*"quality" + 0.008*"rev" + 0.007*"psychology" + 0.007*"answer" + 0.007*"local" + 0.006*"turing" + 0.005*"assistant"
# 2018-08-19 10:48:23,005 : INFO : topic #64 (0.010): 0.014*"generators" + 0.011*"probability" + 0.010*"french" + 0.010*"table" + 0.009*"sentence" + 0.008*"signal" + 0.008*"observed" + 0.008*"generator" + 0.008*"hidden" + 0.008*"configuration"
# 2018-08-19 10:48:23,006 : INFO : topic #2 (0.010): 0.016*"oscar" + 0.010*"person" + 0.010*"pain" + 0.009*"scenario" + 0.009*"sensors" + 0.008*"multiagent" + 0.007*"ii" + 0.007*"touch" + 0.007*"something" + 0.007*"map"
# 2018-08-19 10:48:23,008 : INFO : topic #38 (0.010): 0.024*"consciousness" + 0.010*"legal" + 0.009*"conscious" + 0.008*"kinect" + 0.008*"complete" + 0.006*"symbolic" + 0.006*"symbols" + 0.006*"begins" + 0.006*"capability" + 0.006*"scopecol"
# 2018-08-19 10:48:23,009 : INFO : topic #86 (0.010): 0.017*"frame" + 0.016*"condition" + 0.015*"door" + 0.010*"predicate" + 0.010*"sensory" + 0.009*"communication" + 0.009*"conditions" + 0.008*"calculus" + 0.008*"neg" + 0.006*"false"
# 2018-08-19 10:48:23,011 : INFO : topic #4 (0.010): 0.015*"air" + 0.011*"darwin" + 0.009*"nature" + 0.007*"transformation" + 0.006*"code" + 0.006*"projects" + 0.006*"requirements" + 0.006*"staff" + 0.006*"public" + 0.006*"smart"
# 2018-08-19 10:48:23,012 : INFO : topic #26 (0.010): 0.015*"pop" + 0.012*"explanation" + 0.008*"discovery" + 0.007*"treatment" + 0.006*"code" + 0.005*"easily" + 0.005*"obtain" + 0.005*"article" + 0.005*"union" + 0.005*"european"
# 2018-08-19 10:48:23,013 : INFO : topic #84 (0.010): 0.012*"consciousness" + 0.009*"scientific" + 0.007*"kinect" + 0.005*"intelligencen" + 0.005*"conscious" + 0.005*"industrial" + 0.005*"xbox" + 0.005*"series" + 0.005*"roles" + 0.004*"organization"
# 2018-08-19 10:48:23,014 : INFO : topic #20 (0.010): 0.012*"joshua" + 0.011*"blue" + 0.008*"concerns" + 0.007*"founded" + 0.006*"date" + 0.006*"behaviors" + 0.006*"january" + 0.006*"local" + 0.006*"letter" + 0.006*"emotional"
# 2018-08-19 10:48:23,015 : INFO : topic #51 (0.010): 0.015*"tree" + 0.013*"domains" + 0.012*"vertex" + 0.012*"message" + 0.011*"extraction" + 0.011*"local" + 0.009*"operations" + 0.007*"messages" + 0.006*"entity" + 0.006*"law"
# [(55,
#   '0.015*"fuzzy" + 0.007*"neurons" + 0.007*"transparent" + 0.007*"opaque" + 0.007*"advantages" + 0.007*"nnas" + 0.006*"medical" + 0.006*"trained" + 0.005*"learned" + 0.005*"complicated"'),
#  (97,
#   '0.023*"industrial" + 0.015*"acquisition" + 0.012*"rationality" + 0.011*"principle" + 0.007*"false" + 0.007*"safety" + 0.006*"publisher" + 0.006*"isbn" + 0.006*"newell" + 0.006*"location"'),
#  (87,
#   '0.012*"appearance" + 0.011*"students" + 0.008*"male" + 0.008*"female" + 0.007*"aligncenter" + 0.007*"stylewidth" + 0.006*"scopecol" + 0.006*"emotions" + 0.006*"enhance" + 0.006*"cognition"'),
#  (21,
#   '0.026*"legal" + 0.022*"cloud" + 0.016*"robotics" + 0.010*"law" + 0.009*"services" + 0.008*"access" + 0.007*"service" + 0.006*"corporation" + 0.005*"uncertain" + 0.005*"potential"'),
#  (79,
#   '0.025*"aligncenter" + 0.022*"neuron" + 0.019*"neurons" + 0.015*"potential" + 0.014*"tomas" + 0.014*"sun" + 0.011*"spike" + 0.010*"connectivity" + 0.009*"victor" + 0.008*"autonomic"'),
#  (9,
#   '0.137*"fuzzy" + 0.022*"interval" + 0.015*"ppxa–" + 0.010*"truth" + 0.009*"membership" + 0.008*"uncertainty" + 0.008*"no" + 0.008*"evolving" + 0.007*"trans" + 0.007*"np"'),
#  (27,
#   '0.023*"tree" + 0.022*"local" + 0.016*"message" + 0.014*"domains" + 0.013*"vertex" + 0.012*"law" + 0.011*"chi" + 0.009*"messages" + 0.009*"cdot" + 0.009*"edge"'),
#  (99,
#   '0.042*"games" + 0.022*"player" + 0.019*"players" + 0.015*"strategies" + 0.009*"economic" + 0.009*"knowledgebased" + 0.007*"play" + 0.006*"strategy" + 0.005*"moves" + 0.005*"normal"'),
#  (57,
#   '0.023*"held" + 0.022*"united" + 0.020*"chip" + 0.015*"statesn" + 0.015*"massachusetts" + 0.009*"announced" + 0.009*"ibm" + 0.008*"neurons" + 0.007*"biology" + 0.006*"society"'),
#  (14,
#   '0.027*"genesis" + 0.016*"neurons" + 0.016*"simulation" + 0.010*"neuron" + 0.007*"nervous" + 0.006*"neuronal" + 0.006*"graphical" + 0.006*"latest" + 0.006*"script" + 0.006*"parallel"'),
#  (39,
#   '0.013*"phys" + 0.011*"optimization" + 0.008*"ask" + 0.008*"quality" + 0.008*"rev" + 0.007*"psychology" + 0.007*"answer" + 0.007*"local" + 0.006*"turing" + 0.005*"assistant"'),
#  (64,
#   '0.014*"generators" + 0.011*"probability" + 0.010*"french" + 0.010*"table" + 0.009*"sentence" + 0.008*"signal" + 0.008*"observed" + 0.008*"generator" + 0.008*"hidden" + 0.008*"configuration"'),
#  (2,
#   '0.016*"oscar" + 0.010*"person" + 0.010*"pain" + 0.009*"scenario" + 0.009*"sensors" + 0.008*"multiagent" + 0.007*"ii" + 0.007*"touch" + 0.007*"something" + 0.007*"map"'),
#  (38,
#   '0.024*"consciousness" + 0.010*"legal" + 0.009*"conscious" + 0.008*"kinect" + 0.008*"complete" + 0.006*"symbolic" + 0.006*"symbols" + 0.006*"begins" + 0.006*"capability" + 0.006*"scopecol"'),
#  (86,
#   '0.017*"frame" + 0.016*"condition" + 0.015*"door" + 0.010*"predicate" + 0.010*"sensory" + 0.009*"communication" + 0.009*"conditions" + 0.008*"calculus" + 0.008*"neg" + 0.006*"false"'),
#  (4,
#   '0.015*"air" + 0.011*"darwin" + 0.009*"nature" + 0.007*"transformation" + 0.006*"code" + 0.006*"projects" + 0.006*"requirements" + 0.006*"staff" + 0.006*"public" + 0.006*"smart"'),
#  (26,
#   '0.015*"pop" + 0.012*"explanation" + 0.008*"discovery" + 0.007*"treatment" + 0.006*"code" + 0.005*"easily" + 0.005*"obtain" + 0.005*"article" + 0.005*"union" + 0.005*"european"'),
#  (84,
#   '0.012*"consciousness" + 0.009*"scientific" + 0.007*"kinect" + 0.005*"intelligencen" + 0.005*"conscious" + 0.005*"industrial" + 0.005*"xbox" + 0.005*"series" + 0.005*"roles" + 0.004*"organization"'),
#  (20,
#   '0.012*"joshua" + 0.011*"blue" + 0.008*"concerns" + 0.007*"founded" + 0.006*"date" + 0.006*"behaviors" + 0.006*"january" + 0.006*"local" + 0.006*"letter" + 0.006*"emotional"'),
#  (51,
#   '0.015*"tree" + 0.013*"domains" + 0.012*"vertex" + 0.012*"message" + 0.011*"extraction" + 0.011*"local" + 0.009*"operations" + 0.007*"messages" + 0.006*"entity" + 0.006*"law"')]

# %%
def get_similarity(lda, q_vec):
    index = similarities.MatrixSimilarity(lda[corpus])
    sims = index[q_vec]
    return sims

# %%
query = "who invented deep learning"
bow = dictionary.doc2bow(content.get_cleaned_text(query).split())

# %%
bow
# Out:
# [(346, 1), (2496, 1)]

# %%
print(dictionary[346], dictionary[2496])
# Out:
# deep invented

# %%
q_vec = lda[bow]
print(q_vec)
# Out:
# [(67, 0.67)]

# %%
print(lda.print_topic(max(lda_vector, key=lambda item: item[1])[0]))
# Out:
# 0.030*"music" + 0.016*"february" + 0.014*"weak" + 0.013*"retrieved" + 0.012*"length" + 0.012*"narrow" + 0.011*"extra" + 0.007*"games" + 0.007*"oct" + 0.006*"lab"

# %%
sims = get_similarity(lda, q_vec)
# Out:
# 2018-08-19 10:48:23,181 : WARNING : scanning corpus to determine the number of features (consider setting `num_features` explicitly)
# 2018-08-19 10:48:25,700 : INFO : creating matrix with 2284 documents and 100 features
# /root/anaconda3/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):

# %%
sims = sorted(enumerate(sims), key=lambda item: -item[1])

# %%
sims[:5]
# Out:
# [(83, 1.0), (208, 1.0), (409, 1.0), (534, 1.0), (735, 1.0)]

# %%
for idx in [4, 208, 323, 330, 534]:
    pageid = page_ids[idx]
    print('Page ID {}: {}'.format(pageid, content.get_page_url_by_id(pageid)))
# Out:
# Page ID ('43470933',): ('https://en.wikipedia.org/wiki/0music',)
# Page ID ('53587467',): ('https://en.wikipedia.org/wiki/Outline_of_machine_learning',)
# Page ID ('52968552',): ('https://en.wikipedia.org/wiki/WordDive',)
# Page ID ('43470933',): ('https://en.wikipedia.org/wiki/0music',)
# Page ID ('53587467',): ('https://en.wikipedia.org/wiki/Outline_of_machine_learning',)
