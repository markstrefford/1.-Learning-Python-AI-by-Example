# %% [markdown]
# # LDA with Gensim

# %% [markdown]
# * Start by importing python libraries that we'll be using

# %%
# %load_ext autoreload
# %autoreload 2

import sqlite3
import string
import logging

from gensim import corpora, utils, models, similarities
from collections import defaultdict

import nltk
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# * Let's set up some basic config

# %%
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

punctuation = set(string.punctuation)
stoplist = set(stopwords.words('english'))

frequency = defaultdict(int)

stemmer = SnowballStemmer("english")
lemma = WordNetLemmatizer()

dictionary = corpora.Dictionary()

# %% [markdown]
# ### Create a class for our content

# %% [markdown]
# This class will use the database that we created when we downloaded content from Wikipedia

# %%
class ContentStore:
    def __init__(self, db_file):
        """
        Intialise the crawl_wikipedia class, set up a
        lightweight database for storing content for later use
        :param db_file:
        """
        self.categories = []
        # Connect to the DB db
        self.conn = sqlite3.connect(db_file)
        self.cursor = self.conn.cursor()

    def get_page_urls(self):
        """
        Retrieve a list of urls from the database
        :return: list of urls
        """
        return [row for row in self.cursor.execute("SELECT url FROM content")]
    
    def get_page_ids(self):
        """
        Retrieve a list of page ids from the database
        :return: list of page id tuples
        """
        return [row for row in self.cursor.execute("SELECT pageid FROM content")]   
    
    def get_page_by_id(self, pageid):
        """
        Retrieve the page with the specified pageid
        Note that this is of the format (pageid, ) for SQLite3 to work, for example
        to get the page with the id of 1 in our database, set pageid to ('1', )
        :return: string
        """
        return str(self.cursor.execute("SELECT content FROM content WHERE pageid=?", pageid).fetchone()).lower()
    
    def get_page_url_by_id(self, pageid):
        """
        Retrieve the page with the specified pageid
        Note that this is of the format (pageid, ) for SQLite3 to work, for example
        to get the page with the id of 1 in our database, set pageid to ('1', )
        :return: string
        """
        return self.cursor.execute("SELECT url FROM content WHERE pageid=?", pageid).fetchone()
    
    def get_cleaned_text(self, text):
        """
        Return the page with stopwords, digits, punctuation and single character words removed
        :return: string
        """
        # Remove numbers
        text = ''.join(char for char in text if not char.isdigit())
        # Remove stop words
        text = ' '.join([word for word in text.split() if word not in stoplist])
        # Remove punctuation
        text = ''.join(char for char in text if char not in punctuation)
        # Remove single character words
        text = ' '.join([word for word in text.split() if len(word) > 1])
        return text
        
    def __iter__(self):
        for pageid in self.get_page_ids():
            page = self.get_page_by_id(pageid)
            yield self.get_cleaned_text(page).split()
        
#     def __iter__(self):
#         self.pageids = self.get_page_ids()
#         self.idx = 0
#         return self
    
#     def __next__(self):
#         if self.idx <= len(self.pageids):
#             pageid = self.pageids(self.idx)
#             page = dictionary.doc2bow(self.get_cleaned_page_by_id(pageid))
#             self.idx += 1
#             return page
#         else:
#             raise StopIteration

# %% [markdown]
# ### Remove punctuation from text

# %%
def remove_punctuation(text):
    """
    Remove punctuation from text by checking each character against a set of punctation characters
    :return: string
    """
    return ''.join(char for char in text if char not in punctuation)

# %% [markdown]
# ### Remove numbers from text

# %%
def remove_numbers(text):
    """
    Remove numbers from text as they aren't of value to our model
    :return: string
    """
    return ''.join(char for char in text if not char.isdigit())

# %% [markdown]
# ### Remove stop words from text

# %%
def remove_stop_words(text):
    """
    Remove common words as they won't add any value to our model
    :return: string
    """
    return ' '.join([word for word in text.split() if word not in stoplist])

# %% [markdown]
# ### Remove single character words

# %%
def remove_single_characters(text):
    """
    Remove any remaining single-character words
    :return: string
    """
    return ' '.join([word for word in text.split() if len(word) > 1])

# %% [markdown]
# ### Lemmatize our document

# %%
def lemmatize(text):
    return text

# %% [markdown]
# ### Stemmatize our document

# %%
def stemmatize(text):
    return text

# %% [markdown]
# ### Exploring and cleaning our content
#
# * Access our database of Wikipedia content and get a list of all of the pages IDs

# %%
content = ContentStore('../content.db')
page_ids = content.get_page_ids()

# %% [markdown]
# * Let's view a page from our database

# %%
page = content.get_page_by_id(page_ids[0])
print(page)
# Out:
# ('\'\'\'artificial intelligence\'\'\' (\'\'\'ai\'\'\'), sometimes called \'\'\'machine intelligence\'\'\', iss, such as "learning" and "problem solving".the scope of ai is disputed: as machines become increasingly capable, tasks considered as requiring "intelligence" are often removed from the definition, a phenomenon known as the.\n\n\nartificial intelligence was founded as an academic discipline in 1956, and in the years since has experienced several waves of optimism, followed by disappointment and the loss of funding (known as an "s), or deep philosophical differences. subfields have also been based on social factors (particular institutions or the work of particular researchers).\n\nthe traditional problems (or goals) of ai research includeand many others.\n\n\nthe field was founded on the claim that.\n\nin the twenty-first century, ai techniques have experienced a resurgence following concurrent advances in, helping to solve many challenging problems in computer science.== history ==thought-capable.\n\nthe study of mechanical or"artificial neurons".the field of ai research was born atagreed, writing, "within a generation\xa0... the problem of creating \'artificial intelligence\' will substantially be solved".\n\nthey failed to recognize the difficulty of some of the remaining tasks. progress slowed and in 1974, in response to the criticism of", a period when obtaining funding for ai projects was difficult.\n\n\nin the early 1980s, ai research was revived by the commercial success ofmarket in 1987, ai once again fell into disrepute, and a second, longer-lasting hiatus began.\n\nin the late 1990s and early 21st century, ai began to be used for logistics,on 11 may 1997.in 2011, a \'\',this marked the completion of a significant milestone in the development of artificial intelligence as go is an extremely complex game, more so than chess.\n\naccording tojack clark, 2015 was a landmark year for artificial intelligence, with the number of software projects that use ai within google increased from a "sporadic usage" in 2012 to more than 2,700 projects. clark also presents factual data indicating that error rates in image processing tasks have fallen significantly since 2011.{{cite web\n |url         = https://www.bloomberg.com/news/articles/2015-12-08/why-2015-was-a-breakthrough-year-in-artificial-intelligence\n |title       = why 2015 was a breakthrough year in artificial intelligence\n |last        = clark\n |first       = jack\n |website     = bloomberg news\n |date        = 8 december 2015\n |access-date = 23 november 2016\n |quote       = after a half-decade of quiet breakthroughs in artificial intelligence, 2015 has been a landmark year. computers are smarter and learning faster than ever.\n |deadurl     = no\n |archiveurl  = https://web.archive.org/web/20161123053855/https://www.bloomberg.com/news/articles/2015-12-08/why-2015-was-a-breakthrough-year-in-artificial-intelligence\n |archivedate = 23 november 2016\n |df          = dmy-all\n}} he attributes this to an increase in affordable, due to a rise in cloud computing infrastructure and to an increase in research tools and datasets. other cited examples include microsoft\'s development of a skype system that can automatically translate from one language to another and facebook\'s system that can describe images to blind people. in a 2017 survey, one in five companies reported they had "incorporated ai in some offerings or processes".== basics ==\n\n\na typical ai perceives its environment and takes actions that maximize its chance of successfully achieving its goals. an ai\'s intendedto possess desired traits.such systems can still be benchmarked if the non-goal system is framed as a system whose "goal" is to successfully accomplish its narrow classification task.lindenbaum, m., markovitch, s., & rusakov, d. (2004). selective sampling for nearest neighbor classifiers. machine learning, 54(2), 125–152.\n\nai often revolves around the use of:# if someone has a "threat" (th ...

# %% [markdown]
# * Now let's remove punctuation

# %%
page = remove_punctuation(page)
print(page)
# Out:
# artificial intelligence ai sometimes called machine intelligence iss such as learning and problem solvingthe scope of ai is disputed as machines become increasingly capable tasks considered as requiring intelligence are often removed from the definition a phenomenon known as thennnartificial intelligence was founded as an academic discipline in 1956 and in the years since has experienced several waves of optimism followed by disappointment and the loss of funding known as an s or deep philosophical differences subfields have also been based on social factors particular institutions or the work of particular researchersnnthe traditional problems or goals of ai research includeand many othersnnnthe field was founded on the claim thatnnin the twentyfirst century ai techniques have experienced a resurgence following concurrent advances in helping to solve many challenging problems in computer science history thoughtcapablennthe study of mechanical orartificial neuronsthe field of ai research was born atagreed writing within a generationxa0 the problem of creating artificial intelligence will substantially be solvednnthey failed to recognize the difficulty of some of the remaining tasks progress slowed and in 1974 in response to the criticism of a period when obtaining funding for ai projects was difficultnnnin the early 1980s ai research was revived by the commercial success ofmarket in 1987 ai once again fell into disrepute and a second longerlasting hiatus begannnin the late 1990s and early 21st century ai began to be used for logisticson 11 may 1997in 2011 a this marked the completion of a significant milestone in the development of artificial intelligence as go is an extremely complex game more so than chessnnaccording tojack clark 2015 was a landmark year for artificial intelligence with the number of software projects that use ai within google increased from a sporadic usage in 2012 to more than 2700 projects clark also presents factual data indicating that error rates in image processing tasks have fallen significantly since 2011cite webn url          httpswwwbloombergcomnewsarticles20151208why2015wasabreakthroughyearinartificialintelligencen title        why 2015 was a breakthrough year in artificial intelligencen last         clarkn first        jackn website      bloomberg newsn date         8 december 2015n accessdate  23 november 2016n quote        after a halfdecade of quiet breakthroughs in artificial intelligence 2015 has been a landmark year computers are smarter and learning faster than evern deadurl      non archiveurl   httpswebarchiveorgweb20161123053855httpswwwbloombergcomnewsarticles20151208why2015wasabreakthroughyearinartificialintelligencen archivedate  23 november 2016n df           dmyalln he attributes this to an increase in affordable due to a rise in cloud computing infrastructure and to an increase in research tools and datasets other cited examples include microsofts development of a skype system that can automatically translate from one language to another and facebooks system that can describe images to blind people in a 2017 survey one in five companies reported they had incorporated ai in some offerings or processes basics nnna typical ai perceives its environment and takes actions that maximize its chance of successfully achieving its goals an ais intendedto possess desired traitssuch systems can still be benchmarked if the nongoal system is framed as a system whose goal is to successfully accomplish its narrow classification tasklindenbaum m markovitch s  rusakov d 2004 selective sampling for nearest neighbor classifiers machine learning 542 125–152nnai often revolves around the use of if someone has a threat that is two in a row take the remaining square otherwisen if a move forks to create two threats at once play that move otherwisen take the center square if it is free otherwisen if your opponent has played in a corner take the opposite corner otherwisen take an empty corner if one exists o ...

# %% [markdown]
# * Remove numbers

# %%
page = remove_numbers(page)
print(page)
# Out:
# artificial intelligence ai sometimes called machine intelligence iss such as learning and problem solvingthe scope of ai is disputed as machines become increasingly capable tasks considered as requiring intelligence are often removed from the definition a phenomenon known as thennnartificial intelligence was founded as an academic discipline in  and in the years since has experienced several waves of optimism followed by disappointment and the loss of funding known as an s or deep philosophical differences subfields have also been based on social factors particular institutions or the work of particular researchersnnthe traditional problems or goals of ai research includeand many othersnnnthe field was founded on the claim thatnnin the twentyfirst century ai techniques have experienced a resurgence following concurrent advances in helping to solve many challenging problems in computer science history thoughtcapablennthe study of mechanical orartificial neuronsthe field of ai research was born atagreed writing within a generationxa the problem of creating artificial intelligence will substantially be solvednnthey failed to recognize the difficulty of some of the remaining tasks progress slowed and in  in response to the criticism of a period when obtaining funding for ai projects was difficultnnnin the early s ai research was revived by the commercial success ofmarket in  ai once again fell into disrepute and a second longerlasting hiatus begannnin the late s and early st century ai began to be used for logisticson  may in  a this marked the completion of a significant milestone in the development of artificial intelligence as go is an extremely complex game more so than chessnnaccording tojack clark  was a landmark year for artificial intelligence with the number of software projects that use ai within google increased from a sporadic usage in  to more than  projects clark also presents factual data indicating that error rates in image processing tasks have fallen significantly since cite webn url          httpswwwbloombergcomnewsarticleswhywasabreakthroughyearinartificialintelligencen title        why  was a breakthrough year in artificial intelligencen last         clarkn first        jackn website      bloomberg newsn date          december n accessdate   november n quote        after a halfdecade of quiet breakthroughs in artificial intelligence  has been a landmark year computers are smarter and learning faster than evern deadurl      non archiveurl   httpswebarchiveorgwebhttpswwwbloombergcomnewsarticleswhywasabreakthroughyearinartificialintelligencen archivedate   november n df           dmyalln he attributes this to an increase in affordable due to a rise in cloud computing infrastructure and to an increase in research tools and datasets other cited examples include microsofts development of a skype system that can automatically translate from one language to another and facebooks system that can describe images to blind people in a  survey one in five companies reported they had incorporated ai in some offerings or processes basics nnna typical ai perceives its environment and takes actions that maximize its chance of successfully achieving its goals an ais intendedto possess desired traitssuch systems can still be benchmarked if the nongoal system is framed as a system whose goal is to successfully accomplish its narrow classification tasklindenbaum m markovitch s  rusakov d  selective sampling for nearest neighbor classifiers machine learning  –nnai often revolves around the use of if someone has a threat that is two in a row take the remaining square otherwisen if a move forks to create two threats at once play that move otherwisen take the center square if it is free otherwisen if your opponent has played in a corner take the opposite corner otherwisen take an empty corner if one exists otherwisen take any empty squarennmany ai algorithms are capable of learning from data they can enhance themselves by learning new ...

# %% [markdown]
# * And stop words

# %%
page = remove_stop_words(page)
print(page)
# Out:
# artificial intelligence ai sometimes called machine intelligence iss learning problem solvingthe scope ai disputed machines become increasingly capable tasks considered requiring intelligence often removed definition phenomenon known thennnartificial intelligence founded academic discipline years since experienced several waves optimism followed disappointment loss funding known deep philosophical differences subfields also based social factors particular institutions work particular researchersnnthe traditional problems goals ai research includeand many othersnnnthe field founded claim thatnnin twentyfirst century ai techniques experienced resurgence following concurrent advances helping solve many challenging problems computer science history thoughtcapablennthe study mechanical orartificial neuronsthe field ai research born atagreed writing within generationxa problem creating artificial intelligence substantially solvednnthey failed recognize difficulty remaining tasks progress slowed response criticism period obtaining funding ai projects difficultnnnin early ai research revived commercial success ofmarket ai fell disrepute second longerlasting hiatus begannnin late early st century ai began used logisticson may marked completion significant milestone development artificial intelligence go extremely complex game chessnnaccording tojack clark landmark year artificial intelligence number software projects use ai within google increased sporadic usage projects clark also presents factual data indicating error rates image processing tasks fallen significantly since cite webn url httpswwwbloombergcomnewsarticleswhywasabreakthroughyearinartificialintelligencen title breakthrough year artificial intelligencen last clarkn first jackn website bloomberg newsn date december n accessdate november n quote halfdecade quiet breakthroughs artificial intelligence landmark year computers smarter learning faster evern deadurl non archiveurl httpswebarchiveorgwebhttpswwwbloombergcomnewsarticleswhywasabreakthroughyearinartificialintelligencen archivedate november n df dmyalln attributes increase affordable due rise cloud computing infrastructure increase research tools datasets cited examples include microsofts development skype system automatically translate one language another facebooks system describe images blind people survey one five companies reported incorporated ai offerings processes basics nnna typical ai perceives environment takes actions maximize chance successfully achieving goals ais intendedto possess desired traitssuch systems still benchmarked nongoal system framed system whose goal successfully accomplish narrow classification tasklindenbaum markovitch rusakov selective sampling nearest neighbor classifiers machine learning –nnai often revolves around use someone threat two row take remaining square otherwisen move forks create two threats play move otherwisen take center square free otherwisen opponent played corner take opposite corner otherwisen take empty corner one exists otherwisen take empty squarennmany ai algorithms capable learning data enhance learning newcan avoid combinatorial explosion would ensue every possible route ponderously considered turncite journaln first p en last hartn author nilsson n jauthor raphael bn title correction formal basis heuristic determination minimum cost pathsn journal newslettern issue n pages –n year n doin nnthe earliest easiest understand approach ai symbolism formal logic otherwise healthy adult fever may learn comparing desired output altering strengths connections internal neurons reinforce connections seemed useful four main approaches overlap evolutionary systems example neural nets learn make inferences generalize make analogies systems implicitly explicitly use multiple approaches alongside many ai nonai algorithmslearning algorithms work basis strategies algorithms inferences worked well past likely continue working well future inferences obvious since sun rose every mo ...

# %%
page = remove_single_characters(page)
print(page)
# Out:
# artificial intelligence ai sometimes called machine intelligence iss learning problem solvingthe scope ai disputed machines become increasingly capable tasks considered requiring intelligence often removed definition phenomenon known thennnartificial intelligence founded academic discipline years since experienced several waves optimism followed disappointment loss funding known deep philosophical differences subfields also based social factors particular institutions work particular researchersnnthe traditional problems goals ai research includeand many othersnnnthe field founded claim thatnnin twentyfirst century ai techniques experienced resurgence following concurrent advances helping solve many challenging problems computer science history thoughtcapablennthe study mechanical orartificial neuronsthe field ai research born atagreed writing within generationxa problem creating artificial intelligence substantially solvednnthey failed recognize difficulty remaining tasks progress slowed response criticism period obtaining funding ai projects difficultnnnin early ai research revived commercial success ofmarket ai fell disrepute second longerlasting hiatus begannnin late early st century ai began used logisticson may marked completion significant milestone development artificial intelligence go extremely complex game chessnnaccording tojack clark landmark year artificial intelligence number software projects use ai within google increased sporadic usage projects clark also presents factual data indicating error rates image processing tasks fallen significantly since cite webn url httpswwwbloombergcomnewsarticleswhywasabreakthroughyearinartificialintelligencen title breakthrough year artificial intelligencen last clarkn first jackn website bloomberg newsn date december accessdate november quote halfdecade quiet breakthroughs artificial intelligence landmark year computers smarter learning faster evern deadurl non archiveurl httpswebarchiveorgwebhttpswwwbloombergcomnewsarticleswhywasabreakthroughyearinartificialintelligencen archivedate november df dmyalln attributes increase affordable due rise cloud computing infrastructure increase research tools datasets cited examples include microsofts development skype system automatically translate one language another facebooks system describe images blind people survey one five companies reported incorporated ai offerings processes basics nnna typical ai perceives environment takes actions maximize chance successfully achieving goals ais intendedto possess desired traitssuch systems still benchmarked nongoal system framed system whose goal successfully accomplish narrow classification tasklindenbaum markovitch rusakov selective sampling nearest neighbor classifiers machine learning –nnai often revolves around use someone threat two row take remaining square otherwisen move forks create two threats play move otherwisen take center square free otherwisen opponent played corner take opposite corner otherwisen take empty corner one exists otherwisen take empty squarennmany ai algorithms capable learning data enhance learning newcan avoid combinatorial explosion would ensue every possible route ponderously considered turncite journaln first en last hartn author nilsson jauthor raphael bn title correction formal basis heuristic determination minimum cost pathsn journal newslettern issue pages –n year doin nnthe earliest easiest understand approach ai symbolism formal logic otherwise healthy adult fever may learn comparing desired output altering strengths connections internal neurons reinforce connections seemed useful four main approaches overlap evolutionary systems example neural nets learn make inferences generalize make analogies systems implicitly explicitly use multiple approaches alongside many ai nonai algorithmslearning algorithms work basis strategies algorithms inferences worked well past likely continue working well future inferences obvious since sun rose every morning last day ...

# %% [markdown]
# ### Now build a model using gensim
#
# * Start by building a dictionary of all words found in the cleaned content

# %%
dictionary = corpora.Dictionary(content)
# Out:
# 2018-08-19 12:43:54,270 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2018-08-19 12:43:55,082 : INFO : built Dictionary(30607 unique tokens: ['aaai', 'aally', 'abandoned', 'abduction', 'ability']...) from 327 documents (total 162671 corpus positions)

# %% [markdown]
# * Ignore words that appear in less than 10 documents or more than 20% documents
#
# (These settings are configurable and can produce very different results for the same document set)

# %%
dictionary.filter_extremes(no_below=10, no_above=0.2)
# Out:
# 2018-08-19 12:43:55,135 : INFO : discarding 28741 tokens: [('aally', 1), ('abandoned', 1), ('abduction', 3), ('academy', 5), ('accelerating', 2), ('accepts', 2), ('accomplished', 6), ('accomplishn', 1), ('accordance', 4), ('accumulate', 3)]...
# 2018-08-19 12:43:55,136 : INFO : keeping 1866 tokens which were in no less than 10 and no more than 65 (=20.0%) documents
# 2018-08-19 12:43:55,143 : INFO : resulting dictionary: Dictionary(1866 unique tokens: ['aaai', 'ability', 'able', 'abstract', 'academic']...)

# %% [markdown]
# * Now create a corpus

# %%
corpus = [dictionary.doc2bow(text) for text in content]

# %%
lda = models.LdaModel(corpus, id2word=dictionary, random_state=1, num_topics=200, passes=50)
# Out:
# 2018-08-19 13:05:01,700 : INFO : using symmetric alpha at 0.005
# 2018-08-19 13:05:01,701 : INFO : using symmetric eta at 0.005
# 2018-08-19 13:05:01,703 : INFO : using serial LDA version on this node
# 2018-08-19 13:05:01,752 : INFO : running online (multi-pass) LDA training, 200 topics, 50 passes over the supplied corpus of 327 documents, updating model once every 327 documents, evaluating perplexity every 327 documents, iterating 50x with a convergence threshold of 0.001000
# 2018-08-19 13:05:02,752 : INFO : -27.244 per-word bound, 158908680.4 perplexity estimate based on a held-out corpus of 327 documents with 73982 words
# 2018-08-19 13:05:02,754 : INFO : PROGRESS: pass 0, at document #327/327
# 2018-08-19 13:05:03,453 : INFO : topic #192 (0.005): 0.020*"cognitive" + 0.015*"solving" + 0.010*"communication" + 0.006*"people" + 0.005*"depth" + 0.005*"robot" + 0.005*"object" + 0.005*"vision" + 0.005*"functional" + 0.005*"person"
# 2018-08-19 13:05:03,456 : INFO : topic #145 (0.005): 0.013*"expert" + 0.010*"image" + 0.009*"knowledgebased" + 0.008*"last" + 0.007*"rules" + 0.007*"images" + 0.006*"et" + 0.006*"vision" + 0.005*"term" + 0.005*"ieee"
# 2018-08-19 13:05:03,457 : INFO : topic #133 (0.005): 0.024*"cognitive" + 0.020*"action" + 0.018*"selection" + 0.016*"students" + 0.012*"agents" + 0.007*"dynamic" + 0.007*"plans" + 0.006*"environment" + 0.006*"agent" + 0.006*"approaches"
perplexity estimate based on a held-out corpus of 327 documents with 73982 words
# 2018-08-19 13:05:50,403 : INFO : PROGRESS: pass 44, at document #327/327
# 2018-08-19 13:05:50,736 : INFO : topic #25 (0.005): 0.044*"held" + 0.040*"brain" + 0.035*"united" + 0.028*"cambridge" + 0.020*"project" + 0.020*"objective" + 0.015*"society" + 0.015*"second" + 0.011*"thought" + 0.011*"around"
# 2018-08-19 13:05:50,739 : INFO : topic #82 (0.005): 0.030*"frame" + 0.028*"digital" + 0.023*"languages" + 0.021*"internet" + 0.017*"project" + 0.016*"web" + 0.015*"art" + 0.011*"performance" + 0.010*"generated" + 0.010*"researchers"
# 2018-08-19 13:05:50,742 : INFO : topic #27 (0.005): 0.001*"audio" + 0.001*"consciousness" + 0.001*"features" + 0.001*"music" + 0.001*"chess" + 0.001*"signals" + 0.001*"methods" + 0.001*"cognitive" + 0.001*"structure" + 0.001*"detection"
# 2018-08-19 13:05:50,746 : INFO : topic #88 (0.005): 0.001*"et" + 0.001*"ieee" + 0.001*"al" + 0.001*"recognition" + 0.001*"features" + 0.001*"images" + 0.001*"proceedings" + 0.001*"on" + 0.001*"cite" + 0.001*"vision"
# 2018-08-19 13:05:50,749 : INFO : topic #38 (0.005): 0.090*"function" + 0.090*"an" + 0.045*"computers" + 0.045*"every" + 0.045*"record" + 0.045*"maps" + 0.045*"agent" + 0.045*"act" + 0.045*"users" + 0.045*"application"
# 2018-08-19 13:05:50,753 : INFO : topic diff=inf, rho=0.147442
# 2018-08-19 13:05:51,367 : INFO : -7.572 per-word bound, 190.3 perplexity estimate based on a held-out corpus of 327 documents with 73982 words
# 2018-08-19 13:05:51,370 : INFO : PROGRESS: pass 45, at document #327/327
# 2018-08-19 13:05:51,703 : INFO : topic #171 (0.005): 0.049*"true" + 0.038*"know" + 0.035*"layer" + 0.030*"logic" + 0.027*"agent" + 0.022*"logical" + 0.019*"properties" + 0.018*"worlds" + 0.014*"every" + 0.013*"says"
# 2018-08-19 13:05:51,706 : INFO : topic #163 (0.005): 0.001*"et" + 0.001*"integration" + 0.001*"network" + 0.001*"frame" + 0.001*"agent" + 0.001*"music" + 0.001*"computing" + 0.001*"able" + 0.001*"created" + 0.001*"recognition"
# 2018-08-19 13:05:51,709 : INFO : topic #101 (0.005): 0.001*"network" + 0.001*"competition" + 0.001*"node" + 0.001*"nodes" + 0.001*"neural" + 0.001*"held" + 0.001*"brain" + 0.001*"entity" + 0.001*"ie" + 0.001*"music"
# 2018-08-19 13:05:51,712 : INFO : topic #196 (0.005): 0.027*"agent" + 0.018*"agents" + 0.016*"humans" + 0.012*"series" + 0.011*"user" + 0.011*"role" + 0.011*"robot" + 0.009*"google" + 0.009*"robots" + 0.008*"brain"
# 2018-08-19 13:05:51,715 : INFO : topic #21 (0.005): 0.001*"image" + 0.001*"et" + 0.001*"images" + 0.001*"network" + 0.001*"recognition" + 0.001*"journal" + 0.001*"document" + 0.001*"networks" + 0.001*"ieee" + 0.001*"neural"
# 2018-08-19 13:05:51,719 : INFO : topic diff=inf, rho=0.145865
# 2018-08-19 13:05:52,334 : INFO : -7.571 per-word bound, 190.1 perplexity estimate based on a held-out corpus of 327 documents with 73982 words
# 2018-08-19 13:05
perplexity estimate based on a held-out corpus of 327 documents with 73982 words
# 2018-08-19 13:05:54,346 : INFO : PROGRESS: pass 48, at document #327/327
# 2018-08-19 13:05:54,680 : INFO : topic #167 (0.005): 0.036*"rules" + 0.033*"matrix" + 0.029*"space" + 0.025*"variables" + 0.022*"rule" + 0.022*"true" + 0.022*"logical" + 0.022*"inference" + 0.016*"objects" + 0.016*"network"
# 2018-08-19 13:05:54,683 : INFO : topic #130 (0.005): 0.043*"techniques" + 0.043*"heuristic" + 0.043*"employ" + 0.022*"rules" + 0.022*"field" + 0.022*"key" + 0.022*"machines" + 0.022*"people" + 0.022*"rather" + 0.022*"programming"
# 2018-08-19 13:05:54,686 : INFO : topic #59 (0.005): 0.001*"et" + 0.001*"vision" + 0.001*"image" + 0.001*"images" + 0.001*"al" + 0.001*"ieee" + 0.001*"semantic" + 0.001*"databases" + 0.001*"recognition" + 0.001*"database"
# 2018-08-19 13:05:54,689 : INFO : topic #158 (0.005): 0.049*"action" + 0.047*"selection" + 0.038*"agents" + 0.025*"environment" + 0.018*"plans" + 0.018*"approaches" + 0.016*"distributed" + 0.014*"actions" + 0.014*"agent" + 0.013*"autonomous"
# 2018-08-19 13:05:54,692 : INFO : topic #176 (0.005): 0.044*"brain" + 0.044*"researchers" + 0.037*"strong" + 0.028*"test" + 0.020*"mind" + 0.019*"able" + 0.018*"computers" + 0.017*"machines" + 0.016*"simulation" + 0.015*"progress"
# 2018-08-19 13:05:54,696 : INFO : topic diff=inf, rho=0.141421
# 2018-08-19 13:05:55,342 : INFO : -7.568 per-word bound, 189.7 perplexity estimate based on a held-out corpus of 327 documents with 73982 words
# 2018-08-19 13:05:55,345 : INFO : PROGRESS: pass 49, at document #327/327
# 2018-08-19 13:05:55,680 : INFO : topic #138 (0.005): 0.057*"programming" + 0.037*"game" + 0.037*"design" + 0.036*"school" + 0.036*"students" + 0.032*"rules" + 0.021*"train" + 0.018*"middle" + 0.017*"conversational" + 0.017*"eg"
# 2018-08-19 13:05:55,683 : INFO : topic #135 (0.005): 0.076*"node" + 0.067*"best" + 0.066*"children" + 0.038*"if" + 0.038*"thenn" + 0.038*"classification" + 0.029*"tree" + 0.029*"object" + 0.029*"nodes" + 0.019*"concept"
# 2018-08-19 13:05:55,686 : INFO : topic #192 (0.005): 0.001*"cognitive" + 0.001*"solving" + 0.001*"communication" + 0.001*"people" + 0.001*"depth" + 0.001*"robot" + 0.001*"object" + 0.001*"vision" + 0.001*"functional" + 0.001*"person"
# 2018-08-19 13:05:55,690 : INFO : topic #19 (0.005): 0.119*"results" + 0.119*"actions" + 0.079*"sample" + 0.040*"ie" + 0.040*"analysis" + 0.040*"allows" + 0.040*"estimate" + 0.040*"combination" + 0.040*"actual" + 0.040*"stochastic"
# 2018-08-19 13:05:55,694 : INFO : topic #193 (0.005): 0.060*"agent" + 0.044*"agents" + 0.021*"level" + 0.018*"environment" + 0.018*"database" + 0.014*"strategy" + 0.013*"error" + 0.010*"step" + 0.010*"performance" + 0.010*"utility"
# 2018-08-19 13:05:55,698 : INFO : topic diff=inf, rho=0.140028

# %%
lda.print_topics(20)
# Out:
# 2018-08-19 13:05:55,732 : INFO : topic #120 (0.005): 0.038*"years" + 0.035*"year" + 0.029*"better" + 0.026*"less" + 0.024*"humans" + 0.022*"predicted" + 0.017*"performance" + 0.017*"left" + 0.016*"estimate" + 0.012*"found"
# 2018-08-19 13:05:55,768 : INFO : topic #168 (0.005): 0.037*"stock" + 0.032*"terms" + 0.029*"study" + 0.028*"financial" + 0.028*"articles" + 0.023*"news" + 0.022*"article" + 0.021*"american" + 0.021*"media" + 0.019*"days"
# 2018-08-19 13:05:55,769 : INFO : topic #76 (0.005): 0.001*"control" + 0.001*"able" + 0.001*"complexity" + 0.001*"network" + 0.001*"activation" + 0.001*"basic" + 0.001*"intervention" + 0.001*"management" + 0.001*"resources" + 0.001*"computing"
# 2018-08-19 13:05:55,771 : INFO : topic #175 (0.005): 0.001*"challenge" + 0.001*"turn" + 0.001*"answer" + 0.001*"questions" + 0.001*"computing" + 0.001*"reasoning" + 0.001*"test" + 0.001*"rules" + 0.001*"task" + 0.001*"city"
# 2018-08-19 13:05:55,773 : INFO : topic #5 (0.005): 0.001*"et" + 0.001*"al" + 0.001*"mind" + 0.001*"recognition" + 0.001*"reasoning" + 0.001*"retrieved" + 0.001*"ieee" + 0.001*"natural" + 0.001*"automated" + 0.001*"theorem"
# 2018-08-19 13:05:55,774 : INFO : topic #61 (0.005): 0.042*"goals" + 0.038*"final" + 0.032*"goal" + 0.032*"resources" + 0.019*"value" + 0.019*"values" + 0.016*"people" + 0.016*"agent" + 0.016*"function" + 0.016*"might"
# 2018-08-19 13:05:55,778 : INFO : topic #103 (0.005): 0.001*"consciousness" + 0.001*"conscious" + 0.001*"awareness" + 0.001*"attention" + 0.001*"neuron" + 0.001*"physical" + 0.001*"pp" + 0.001*"brain" + 0.001*"cognitive" + 0.001*"simulate"
# 2018-08-19 13:05:55,779 : INFO : topic #75 (0.005): 0.028*"action" + 0.020*"understanding" + 0.019*"worked" + 0.017*"nnin" + 0.017*"design" + 0.017*"neuron" + 0.017*"communication" + 0.016*"interaction" + 0.016*"per" + 0.015*"framework"
# [(120,
#   '0.038*"years" + 0.035*"year" + 0.029*"better" + 0.026*"less" + 0.024*"humans" + 0.022*"predicted" + 0.017*"performance" + 0.017*"left" + 0.016*"estimate" + 0.012*"found"'),
#  (52,
#   '0.032*"read" + 0.032*"write" + 0.020*"neural" + 0.018*"memory" + 0.017*"chess" + 0.013*"theories" + 0.011*"networks" + 0.011*"results" + 0.011*"output" + 0.010*"it"'),
#  (161,
#   '0.001*"fuzzy" + 0.001*"brain" + 0.001*"neurons" + 0.001*"neuron" + 0.001*"strong" + 0.001*"researchers" + 0.001*"potential" + 0.001*"neural" + 0.001*"action" + 0.001*"logic"'),
#  (95,
#   '0.017*"industry" + 0.017*"workshop" + 0.017*"user" + 0.017*"proceedings" + 0.015*"industrial" + 0.013*"aaai" + 0.013*"aims" + 0.013*"value" + 0.012*"national" + 0.012*"ethics"'),
#  (38,
#   '0.090*"function" + 0.090*"an" + 0.045*"computers" + 0.045*"every" + 0.045*"record" + 0.045*"maps" + 0.045*"agent" + 0.045*"act" + 0.045*"users" + 0.045*"application"'),
#  (48,
#   '0.040*"consciousness" + 0.033*"architecture" + 0.021*"nthe" + 0.018*"autonomous" + 0.015*"states" + 0.015*"july" + 0.014*"capability" + 0.014*"complete" + 0.013*"implementation" + 0.013*"june"'),
#  (159,
#   '0.043*"product" + 0.039*"pp" + 0.033*"no" + 0.028*"mass" + 0.026*"vol" + 0.025*"engineering" + 0.019*"ieee" + 0.017*"journal" + 0.017*"design" + 0.016*"management"'),
#  (29,
#   '0.046*"representation" + 0.035*"develop" + 0.030*"education" + 0.025*"future" + 0.024*"developing" + 0.020*"early" + 0.018*"strategy" + 0.016*"government" + 0.014*"office" + 0.014*"logic"'),
#  (140,
#   '0.045*"agents" + 0.041*"autonomous" + 0.037*"multiagent" + 0.024*"previous" + 0.022*"emotions" + 0.022*"main" + 0.017*"track" + 0.016*"content" + 0.015*"users" + 0.015*"industry"'),
#  (7,
#   '0.024*"cognitive" + 0.018*"concept" + 0.018*"transformation" + 0.015*"code" + 0.015*"later" + 0.014*"format" + 0.014*"domain" + 0.013*"user" + 0.012*"generation" + 0.011*"real"'),
#  (108,
#   '0.034*"described" + 0.034*"sense" + 0.025*"implemented" + 0.025*"computers" + 0.024*"algorithm" + 0.024*"analysis" + 0.022*"proceedings" + 0.018*"direction" + 0.017*"eds" + 0.017*"sentence"'),
#  (179,
#   '0.029*"study" + 0.017*"step" + 0.013*"social" + 0.013*"design" + 0.010*"degree" + 0.010*"environment" + 0.009*"analysis" + 0.009*"scientific" + 0.008*"computing" + 0.008*"activity"'),
#  (9,
#   '0.045*"behavior" + 0.031*"control" + 0.030*"return" + 0.030*"node" + 0.025*"sequence" + 0.021*"running" + 0.019*"status" + 0.017*"execution" + 0.013*"child" + 0.013*"composition"'),
#  (168,
#   '0.037*"stock" + 0.032*"terms" + 0.029*"study" + 0.028*"financial" + 0.028*"articles" + 0.023*"news" + 0.022*"article" + 0.021*"american" + 0.021*"media" + 0.019*"days"'),
#  (76,
#   '0.001*"control" + 0.001*"able" + 0.001*"complexity" + 0.001*"network" + 0.001*"activation" + 0.001*"basic" + 0.001*"intervention" + 0.001*"management" + 0.001*"resources" + 0.001*"computing"'),
#  (175,
#   '0.001*"challenge" + 0.001*"turn" + 0.001*"answer" + 0.001*"questions" + 0.001*"computing" + 0.001*"reasoning" + 0.001*"test" + 0.001*"rules" + 0.001*"task" + 0.001*"city"'),
#  (5,
#   '0.001*"et" + 0.001*"al" + 0.001*"mind" + 0.001*"recognition" + 0.001*"reasoning" + 0.001*"retrieved" + 0.001*"ieee" + 0.001*"natural" + 0.001*"automated" + 0.001*"theorem"'),
#  (61,
#   '0.042*"goals" + 0.038*"final" + 0.032*"goal" + 0.032*"resources" + 0.019*"value" + 0.019*"values" + 0.016*"people" + 0.016*"agent" + 0.016*"function" + 0.016*"might"'),
#  (103,
#   '0.001*"consciousness" + 0.001*"conscious" + 0.001*"awareness" + 0.001*"attention" + 0.001*"neuron" + 0.001*"physical" + 0.001*"pp" + 0.001*"brain" + 0.001*"cognitive" + 0.001*"simulate"'),
#  (75,
#   '0.028*"action" + 0.020*"understanding" + 0.019*"worked" + 0.017*"nnin" + 0.017*"design" + 0.017*"neuron" + 0.017*"communication" + 0.016*"interaction" + 0.016*"per" + 0.015*"framework"')]

# %% [markdown]
# ### Now let's query our datset to find related documents
#
# * Let's start by creating a get_similarity() function

# %%
def get_similarity(lda, q_vec):
    index = similarities.MatrixSimilarity(lda[corpus])
    sims = index[q_vec]
    return sims

# %% [markdown]
# * Let's manually create a subject we want to query the dataset for

# %%
query = "using deep learning for computer vision in real time"

# %% [markdown]
# * And see how our LDA model interprets this
#
# Remember, we hare passing this through the same text cleaning functionality as the documents, so punctuation, stop words, etc. will all be removed.
#
# This leaves us with the statistically important related words from our dictionary

# %%
bow = dictionary.doc2bow(content.get_cleaned_text(query).split())
words = [word for word in bow]
for word in words:
    print('{}: {}'.format(word[0], dictionary[word[0]]))
# Out:
# 243: deep
# 709: real
# 1072: vision

# %% [markdown]
# * Now let's query our LDA model based on this bag of words
#
# This will give us a vector based on our model for our query above

# %%
for i in range(5):
    print(bow)
    q_vec = lda[bow]
    print(q_vec)
    print('')
# Out:
# [(243, 1), (709, 1), (1072, 1)]
# [(10, 0.25125), (80, 0.25125), (176, 0.25125)]
#
# [(243, 1), (709, 1), (1072, 1)]
# [(10, 0.25125), (80, 0.25125), (113, 0.25125003)]
#
# [(243, 1), (709, 1), (1072, 1)]
# [(10, 0.25125), (80, 0.25125), (113, 0.25125)]
#
# [(243, 1), (709, 1), (1072, 1)]
# [(10, 0.2339462), (18, 0.2733853), (80, 0.24641854)]
#
# [(243, 1), (709, 1), (1072, 1)]
# [(10, 0.25125), (80, 0.25125), (176, 0.25125)]

# %%
print(lda.print_topic(max(q_vec, key=lambda item: item[1])[0]))
# Out:
# 0.058*"vision" + 0.041*"image" + 0.035*"depth" + 0.032*"camera" + 0.026*"images" + 0.015*"methods" + 0.012*"points" + 0.012*"point" + 0.011*"field" + 0.010*"object"

# %%
sims = get_similarity(lda, q_vec)
# Out:
# 2018-08-19 13:07:42,208 : WARNING : scanning corpus to determine the number of features (consider setting `num_features` explicitly)
# 2018-08-19 13:07:42,548 : INFO : creating matrix with 327 documents and 200 features
# /root/anaconda3/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):

# %%
sims = sorted(enumerate(sims), key=lambda item: -item[1])

# %%
for idx in [page[0] for page in sims[:10]]:
    pageid = page_ids[idx]
    print('Page ID {}: {}'.format(pageid[0], content.get_page_url_by_id(pageid)[0]))
# Out:
# Page ID 46222904: https://en.wikipedia.org/wiki/Intel_RealSense
# Page ID 52918812: https://en.wikipedia.org/wiki/NTU_RGB-D_dataset
# Page ID 6596: https://en.wikipedia.org/wiki/Computer_vision
# Page ID 34668189: https://en.wikipedia.org/wiki/3D_reconstruction_from_multiple_images
# Page ID 586357: https://en.wikipedia.org/wiki/Artificial_general_intelligence
# Page ID 2088095: https://en.wikipedia.org/wiki/IJCAI_Computers_and_Thought_Award
# Page ID 2862: https://en.wikipedia.org/wiki/AI-complete
# Page ID 1164: https://en.wikipedia.org/wiki/Artificial_intelligence
# Page ID 47336626: https://en.wikipedia.org/wiki/Oriented_energy_filters
# Page ID 195552: https://en.wikipedia.org/wiki/Artificial_consciousness
