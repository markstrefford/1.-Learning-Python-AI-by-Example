# %% [markdown]
# # LDA with Gensim

# %% [markdown]
# * Start by importing python libraries that we'll be using

# %%
# %load_ext autoreload
# %autoreload 2

import sqlite3
import string
import logging
from gensim import corpora
import nltk
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# * Let's set up some basic config

# %%
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

punctuation = set(string.punctuation)
stoplist = set(stopwords.words('english'))

stemmer = SnowballStemmer("english")
lemma = WordNetLemmatizer()

# %% [markdown]
# ### Create a class for our content

# %% [markdown]
# This class will use the database that we created when we downloaded content from Wikipedia

# %%
class ContentStore:
    def __init__(self, db_file):
        """
        Intialise the crawl_wikipedia class, set up a
        lightweight database for storing content for later use
        :param db_file:
        """
        self.categories = []
        # Connect to the DB db
        self.conn = sqlite3.connect(db_file)
        self.cursor = self.conn.cursor()

    def get_page_urls(self):
        """
        Retrieve a list of urls from the database
        :return: list of urls
        """
        return [row for row in self.cursor.execute("SELECT url FROM content")]
    
    def get_page_ids(self):
        """
        Retrieve a list of page ids from the database
        :return: list of page id tuples
        """
        return [row for row in self.cursor.execute("SELECT pageid FROM content")]   
    
    def get_page_by_id(self, pageid):
        """
        Retrieve the page with the specified pageid
        Note that this is of the format (pageid, ) for SQLite3 to work, for example
        to get the page with the id of 1 in our database, set pageid to ('1', )
        :return: string
        """
        return str(self.cursor.execute("SELECT content FROM content WHERE pageid=?", pageid).fetchone()).lower()
    
    def get_cleaned_page_by_id(self, pageid):
        page = self.get_page_by_id(pageid)
        # Remove numbers
        page = ''.join(char for char in page if not char.isdigit())
        # Remove stop words
        page = ' '.join([word for word in page.split() if word not in stoplist])
        # Remove punctuation
        page = ''.join(char for char in words if char not in punctuation)
        # Remove single character words
        page = ' '.join([word for word in page.split() if len(word) > 1])
        return page
        
    def __iter__(self):
        for page_id in get_page_ids():
            yield self.get_cleaned_page_by_id(page_id)

# %% [markdown]
# ### Remove punctuation from text

# %%
def remove_punctuation(text):
    """
    Remove punctuation from text by checking each character against a set of punctation characters
    :return: string
    """
    return ''.join(char for char in text if char not in punctuation)

# %% [markdown]
# ### Remove numbers from text

# %%
def remove_numbers(text):
    """
    Remove numbers from text as they aren't of value to our model
    :return: string
    """
    return ''.join(char for char in text if not char.isdigit())

# %% [markdown]
# ### Remove stop words from text

# %%
def remove_stop_words(text):
    """
    Remove common words as they won't add any value to our model
    :return: string
    """
    return ' '.join([word for word in text.split() if word not in stoplist])

# %% [markdown]
# ### Remove single character words

# %%
def remove_single_characters(text):
    """
    Remove any remaining single-character words
    :return: string
    """
    return ' '.join([word for word in text.split() if len(word) > 1])

# %% [markdown]
# ### Lemmatize our document

# %%
def lemmatize(text):
    return text

# %% [markdown]
# ### Stemmatize our document

# %%
def stemmatize(text):
    return text

# %% [markdown]
# ### Exploring and cleaning our content
#
# * Access our database of Wikipedia content and get a list of all of the pages IDs

# %%
content = ContentStore('../content.db')
page_ids = content.get_page_ids()

# %% [markdown]
# * Let's view a page from our database

# %%
page = content.get_page_by_id(page_ids[0])
print(page)
# Out:
# ('    \'\'\'artificial intelligence\'\'\' (\'\'\'ai\'\'\'), sometimes called \'\'\'machine intelligence\'\'\', is s, such as "learning" and "problem solving". the scope of ai is disputed: as machines become increasingly capable, tasks considered as requiring "intelligence" are often removed from the definition, a phenomenon known as the .\n\n\nartificial intelligence was founded as an academic discipline in 1956, and in the years since has experienced several waves of optimism, followed by disappointment and the loss of funding (known as an " s), or deep philosophical differences. subfields have also been based on social factors (particular institutions or the work of particular researchers).\n\nthe traditional problems (or goals) of ai research include and many others.\n\n\nthe field was founded on the claim that .\n\nin the twenty-first century, ai techniques have experienced a resurgence following concurrent advances in , helping to solve many challenging problems in computer science. == history ==  thought-capable .\n\nthe study of mechanical or "artificial neurons". the field of ai research was born at agreed, writing, "within a generation\xa0... the problem of creating \'artificial intelligence\' will substantially be solved".\n\nthey failed to recognize the difficulty of some of the remaining tasks. progress slowed and in 1974, in response to the criticism of ", a period when obtaining funding for ai projects was difficult.\n\n\nin the early 1980s, ai research was revived by the commercial success of market in 1987, ai once again fell into disrepute, and a second, longer-lasting hiatus began.\n\nin the late 1990s and early 21st century, ai began to be used for logistics, on 11 may 1997. in 2011, a \'\' , this marked the completion of a significant milestone in the development of artificial intelligence as go is an extremely complex game, more so than chess.\n\naccording to jack clark, 2015 was a landmark year for artificial intelligence, with the number of software projects that use ai within google increased from a "sporadic usage" in 2012 to more than 2,700 projects. clark also presents factual data indicating that error rates in image processing tasks have fallen significantly since 2011.{{cite web\n |url         = https://www.bloomberg.com/news/articles/2015-12-08/why-2015-was-a-breakthrough-year-in-artificial-intelligence\n |title       = why 2015 was a breakthrough year in artificial intelligence\n |last        = clark\n |first       = jack\n |website     = bloomberg news\n |date        = 8 december 2015\n |access-date = 23 november 2016\n |quote       = after a half-decade of quiet breakthroughs in artificial intelligence, 2015 has been a landmark year. computers are smarter and learning faster than ever.\n |deadurl     = no\n |archiveurl  = https://web.archive.org/web/20161123053855/https://www.bloomberg.com/news/articles/2015-12-08/why-2015-was-a-breakthrough-year-in-artificial-intelligence\n |archivedate = 23 november 2016\n |df          = dmy-all\n}} he attributes this to an increase in affordable , due to a rise in cloud computing infrastructure and to an increase in research tools and datasets. other cited examples include microsoft\'s development of a skype system that can automatically translate from one language to another and facebook\'s system that can describe images to blind people. in a 2017 survey, one in five companies reported they had "incorporated ai in some offerings or processes". == basics ==\n\n\na typical ai perceives its environment and takes actions that maximize its chance of successfully achieving its goals. an ai\'s intended to possess desired traits. such systems can still be benchmarked if the non-goal system is framed as a system whose "goal" is to successfully accomplish its narrow classification task.lindenbaum, m., markovitch, s., & rusakov, d. (2004). selective sampling for nearest neighbor classifiers. machine learning, 54(2), 125–152.\n\nai often revolves around the use of :  ...

# %% [markdown]
# * Now let's remove punctuation

# %%
page = remove_punctuation(page)
print(page)
# Out:
#     Artificial intelligence AI sometimes called machine intelligence is s such as learning and problem solving The scope of AI is disputed as machines become increasingly capable tasks considered as requiring intelligence are often removed from the definition a phenomenon known as the nnnArtificial intelligence was founded as an academic discipline in 1956 and in the years since has experienced several waves of optimism followed by disappointment and the loss of funding known as an  s or deep philosophical differences Subfields have also been based on social factors particular institutions or the work of particular researchersnnThe traditional problems or goals of AI research include and many othersnnnThe field was founded on the claim that nnIn the twentyfirst century AI techniques have experienced a resurgence following concurrent advances in  helping to solve many challenging problems in computer science  History   Thoughtcapable nnThe study of mechanical or artificial neurons The field of AI research was born at agreed writing within a generationxa0 the problem of creating artificial intelligence will substantially be solvednnThey failed to recognize the difficulty of some of the remaining tasks Progress slowed and in 1974 in response to the criticism of  a period when obtaining funding for AI projects was difficultnnnIn the early 1980s AI research was revived by the commercial success of market in 1987 AI once again fell into disrepute and a second longerlasting hiatus begannnIn the late 1990s and early 21st century AI began to be used for logistics on 11 May 1997 In 2011 a   This marked the completion of a significant milestone in the development of Artificial Intelligence as Go is an extremely complex game more so than ChessnnAccording to Jack Clark 2015 was a landmark year for artificial intelligence with the number of software projects that use AI within Google increased from a sporadic usage in 2012 to more than 2700 projects Clark also presents factual data indicating that error rates in image processing tasks have fallen significantly since 2011cite webn url          httpswwwbloombergcomnewsarticles20151208why2015wasabreakthroughyearinartificialintelligencen title        Why 2015 Was a Breakthrough Year in Artificial Intelligencen last         Clarkn first        Jackn website      Bloomberg Newsn date         8 December 2015n accessdate  23 November 2016n quote        After a halfdecade of quiet breakthroughs in artificial intelligence 2015 has been a landmark year Computers are smarter and learning faster than evern deadurl      non archiveurl   httpswebarchiveorgweb20161123053855httpswwwbloombergcomnewsarticles20151208why2015wasabreakthroughyearinartificialintelligencen archivedate  23 November 2016n df           dmyalln He attributes this to an increase in affordable  due to a rise in cloud computing infrastructure and to an increase in research tools and datasets Other cited examples include Microsofts development of a Skype system that can automatically translate from one language to another and Facebooks system that can describe images to blind people In a 2017 survey one in five companies reported they had incorporated AI in some offerings or processes  Basics nnnA typical AI perceives its environment and takes actions that maximize its chance of successfully achieving its goals An AIs intended to possess desired traits Such systems can still be benchmarked if the nongoal system is framed as a system whose goal is to successfully accomplish its narrow classification taskLindenbaum M Markovitch S  Rusakov D 2004 Selective sampling for nearest neighbor classifiers Machine learning 542 125–152nnAI often revolves around the use of   If someone has a threat that is two in a row take the remaining square Otherwisen if a move forks to create two threats at once play that move Otherwisen take the center square if it is free Otherwisen if your opponent has played in a corner take the opposite corner Otherwisen take  ...

# %% [markdown]
# * Remove numbers

# %%
page = remove_numbers(page)
print(page)
# Out:
#     Artificial intelligence AI sometimes called machine intelligence is s such as learning and problem solving The scope of AI is disputed as machines become increasingly capable tasks considered as requiring intelligence are often removed from the definition a phenomenon known as the nnnArtificial intelligence was founded as an academic discipline in  and in the years since has experienced several waves of optimism followed by disappointment and the loss of funding known as an  s or deep philosophical differences Subfields have also been based on social factors particular institutions or the work of particular researchersnnThe traditional problems or goals of AI research include and many othersnnnThe field was founded on the claim that nnIn the twentyfirst century AI techniques have experienced a resurgence following concurrent advances in  helping to solve many challenging problems in computer science  History   Thoughtcapable nnThe study of mechanical or artificial neurons The field of AI research was born at agreed writing within a generationxa the problem of creating artificial intelligence will substantially be solvednnThey failed to recognize the difficulty of some of the remaining tasks Progress slowed and in  in response to the criticism of  a period when obtaining funding for AI projects was difficultnnnIn the early s AI research was revived by the commercial success of market in  AI once again fell into disrepute and a second longerlasting hiatus begannnIn the late s and early st century AI began to be used for logistics on  May  In  a   This marked the completion of a significant milestone in the development of Artificial Intelligence as Go is an extremely complex game more so than ChessnnAccording to Jack Clark  was a landmark year for artificial intelligence with the number of software projects that use AI within Google increased from a sporadic usage in  to more than  projects Clark also presents factual data indicating that error rates in image processing tasks have fallen significantly since cite webn url          httpswwwbloombergcomnewsarticleswhywasabreakthroughyearinartificialintelligencen title        Why  Was a Breakthrough Year in Artificial Intelligencen last         Clarkn first        Jackn website      Bloomberg Newsn date          December n accessdate   November n quote        After a halfdecade of quiet breakthroughs in artificial intelligence  has been a landmark year Computers are smarter and learning faster than evern deadurl      non archiveurl   httpswebarchiveorgwebhttpswwwbloombergcomnewsarticleswhywasabreakthroughyearinartificialintelligencen archivedate   November n df           dmyalln He attributes this to an increase in affordable  due to a rise in cloud computing infrastructure and to an increase in research tools and datasets Other cited examples include Microsofts development of a Skype system that can automatically translate from one language to another and Facebooks system that can describe images to blind people In a  survey one in five companies reported they had incorporated AI in some offerings or processes  Basics nnnA typical AI perceives its environment and takes actions that maximize its chance of successfully achieving its goals An AIs intended to possess desired traits Such systems can still be benchmarked if the nongoal system is framed as a system whose goal is to successfully accomplish its narrow classification taskLindenbaum M Markovitch S  Rusakov D  Selective sampling for nearest neighbor classifiers Machine learning  –nnAI often revolves around the use of   If someone has a threat that is two in a row take the remaining square Otherwisen if a move forks to create two threats at once play that move Otherwisen take the center square if it is free Otherwisen if your opponent has played in a corner take the opposite corner Otherwisen take an empty corner if one exists Otherwisen take any empty squarennMany AI algorithms are capable of learning from data they can enh ...

# %% [markdown]
# * And stop words

# %%
page = remove_stop_words(page)
print(page)
# Out:
# Artificial intelligence AI sometimes called machine intelligence learning problem solving The scope AI disputed machines become increasingly capable tasks considered requiring intelligence often removed definition phenomenon known nnnArtificial intelligence founded academic discipline years since experienced several waves optimism followed disappointment loss funding known deep philosophical differences Subfields also based social factors particular institutions work particular researchersnnThe traditional problems goals AI research include many othersnnnThe field founded claim nnIn twentyfirst century AI techniques experienced resurgence following concurrent advances helping solve many challenging problems computer science History Thoughtcapable nnThe study mechanical artificial neurons The field AI research born agreed writing within generationxa problem creating artificial intelligence substantially solvednnThey failed recognize difficulty remaining tasks Progress slowed response criticism period obtaining funding AI projects difficultnnnIn early AI research revived commercial success market AI fell disrepute second longerlasting hiatus begannnIn late early st century AI began used logistics May In This marked completion significant milestone development Artificial Intelligence Go extremely complex game ChessnnAccording Jack Clark landmark year artificial intelligence number software projects use AI within Google increased sporadic usage projects Clark also presents factual data indicating error rates image processing tasks fallen significantly since cite webn url httpswwwbloombergcomnewsarticleswhywasabreakthroughyearinartificialintelligencen title Why Was Breakthrough Year Artificial Intelligencen last Clarkn first Jackn website Bloomberg Newsn date December n accessdate November n quote After halfdecade quiet breakthroughs artificial intelligence landmark year Computers smarter learning faster evern deadurl non archiveurl httpswebarchiveorgwebhttpswwwbloombergcomnewsarticleswhywasabreakthroughyearinartificialintelligencen archivedate November n df dmyalln He attributes increase affordable due rise cloud computing infrastructure increase research tools datasets Other cited examples include Microsofts development Skype system automatically translate one language another Facebooks system describe images blind people In survey one five companies reported incorporated AI offerings processes Basics nnnA typical AI perceives environment takes actions maximize chance successfully achieving goals An AIs intended possess desired traits Such systems still benchmarked nongoal system framed system whose goal successfully accomplish narrow classification taskLindenbaum M Markovitch S Rusakov D Selective sampling nearest neighbor classifiers Machine learning –nnAI often revolves around use If someone threat two row take remaining square Otherwisen move forks create two threats play move Otherwisen take center square free Otherwisen opponent played corner take opposite corner Otherwisen take empty corner one exists Otherwisen take empty squarennMany AI algorithms capable learning data enhance learning new avoid combinatorial explosion would ensue every possible route ponderously considered turncite journaln first P En last Hartn author Nilsson N Jauthor Raphael Bn title Correction A Formal Basis Heuristic Determination Minimum Cost Pathsn journal Newslettern issue n pages –n year n doin nnThe earliest easiest understand approach AI symbolism formal logic If otherwise healthy adult fever may learn comparing desired output altering strengths connections internal neurons reinforce connections seemed useful These four main approaches overlap evolutionary systems example neural nets learn make inferences generalize make analogies Some systems implicitly explicitly use multiple approaches alongside many AI nonAI algorithms Learning algorithms work basis strategies algorithms inferences worked well past likely continue working well future Thes ...

# %%
page = remove_single_characters(page)
print(page)
# Out:
# Artificial intelligence AI sometimes called machine intelligence learning problem solving The scope AI disputed machines become increasingly capable tasks considered requiring intelligence often removed definition phenomenon known nnnArtificial intelligence founded academic discipline years since experienced several waves optimism followed disappointment loss funding known deep philosophical differences Subfields also based social factors particular institutions work particular researchersnnThe traditional problems goals AI research include many othersnnnThe field founded claim nnIn twentyfirst century AI techniques experienced resurgence following concurrent advances helping solve many challenging problems computer science History Thoughtcapable nnThe study mechanical artificial neurons The field AI research born agreed writing within generationxa problem creating artificial intelligence substantially solvednnThey failed recognize difficulty remaining tasks Progress slowed response criticism period obtaining funding AI projects difficultnnnIn early AI research revived commercial success market AI fell disrepute second longerlasting hiatus begannnIn late early st century AI began used logistics May In This marked completion significant milestone development Artificial Intelligence Go extremely complex game ChessnnAccording Jack Clark landmark year artificial intelligence number software projects use AI within Google increased sporadic usage projects Clark also presents factual data indicating error rates image processing tasks fallen significantly since cite webn url httpswwwbloombergcomnewsarticleswhywasabreakthroughyearinartificialintelligencen title Why Was Breakthrough Year Artificial Intelligencen last Clarkn first Jackn website Bloomberg Newsn date December accessdate November quote After halfdecade quiet breakthroughs artificial intelligence landmark year Computers smarter learning faster evern deadurl non archiveurl httpswebarchiveorgwebhttpswwwbloombergcomnewsarticleswhywasabreakthroughyearinartificialintelligencen archivedate November df dmyalln He attributes increase affordable due rise cloud computing infrastructure increase research tools datasets Other cited examples include Microsofts development Skype system automatically translate one language another Facebooks system describe images blind people In survey one five companies reported incorporated AI offerings processes Basics nnnA typical AI perceives environment takes actions maximize chance successfully achieving goals An AIs intended possess desired traits Such systems still benchmarked nongoal system framed system whose goal successfully accomplish narrow classification taskLindenbaum Markovitch Rusakov Selective sampling nearest neighbor classifiers Machine learning –nnAI often revolves around use If someone threat two row take remaining square Otherwisen move forks create two threats play move Otherwisen take center square free Otherwisen opponent played corner take opposite corner Otherwisen take empty corner one exists Otherwisen take empty squarennMany AI algorithms capable learning data enhance learning new avoid combinatorial explosion would ensue every possible route ponderously considered turncite journaln first En last Hartn author Nilsson Jauthor Raphael Bn title Correction Formal Basis Heuristic Determination Minimum Cost Pathsn journal Newslettern issue pages –n year doin nnThe earliest easiest understand approach AI symbolism formal logic If otherwise healthy adult fever may learn comparing desired output altering strengths connections internal neurons reinforce connections seemed useful These four main approaches overlap evolutionary systems example neural nets learn make inferences generalize make analogies Some systems implicitly explicitly use multiple approaches alongside many AI nonAI algorithms Learning algorithms work basis strategies algorithms inferences worked well past likely continue working well future These inferences obvious s ...
