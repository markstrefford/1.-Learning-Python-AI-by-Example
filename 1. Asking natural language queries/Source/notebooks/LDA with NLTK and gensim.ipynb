# %% [markdown]
# # LDA with NLTK and Gensim

# %% [markdown]
# * Start by importing python libraries that we'll be using

# %%
# %load_ext autoreload
# %autoreload 2

import sqlite3
import string
import logging
import pickle

from gensim import corpora, utils, models, similarities
from collections import defaultdict

import nltk
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords
nltk.download('stopwords')
from nltk.corpus import wordnet
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# * Let's set up some basic config

# %%
# Set up logging for gensim
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# Punctuation and stop words to be removed later
punctuation = set(string.punctuation)
stoplist = set(stopwords.words('english'))

# For LDA training later
dictionary = corpora.Dictionary()
lemma = WordNetLemmatizer()

NUM_PASSES=10
NUM_TOPICS=100
RANDOM_STATE=1

# %% [markdown]
# ### Remove punctuation from text

# %%
def remove_punctuation(text):
    """
    Remove punctuation from text by checking each character against a set of punctation characters
    :text: string
    :return: string
    """
    return ''.join(char for char in text if char not in punctuation)

# %% [markdown]
# ### Remove numbers from text

# %%
def remove_numbers(text):
    """
    Remove numbers from text as they aren't of value to our model
    :text: string
    :return: string
    """
    return ''.join(char for char in text if not char.isdigit())

# %% [markdown]
# ### Remove stop words from text

# %%
def remove_stop_words(text):
    """
    Remove common words as they won't add any value to our model
    :text: string
    :return: string
    """
    return ' '.join([word for word in text.split() if word not in stoplist])

# %% [markdown]
# ### Remove single character words

# %%
def remove_single_characters(text):
    """
    Remove any remaining single-character words
    :text: string
    :return: string
    """
    return ' '.join([word for word in text.split() if len(word) > 1])

# %% [markdown]
# ### Lemmatize our document

# %%
def lemmatize(text):
    """
    Use NLTK lemma functionality to get the route word
    :text: string
    :return: string
    """
    return ' '.join([lemma.lemmatize(word) for word in text.split()])

# %% [markdown]
# ### Single function to clean text

# %%
def get_cleaned_text(text):
    """
    Return the page with stopwords, digits, punctuation and single character words removed
    :text: string
    :return: string
    """
    # Remove \n characters (Wikipedia has a lot of them in the page content!)
    text = text.replace('\n', '')
    # Remove numbers
    text = remove_numbers(text)
    # Remove stop words
    text = remove_stop_words(text)
    # Remove punctuation
    text = remove_punctuation(text)
    # Remove single character words
    text = remove_single_characters(text)
    # Lemmatize the document
    text = lemmatize(text)
    return text

# %% [markdown]
# ### Create a class for our content
#
# This class will use the database that we created when we downloaded content from Wikipedia

# %%
class ContentStore:
    def __init__(self, db_file):
        """
        Intialise the crawl_wikipedia class, set up a
        lightweight database for storing content for later use
        :param db_file: string
        """
        self.categories = []
        # Connect to the DB db
        self.conn = sqlite3.connect(db_file)
        self.cursor = self.conn.cursor()

    def get_page_urls(self):
        """
        Retrieve a list of urls from the database
        :return: list of urls
        """
        return [row for row in self.cursor.execute("SELECT url FROM content")]
    
    def get_page_ids(self):
        """
        Retrieve a list of page ids from the database
        :return: list of page id tuples
        """
        return [row for row in self.cursor.execute("SELECT pageid FROM content")]   
    
    def get_page_by_id(self, pageid):
        """
        Retrieve the page with the specified pageid
        Note that this is of the format (pageid, ) for SQLite3 to work, for example
        to get the page with the id of 1 in our database, set pageid to ('1', )
        :pageid: tuple ('id', )
        :return: string
        """
        return str(self.cursor.execute("SELECT content FROM content WHERE pageid=?", pageid).fetchone()).lower()
    
    def get_page_url_by_id(self, pageid):
        """
        Retrieve the page with the specified pageid
        Note that this is of the format (pageid, ) for SQLite3 to work, for example
        to get the page with the id of 1 in our database, set pageid to ('1', )
        :pageid: tuple ('id', )
        :return: string
        """
        return self.cursor.execute("SELECT url FROM content WHERE pageid=?", pageid).fetchone()
            
    def __iter__(self):
        """
        Iterator for the document set stored in the database
        This is more efficient memory wise than loading the complete document set into memory
        and therefore will scale well for larger document sets (or those not available on local disk)
        :return: tuple (string, )
        """
        for pageid in self.get_page_ids():
            page = self.get_page_by_id(pageid)
            yield get_cleaned_text(page).split()

# %% [markdown]
# ### Exploring and cleaning our content
#
# * Access our database of Wikipedia content and get a list of all of the pages IDs

# %%
content = ContentStore('../data/content.db')
page_ids = content.get_page_ids()

# %% [markdown]
# * Let's view a page from our database

# %%
page = content.get_page_by_id(page_ids[0])
print(page)
# Out:
# ('\'\'\'artificial intelligence\'\'\' (\'\'\'ai\'\'\'), sometimes called \'\'\'machine intelligence\'\'\', iss, such as "learning" and "problem solving".the scope of ai is disputed: as machines become increasingly capable, tasks considered as requiring "intelligence" are often removed from the definition, a phenomenon known as the.\n\n\nartificial intelligence was founded as an academic discipline in 1956, and in the years since has experienced several waves of optimism, followed by disappointment and the loss of funding (known as an "s), or deep philosophical differences. subfields have also been based on social factors (particular institutions or the work of particular researchers).\n\nthe traditional problems (or goals) of ai research includeand many others.\n\n\nthe field was founded on the claim that.\n\nin the twenty-first century, ai techniques have experienced a resurgence following concurrent advances in, helping to solve many challenging problems in computer science.== history ==thought-capable.\n\nthe study of mechanical or"artificial neurons".the field of ai research was born atagreed, writing, "within a generation\xa0... the problem of creating \'artificial intelligence\' will substantially be solved".\n\nthey failed to recognize the difficulty of some of the remaining tasks. progress slowed and in 1974, in response to the criticism of", a period when obtaining funding for ai projects was difficult.\n\n\nin the early 1980s, ai research was revived by the commercial success ofmarket in 1987, ai once again fell into disrepute, and a second, longer-lasting hiatus began.\n\nin the late 1990s and early 21st century, ai began to be used for logistics,on 11 may 1997.in 2011, a \'\',this marked the completion of a significant milestone in the development of artificial intelligence as go is an extremely complex game, more so than chess.\n\naccording tojack clark, 2015 was a landmark year for artificial intelligence, with the number of software projects that use ai within google increased from a "sporadic usage" in 2012 to more than 2,700 projects. clark also presents factual data indicating that error rates in image processing tasks have fallen significantly since 2011.{{cite web\n |url         = https://www.bloomberg.com/news/articles/2015-12-08/why-2015-was-a-breakthrough-year-in-artificial-intelligence\n |title       = why 2015 was a breakthrough year in artificial intelligence\n |last        = clark\n |first       = jack\n |website     = bloomberg news\n |date        = 8 december 2015\n |access-date = 23 november 2016\n |quote       = after a half-decade of quiet breakthroughs in artificial intelligence, 2015 has been a landmark year. computers are smarter and learning faster than ever.\n |deadurl     = no\n |archiveurl  = https://web.archive.org/web/20161123053855/https://www.bloomberg.com/news/articles/2015-12-08/why-2015-was-a-breakthrough-year-in-artificial-intelligence\n |archivedate = 23 november 2016\n |df          = dmy-all\n}} he attributes this to an increase in affordable, due to a rise in cloud computing infrastructure and to an increase in research tools and datasets. other cited examples include microsoft\'s development of a skype system that can automatically translate from one language to another and facebook\'s system that can describe images to blind people. in a 2017 survey, one in five companies reported they had "incorporated ai in some offerings or processes".== basics ==\n\n\na typical ai perceives its environment and takes actions that maximize its chance of successfully achieving its goals. an ai\'s intendedto possess desired traits.such systems can still be benchmarked if the non-goal system is framed as a system whose "goal" is to successfully accomplish its narrow classification task.lindenbaum, m., markovitch, s., & rusakov, d. (2004). selective sampling for nearest neighbor classifiers. machine learning, 54(2), 125–152.\n\nai often revolves around the use of:# if someone has a "threat" (th ...

# %% [markdown]
# * Now let's remove punctuation

# %%
page = page.replace('\n', '')
page = remove_punctuation(page)
print(page)
# Out:
# artificial intelligence ai sometimes called machine intelligence iss such as learning and problem solvingthe scope of ai is disputed as machines become increasingly capable tasks considered as requiring intelligence are often removed from the definition a phenomenon known as thennnartificial intelligence was founded as an academic discipline in 1956 and in the years since has experienced several waves of optimism followed by disappointment and the loss of funding known as an s or deep philosophical differences subfields have also been based on social factors particular institutions or the work of particular researchersnnthe traditional problems or goals of ai research includeand many othersnnnthe field was founded on the claim thatnnin the twentyfirst century ai techniques have experienced a resurgence following concurrent advances in helping to solve many challenging problems in computer science history thoughtcapablennthe study of mechanical orartificial neuronsthe field of ai research was born atagreed writing within a generationxa0 the problem of creating artificial intelligence will substantially be solvednnthey failed to recognize the difficulty of some of the remaining tasks progress slowed and in 1974 in response to the criticism of a period when obtaining funding for ai projects was difficultnnnin the early 1980s ai research was revived by the commercial success ofmarket in 1987 ai once again fell into disrepute and a second longerlasting hiatus begannnin the late 1990s and early 21st century ai began to be used for logisticson 11 may 1997in 2011 a this marked the completion of a significant milestone in the development of artificial intelligence as go is an extremely complex game more so than chessnnaccording tojack clark 2015 was a landmark year for artificial intelligence with the number of software projects that use ai within google increased from a sporadic usage in 2012 to more than 2700 projects clark also presents factual data indicating that error rates in image processing tasks have fallen significantly since 2011cite webn url          httpswwwbloombergcomnewsarticles20151208why2015wasabreakthroughyearinartificialintelligencen title        why 2015 was a breakthrough year in artificial intelligencen last         clarkn first        jackn website      bloomberg newsn date         8 december 2015n accessdate  23 november 2016n quote        after a halfdecade of quiet breakthroughs in artificial intelligence 2015 has been a landmark year computers are smarter and learning faster than evern deadurl      non archiveurl   httpswebarchiveorgweb20161123053855httpswwwbloombergcomnewsarticles20151208why2015wasabreakthroughyearinartificialintelligencen archivedate  23 november 2016n df           dmyalln he attributes this to an increase in affordable due to a rise in cloud computing infrastructure and to an increase in research tools and datasets other cited examples include microsofts development of a skype system that can automatically translate from one language to another and facebooks system that can describe images to blind people in a 2017 survey one in five companies reported they had incorporated ai in some offerings or processes basics nnna typical ai perceives its environment and takes actions that maximize its chance of successfully achieving its goals an ais intendedto possess desired traitssuch systems can still be benchmarked if the nongoal system is framed as a system whose goal is to successfully accomplish its narrow classification tasklindenbaum m markovitch s  rusakov d 2004 selective sampling for nearest neighbor classifiers machine learning 542 125–152nnai often revolves around the use of if someone has a threat that is two in a row take the remaining square otherwisen if a move forks to create two threats at once play that move otherwisen take the center square if it is free otherwisen if your opponent has played in a corner take the opposite corner otherwisen take an empty corner if one exists o ...

# %% [markdown]
# * Remove numbers

# %%
page = remove_numbers(page)
print(page)
# Out:
# artificial intelligence ai sometimes called machine intelligence iss such as learning and problem solvingthe scope of ai is disputed as machines become increasingly capable tasks considered as requiring intelligence are often removed from the definition a phenomenon known as thennnartificial intelligence was founded as an academic discipline in  and in the years since has experienced several waves of optimism followed by disappointment and the loss of funding known as an s or deep philosophical differences subfields have also been based on social factors particular institutions or the work of particular researchersnnthe traditional problems or goals of ai research includeand many othersnnnthe field was founded on the claim thatnnin the twentyfirst century ai techniques have experienced a resurgence following concurrent advances in helping to solve many challenging problems in computer science history thoughtcapablennthe study of mechanical orartificial neuronsthe field of ai research was born atagreed writing within a generationxa the problem of creating artificial intelligence will substantially be solvednnthey failed to recognize the difficulty of some of the remaining tasks progress slowed and in  in response to the criticism of a period when obtaining funding for ai projects was difficultnnnin the early s ai research was revived by the commercial success ofmarket in  ai once again fell into disrepute and a second longerlasting hiatus begannnin the late s and early st century ai began to be used for logisticson  may in  a this marked the completion of a significant milestone in the development of artificial intelligence as go is an extremely complex game more so than chessnnaccording tojack clark  was a landmark year for artificial intelligence with the number of software projects that use ai within google increased from a sporadic usage in  to more than  projects clark also presents factual data indicating that error rates in image processing tasks have fallen significantly since cite webn url          httpswwwbloombergcomnewsarticleswhywasabreakthroughyearinartificialintelligencen title        why  was a breakthrough year in artificial intelligencen last         clarkn first        jackn website      bloomberg newsn date          december n accessdate   november n quote        after a halfdecade of quiet breakthroughs in artificial intelligence  has been a landmark year computers are smarter and learning faster than evern deadurl      non archiveurl   httpswebarchiveorgwebhttpswwwbloombergcomnewsarticleswhywasabreakthroughyearinartificialintelligencen archivedate   november n df           dmyalln he attributes this to an increase in affordable due to a rise in cloud computing infrastructure and to an increase in research tools and datasets other cited examples include microsofts development of a skype system that can automatically translate from one language to another and facebooks system that can describe images to blind people in a  survey one in five companies reported they had incorporated ai in some offerings or processes basics nnna typical ai perceives its environment and takes actions that maximize its chance of successfully achieving its goals an ais intendedto possess desired traitssuch systems can still be benchmarked if the nongoal system is framed as a system whose goal is to successfully accomplish its narrow classification tasklindenbaum m markovitch s  rusakov d  selective sampling for nearest neighbor classifiers machine learning  –nnai often revolves around the use of if someone has a threat that is two in a row take the remaining square otherwisen if a move forks to create two threats at once play that move otherwisen take the center square if it is free otherwisen if your opponent has played in a corner take the opposite corner otherwisen take an empty corner if one exists otherwisen take any empty squarennmany ai algorithms are capable of learning from data they can enhance themselves by learning new ...

# %% [markdown]
# * And stop words

# %%
page = remove_stop_words(page)
print(page)
# Out:
# artificial intelligence ai sometimes called machine intelligence iss learning problem solvingthe scope ai disputed machines become increasingly capable tasks considered requiring intelligence often removed definition phenomenon known thennnartificial intelligence founded academic discipline years since experienced several waves optimism followed disappointment loss funding known deep philosophical differences subfields also based social factors particular institutions work particular researchersnnthe traditional problems goals ai research includeand many othersnnnthe field founded claim thatnnin twentyfirst century ai techniques experienced resurgence following concurrent advances helping solve many challenging problems computer science history thoughtcapablennthe study mechanical orartificial neuronsthe field ai research born atagreed writing within generationxa problem creating artificial intelligence substantially solvednnthey failed recognize difficulty remaining tasks progress slowed response criticism period obtaining funding ai projects difficultnnnin early ai research revived commercial success ofmarket ai fell disrepute second longerlasting hiatus begannnin late early st century ai began used logisticson may marked completion significant milestone development artificial intelligence go extremely complex game chessnnaccording tojack clark landmark year artificial intelligence number software projects use ai within google increased sporadic usage projects clark also presents factual data indicating error rates image processing tasks fallen significantly since cite webn url httpswwwbloombergcomnewsarticleswhywasabreakthroughyearinartificialintelligencen title breakthrough year artificial intelligencen last clarkn first jackn website bloomberg newsn date december n accessdate november n quote halfdecade quiet breakthroughs artificial intelligence landmark year computers smarter learning faster evern deadurl non archiveurl httpswebarchiveorgwebhttpswwwbloombergcomnewsarticleswhywasabreakthroughyearinartificialintelligencen archivedate november n df dmyalln attributes increase affordable due rise cloud computing infrastructure increase research tools datasets cited examples include microsofts development skype system automatically translate one language another facebooks system describe images blind people survey one five companies reported incorporated ai offerings processes basics nnna typical ai perceives environment takes actions maximize chance successfully achieving goals ais intendedto possess desired traitssuch systems still benchmarked nongoal system framed system whose goal successfully accomplish narrow classification tasklindenbaum markovitch rusakov selective sampling nearest neighbor classifiers machine learning –nnai often revolves around use someone threat two row take remaining square otherwisen move forks create two threats play move otherwisen take center square free otherwisen opponent played corner take opposite corner otherwisen take empty corner one exists otherwisen take empty squarennmany ai algorithms capable learning data enhance learning newcan avoid combinatorial explosion would ensue every possible route ponderously considered turncite journaln first p en last hartn author nilsson n jauthor raphael bn title correction formal basis heuristic determination minimum cost pathsn journal newslettern issue n pages –n year n doin nnthe earliest easiest understand approach ai symbolism formal logic otherwise healthy adult fever may learn comparing desired output altering strengths connections internal neurons reinforce connections seemed useful four main approaches overlap evolutionary systems example neural nets learn make inferences generalize make analogies systems implicitly explicitly use multiple approaches alongside many ai nonai algorithmslearning algorithms work basis strategies algorithms inferences worked well past likely continue working well future inferences obvious since sun rose every mo ...

# %%
page = remove_single_characters(page)
print(page)
# Out:
# artificial intelligence ai sometimes called machine intelligence iss learning problem solvingthe scope ai disputed machines become increasingly capable tasks considered requiring intelligence often removed definition phenomenon known thennnartificial intelligence founded academic discipline years since experienced several waves optimism followed disappointment loss funding known deep philosophical differences subfields also based social factors particular institutions work particular researchersnnthe traditional problems goals ai research includeand many othersnnnthe field founded claim thatnnin twentyfirst century ai techniques experienced resurgence following concurrent advances helping solve many challenging problems computer science history thoughtcapablennthe study mechanical orartificial neuronsthe field ai research born atagreed writing within generationxa problem creating artificial intelligence substantially solvednnthey failed recognize difficulty remaining tasks progress slowed response criticism period obtaining funding ai projects difficultnnnin early ai research revived commercial success ofmarket ai fell disrepute second longerlasting hiatus begannnin late early st century ai began used logisticson may marked completion significant milestone development artificial intelligence go extremely complex game chessnnaccording tojack clark landmark year artificial intelligence number software projects use ai within google increased sporadic usage projects clark also presents factual data indicating error rates image processing tasks fallen significantly since cite webn url httpswwwbloombergcomnewsarticleswhywasabreakthroughyearinartificialintelligencen title breakthrough year artificial intelligencen last clarkn first jackn website bloomberg newsn date december accessdate november quote halfdecade quiet breakthroughs artificial intelligence landmark year computers smarter learning faster evern deadurl non archiveurl httpswebarchiveorgwebhttpswwwbloombergcomnewsarticleswhywasabreakthroughyearinartificialintelligencen archivedate november df dmyalln attributes increase affordable due rise cloud computing infrastructure increase research tools datasets cited examples include microsofts development skype system automatically translate one language another facebooks system describe images blind people survey one five companies reported incorporated ai offerings processes basics nnna typical ai perceives environment takes actions maximize chance successfully achieving goals ais intendedto possess desired traitssuch systems still benchmarked nongoal system framed system whose goal successfully accomplish narrow classification tasklindenbaum markovitch rusakov selective sampling nearest neighbor classifiers machine learning –nnai often revolves around use someone threat two row take remaining square otherwisen move forks create two threats play move otherwisen take center square free otherwisen opponent played corner take opposite corner otherwisen take empty corner one exists otherwisen take empty squarennmany ai algorithms capable learning data enhance learning newcan avoid combinatorial explosion would ensue every possible route ponderously considered turncite journaln first en last hartn author nilsson jauthor raphael bn title correction formal basis heuristic determination minimum cost pathsn journal newslettern issue pages –n year doin nnthe earliest easiest understand approach ai symbolism formal logic otherwise healthy adult fever may learn comparing desired output altering strengths connections internal neurons reinforce connections seemed useful four main approaches overlap evolutionary systems example neural nets learn make inferences generalize make analogies systems implicitly explicitly use multiple approaches alongside many ai nonai algorithmslearning algorithms work basis strategies algorithms inferences worked well past likely continue working well future inferences obvious since sun rose every morning last day ...

# %% [markdown]
# ### Lemmatize the document

# %%
page = lemmatize(page)
print(page)
# Out:
# artificial intelligence ai sometimes called machine intelligence i learning problem solvingthe scope ai disputed machine become increasingly capable task considered requiring intelligence often removed definition phenomenon known thennnartificial intelligence founded academic discipline year since experienced several wave optimism followed disappointment loss funding known deep philosophical difference subfields also based social factor particular institution work particular researchersnnthe traditional problem goal ai research includeand many othersnnnthe field founded claim thatnnin twentyfirst century ai technique experienced resurgence following concurrent advance helping solve many challenging problem computer science history thoughtcapablennthe study mechanical orartificial neuronsthe field ai research born atagreed writing within generationxa problem creating artificial intelligence substantially solvednnthey failed recognize difficulty remaining task progress slowed response criticism period obtaining funding ai project difficultnnnin early ai research revived commercial success ofmarket ai fell disrepute second longerlasting hiatus begannnin late early st century ai began used logisticson may marked completion significant milestone development artificial intelligence go extremely complex game chessnnaccording tojack clark landmark year artificial intelligence number software project use ai within google increased sporadic usage project clark also present factual data indicating error rate image processing task fallen significantly since cite webn url httpswwwbloombergcomnewsarticleswhywasabreakthroughyearinartificialintelligencen title breakthrough year artificial intelligencen last clarkn first jackn website bloomberg newsn date december accessdate november quote halfdecade quiet breakthrough artificial intelligence landmark year computer smarter learning faster evern deadurl non archiveurl httpswebarchiveorgwebhttpswwwbloombergcomnewsarticleswhywasabreakthroughyearinartificialintelligencen archivedate november df dmyalln attribute increase affordable due rise cloud computing infrastructure increase research tool datasets cited example include microsofts development skype system automatically translate one language another facebooks system describe image blind people survey one five company reported incorporated ai offering process basic nnna typical ai perceives environment take action maximize chance successfully achieving goal ai intendedto posse desired traitssuch system still benchmarked nongoal system framed system whose goal successfully accomplish narrow classification tasklindenbaum markovitch rusakov selective sampling nearest neighbor classifier machine learning –nnai often revolves around use someone threat two row take remaining square otherwisen move fork create two threat play move otherwisen take center square free otherwisen opponent played corner take opposite corner otherwisen take empty corner one exists otherwisen take empty squarennmany ai algorithm capable learning data enhance learning newcan avoid combinatorial explosion would ensue every possible route ponderously considered turncite journaln first en last hartn author nilsson jauthor raphael bn title correction formal basis heuristic determination minimum cost pathsn journal newslettern issue page –n year doin nnthe earliest easiest understand approach ai symbolism formal logic otherwise healthy adult fever may learn comparing desired output altering strength connection internal neuron reinforce connection seemed useful four main approach overlap evolutionary system example neural net learn make inference generalize make analogy system implicitly explicitly use multiple approach alongside many ai nonai algorithmslearning algorithm work basis strategy algorithm inference worked well past likely continue working well future inference obvious since sun rose every morning last day probably rise tomorrow morning well nuanced many system attempt  ...

# %% [markdown]
# ### Now build a model using gensim
#
# * Start by building a dictionary of all words found in the cleaned content

# %%
dictionary = corpora.Dictionary(content)
# Out:
# 2018-08-19 15:26:18,071 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2018-08-19 15:26:36,007 : INFO : built Dictionary(132307 unique tokens: ['a', 'aaai', 'aally', 'abandoned', 'abduction']...) from 2727 documents (total 1294610 corpus positions)

# %% [markdown]
# * Ignore words that appear in less than 5 documents or more than 40% documents
#
# (These settings are configurable and can produce very different results for the same document set)

# %%
dictionary.filter_extremes(no_below=5, no_above=0.4)
# Out:
# 2018-08-19 15:26:36,167 : INFO : discarding 117937 tokens: [('aally', 1), ('accomplishn', 1), ('achievementsn', 2), ('acmnn', 2), ('actionsapply', 1), ('aerosense', 1), ('afternigor', 1), ('agar', 1), ('agentsnpublisher', 1), ('aicite', 1)]...
# 2018-08-19 15:26:36,168 : INFO : keeping 14370 tokens which were in no less than 5 and no more than 1090 (=40.0%) documents
# 2018-08-19 15:26:36,208 : INFO : resulting dictionary: Dictionary(14370 unique tokens: ['a', 'aaai', 'abandoned', 'abduction', 'ability']...)

# %% [markdown]
# * Now create a corpus

# %%
corpus = [dictionary.doc2bow(text) for text in content]

# %% [markdown]
# * Build our LDA model
#
# Note this may take a while depending on how many documents you have and how many passes you set.
# An increased number of passes improves consistency of the model at the expense of longer training times.

# %%
lda = models.LdaModel(corpus, id2word=dictionary, random_state=RANDOM_STATE, num_topics=NUM_TOPICS, passes=NUM_PASSES)
# Out:
# 2018-08-19 15:26:53,762 : INFO : using symmetric alpha at 0.01
# 2018-08-19 15:26:53,763 : INFO : using symmetric eta at 0.01
# 2018-08-19 15:26:53,766 : INFO : using serial LDA version on this node
# 2018-08-19 15:26:53,950 : INFO : running online (multi-pass) LDA training, 100 topics, 10 passes over the supplied corpus of 2727 documents, updating model once every 2000 documents, evaluating perplexity every 2727 documents, iterating 50x with a convergence threshold of 0.001000
# 2018-08-19 15:26:53,951 : INFO : PROGRESS: pass 0, at document #2000/2727
# 2018-08-19 15:26:58,020 : INFO : merging changes from 2000 documents into a model of 2727 documents
# 2018-08-19 15:26:58,201 : INFO : topic #52 (0.010): 0.007*"time" + 0.006*"model" + 0.005*"user" + 0.005*"information" + 0.004*"example" + 0.004*"action" + 0.004*"set" + 0.004*"use" + 0.003*"ontology" + 0.003*"true"
# 2018-08-19 15:26:58,203 : INFO : topic #21 (0.010): 0.007*"human" + 0.004*"model" + 0.003*"intelligence" + 0.003*"data" + 0.003*"time" + 0.003*"learning" + 0.003*"research" + 0.003*"machine" + 0.003*"set" + 0.003*"work"
# 2018-08-19 15:26:58,204 : INFO : topic #76 (0.010): 0.008*"set" + 0.007*"image" + 0.005*"model" + 0.004*"human" + 0.004*"point" + 0.004*"learning" + 0.004*"object" + 0.003*"time" + 0.003*"data" + 0.003*"algorithm"
# 2018-08-19 15:26:58,205 : INFO : topic #53 (0.010): 0.009*"model" + 0.007*"set" + 0.006*"value" + 0.005*"theory" + 0.005*"last" + 0.005*"information" + 0.004*"example" + 0.004*"concept" + 0.004*"default" + 0.004*"may"
# 2018-08-19 15:26:58,207 : INFO : topic #66 (0.010): 0.010*"–n" + 0.006*"data" + 0.005*"nn" + 0.004*"use" + 0.004*"problem" + 0.004*"time" + 0.004*"human" + 0.004*"learning" + 0.004*"set" + 0.004*"may"
# 2018-08-19 15:26:58,209 : INFO : topic diff=16.869835, rho=1.000000
# 2018-08-19 15:27:00,127 : INFO : -12.525 per-word bound, 5894.3 perplexity estimate based on a held-out corpus of 727 documents with 189680 words
# 2018-08-19 15:27:00,127 : INFO : PROGRESS: pass 0, at document #2727/2727
# /root/anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:1023: RuntimeWarning: divide by zero encountered in log
#   diff = np.log(self.expElogbeta)
# 2018-08-19 15:27:52,479 : INFO : topic #34 (0.010): 0.352*"–n" + 0.114*"cyborg" + 0.066*"nn" + 0.015*"gi" + 0.009*"tech" + 0.008*"term" + 0.007*"web" + 0.007*"aligncenter" + 0.006*"toronto" + 0.006*"artist"
# 2018-08-19 15:27:52,480 : INFO : topic #40 (0.010): 0.062*"semantic" + 0.043*"web" + 0.035*"owl" + 0.034*"rdf" + 0.025*"reasoner" + 0.018*"description" + 0.016*"dl" + 0.013*"software" + 0.013*"apache" + 0.013*"nn"
# 2018-08-19 15:27:52,481 : INFO : topic #35 (0.010): 0.019*"automated" + 0.017*"vision" + 0.015*"learning" + 0.012*"machine" + 0.010*"processing" + 0.010*"understanding" + 0.010*"visual" + 0.009*"neocortex" + 0.008*"paper" + 0.008*"theory"
# 2018-08-19 15:27:52,484 : INFO : topic diff=inf, rho=0.368517
# 2018-08-19 15:27:52,487 : INFO : PROGRESS: pass 6, at document #2000/2727
# 2018-08-19 15:28:00,086 : INFO : merging changes from 2000 documents into a model of 2727 documents
# 2018-08-19 15:28:00,298 : INFO : topic #7 (0.010): 0.020*"mind" + 0.017*"machine" + 0.015*"turing" + 0.013*"would" + 0.011*"argument" + 0.007*"human" + 0.007*"question" + 0.006*"searle" + 0.006*"symbol" + 0.006*"could"
# 2018-08-19 15:28:00,301 : INFO : topic #3 (0.010): 0.034*"link" + 0.033*"title" + 0.023*"length" + 0.021*"op" + 0.020*"journal" + 0.020*"country" + 0.019*"piano" + 0.016*"external" + 0.015*"history" + 0.015*"editor"
# 2018-08-19 15:28:00,302 : INFO : topic #16 (0.010): 0.110*"matrix" + 0.046*"bag" + 0.037*"neo" + 0.029*"bishop" + 0.019*"cd" + 0.017*"silvia" + 0.012*"morpheus" + 0.012*"like" + 0.012*"code" + 0.010*"several"
# 2018-08-19 15:28:00,304 : INFO : topic #58 (0.010): 0.024*"conference" + 0.024*"proceeding" + 0.019*"probability" + 0.018*"information" + 0.017*"vol" + 0.016*"international" + 0.014*"learning" + 0.012*"in" + 0.012*"theory" + 0.011*"science"
# 2018-08-19 15:28:00,305 : INFO : topic #30 (0.010): 0.024*"algorithm" + 0.015*"problem" + 0.013*"model" + 0.011*"function" + 0.009*"learning" + 0.009*"method" + 0.008*"solution" + 0.008*"search" + 0.007*"last" + 0.007*"set"
# 2018-08-19 15:28:00,308 : INFO : topic diff=inf, rho=0.345785
# 2018-08-19 15:28:03,125 : INFO : -8.191 per-word bound, 292.2 perplexity estimate based on a held-out corpus of 727 documents with 189680 words
# 2018-08-19 15:28:03,126 : INFO : PROGRESS: pass 6, at document #2727/2727
# 2018-08-19 15:28:05,024 : INFO : merging changes from 727 documents into a model of 2727 documents
# 2018-08-19 15:28:05,224 : INFO : topic #12 (0.010): 0.059*"question" + 0.046*"object" + 0.023*"attribute" + 0.020*"query" + 0.019*"image" + 0.013*"answer" + 0.010*"human" + 0.009*"history" + 0.009*"relationship" + 0.007*"test"
# 2018-08-19 15:28:05,226 : INFO : topic #83 (0.010): 0.013*"human" + 0.009*"would" + 0.007*"game" + 0.007*"drone" + 0.006*"time" + 0.005*"bot" + 0.005*"character" + 0.005*"test" + 0.004*"able" + 0.004*"said"
# 2018-08-19 15:28:05,228 : INFO : topic #28 (0.010): 0.102*"fuzzy" + 0.051*"set" + 0.023*"type" + 0.019*"vol" + 0.017*"ieee" + 0.014*"logic" + 0.011*"interval" + 0.010*"application" + 0.010*"ppxa–" + 0.010*"membership"
# 2018-08-19 15:28:05,230 : INFO : topic #94 (0.010): 0.083*"length" + 0.065*"title" + 0.046*"shape" + 0.021*"normal" + 0.020*"category" + 0.015*"snake" + 0.014*"gate" + 0.012*"contour" + 0.011*"feature" + 0.010*"energy"
# 2018-08-19 15:28:05,232 : INFO : topic #7 (0.010): 0.020*"mind" + 0.018*"machine" + 0.017*"turing" + 0.013*"would" + 0.011*"argument" + 0.009*"searle" + 0.007*"room" + 0.007*"human" + 0.007*"symbol" + 0.007*"question"
# 2018-08-19 15:28:05,234 : INFO : topic diff=inf, rho=0.345785
# 2018-08-19 15:28:05,238 : INFO : PROGRESS: pass 7, at document #2000/2727
# 2018-08-19 15:28:13,598 : INFO : merging changes from 2000 documents into a model of 2727 documents
# 2018-08-19 15:28:13,776 : INFO : topic #0 (0.010): 0.030*"gear" + 0.027*"metal" + 0.024*"snake" + 0.023*"solid" + 0.015*"representation" + 0.014*"quantum" + 0.012*"knowledge" + 0.010*"learning" + 0.009*"model" + 0.008*"kit"
# 2018-08-19 15:28:13,777 : INFO : topic #48 (0.010): 0.024*"award" + 0.021*"research" + 0.019*"science" + 0.016*"field" + 0.016*"infobox" + 0.015*"professor" + 0.015*"birthplace" + 0.015*"born" + 0.014*"almamater" + 0.013*"birthdate"
# 2018-08-19 15:28:13,779 : INFO : topic #67 (0.010): 0.007*"september" + 0.006*"july" + 0.006*"group" + 0.006*"december" + 0.005*"genetic" + 0.005*"time" + 0.005*"april" + 0.005*"listn" + 0.004*"th" + 0.004*"father"
# 2018-08-19 15:28:13,780 : INFO : topic #53 (0.010): 0.034*"theory" + 0.032*"default" + 0.028*"concept" + 0.027*"logic" + 0.012*"set" + 0.012*"inference" + 0.011*"model" + 0.010*"applied" + 0.010*"example" + 0.009*"similarity"
# 2018-08-19 15:28:13,784 : INFO : topic #81 (0.010): 0.067*"information" + 0.037*"search" + 0.034*"portal" + 0.030*"collaborative" + 0.029*"tag" + 0.021*"web" + 0.017*"collaboration" + 0.016*"user" + 0.013*"query" + 0.012*"tagging"
# 2018-08-19 15:28:13,788 : INFO : topic diff=inf, rho=0.326799
# 2018-08-19 15:28:16,024 : INFO : -8.147 per-word bound, 283.4 perplexity estimate based on a held-out corpus of 727 documents with 189680 words
# 2018-08-19 15:28:16,025 : INFO : PROGRESS: pass 7, at document #2727/2727
# 2018-08-19 15:28:17,544 : INFO : merging changes from 727 documents into a model of 2727 documents
# 2018-08-19 15:28:17,721 : INFO : topic #50 (0.010): 0.067*"value" + 0.034*"brainiac" + 0.027*"set" + 0.021*"superman" + 0.018*"and" + 0.016*"probability" + 0.013*"in" + 0.013*"condition" + 0.012*"world" + 0.011*"may"
# 2018-08-19 15:28:17,724 : INFO : topic #19 (0.010): 0.066*"logic" + 0.028*"tnorm" + 0.028*"truth" + 0.028*"rightarrow" + 0.020*"function" + 0.020*"fuzzy" + 0.016*"conjunction" + 0.015*"called" + 0.014*"defined" + 0.013*"value"
# 2018-08-19 15:28:17,725 : INFO : topic #34 (0.010): 0.336*"–n" + 0.121*"cyborg" + 0.081*"nn" + 0.016*"gi" + 0.009*"tech" + 0.008*"aligncenter" + 0.008*"term" + 0.008*"artist" + 0.008*"web" + 0.006*"toronto"
# 2018-08-19 15:28:17,726 : INFO : topic #56 (0.010): 0.064*"hazard" + 0.040*"ranking" + 0.032*"lecun" + 0.027*"interactivity" + 0.021*"yann" + 0.020*"safeguarding" + 0.017*"quantifying" + 0.013*"pairwise" + 0.013*"goodman" + 0.013*"participates"
# 2018-08-19 15:28:17,728 : INFO : topic #97 (0.010): 0.165*"image" + 0.039*"pixel" + 0.033*"color" + 0.017*"feature" + 0.016*"histogram" + 0.015*"region" + 0.013*"nn" + 0.013*"moment" + 0.009*"spatial" + 0.009*"method"
# 2018-08-19 15:28:17,731 : INFO : topic diff=inf, rho=0.326799
# 2018-08-19 15:28:17,734 : INFO : PROGRESS: pass 8, at document #2000/2727
# 2018-08-19 15:28:24,567 : INFO : merging changes from 2000 documents into a model of 2727 documents
# 2018-08-19 15:28:24,744 : INFO : topic #34 (0.010): 0.366*"–n" + 0.099*"nn" + 0.090*"cyborg" + 0.020*"gi" + 0.012*"aligncenter" + 0.008*"term" + 0.007*"darwin" + 0.007*"tech" + 0.007*"wen" + 0.005*"web"
# 2018-08-19 15:28:24,746 : INFO : topic #88 (0.010): 0.034*"enterprise" + 0.033*"lab" + 0.025*"software" + 0.022*"building" + 0.020*"business" + 0.016*"interoperability" + 0.013*"application" + 0.012*"architect" + 0.011*"framework" + 0.011*"knowledge"
# 2018-08-19 15:28:24,748 : INFO : topic #93 (0.010): 0.044*"neutral" + 0.040*"trust" + 0.033*"love" + 0.032*"nn" + 0.027*"enemy" + 0.026*"friendship" + 0.025*"orn" + 0.021*"rightarrow" + 0.018*"fear" + 0.017*"method"
# 2018-08-19 15:28:24,749 : INFO : topic #13 (0.010): 0.142*"decision" + 0.032*"alphago" + 0.025*"support" + 0.023*"list" + 0.021*"dialog" + 0.019*"team" + 0.017*"dm" + 0.013*"deepmind" + 0.012*"morgan" + 0.010*"match"
# 2018-08-19 15:28:24,750 : INFO : topic #54 (0.010): 0.052*"learning" + 0.048*"instance" + 0.017*"example" + 0.017*"classifier" + 0.015*"label" + 0.015*"schema" + 0.015*"automaton" + 0.014*"training" + 0.014*"machine" + 0.012*"winograd"
# 2018-08-19 15:28:24,754 : INFO : topic diff=inf, rho=0.310632
# 2018-08-19 15:28:26,938 : INFO : -8.116 per-word bound, 277.4 perplexity estimate based on a held-out corpus of 727 documents with 189680 words
# 2018-08-19 15:28:26,938 : INFO : PROGRESS: pass 8, at document #2727/2727
# 2018-08-19 15:28:28,393 : INFO : merging changes from 727 documents into a model of 2727 documents
# 2018-08-19 15:28:28,568 : INFO : topic #61 (0.010): 0.092*"ai" + 0.018*"human" + 0.015*"artificial" + 0.013*"brain" + 0.012*"would" + 0.012*"could" + 0.009*"personn" + 0.009*"experiment" + 0.008*"attempt" + 0.008*"ibm"
# 2018-08-19 15:28:28,571 : INFO : topic #36 (0.010): 0.040*"chess" + 0.021*"program" + 0.020*"university" + 0.016*"van" + 0.014*"competition" + 0.014*"game" + 0.013*"martin" + 0.012*"held" + 0.012*"david" + 0.012*"go"
# 2018-08-19 15:28:28,571 : INFO : topic #29 (0.010): 0.105*"uavs" + 0.055*"accessdate" + 0.052*"pilot" + 0.034*"storm" + 0.032*"police" + 0.030*"operator" + 0.027*"flying" + 0.025*"air" + 0.021*"december" + 0.018*"it"
# 2018-08-19 15:28:28,572 : INFO : topic #99 (0.010): 0.167*"adam" + 0.104*"guide" + 0.094*"pp" + 0.042*"demon" + 0.021*"vampire" + 0.018*"parody" + 0.017*"find" + 0.015*"dispense" + 0.015*"initiative" + 0.013*"word"
# 2018-08-19 15:28:28,574 : INFO : topic #28 (0.010): 0.108*"fuzzy" + 0.053*"set" + 0.025*"type" + 0.019*"vol" + 0.017*"ieee" + 0.013*"logic" + 0.011*"interval" + 0.011*"application" + 0.010*"membership" + 0.010*"ppxa–"
# 2018-08-19 15:28:28,576 : INFO : topic diff=inf, rho=0.310632
# 2018-08-19 15:28:28,578 : INFO : PROGRESS: pass 9, at document #2000/2727
# 2018-08-19 15:28:34,995 : INFO : merging changes from 2000 documents into a model of 2727 documents
# 2018-08-19 15:28:35,174 : INFO : topic #2 (0.010): 0.011*"research" + 0.008*"intelligence" + 0.007*"artificial" + 0.007*"technology" + 0.006*"university" + 0.006*"science" + 0.005*"project" + 0.005*"kurzweil" + 0.005*"book" + 0.004*"many"
# 2018-08-19 15:28:35,175 : INFO : topic #4 (0.010): 0.049*"ai" + 0.041*"human" + 0.030*"intelligence" + 0.017*"artificial" + 0.015*"machine" + 0.015*"would" + 0.008*"goal" + 0.008*"singularity" + 0.007*"intelligent" + 0.007*"could"
# 2018-08-19 15:28:35,176 : INFO : topic #87 (0.010): 0.058*"synth" + 0.047*"leo" + 0.040*"anita" + 0.038*"channel" + 0.036*"joe" + 0.036*"synths" + 0.035*"laura" + 0.033*"niska" + 0.033*"episode" + 0.027*"million"
# 2018-08-19 15:28:35,177 : INFO : topic #84 (0.010): 0.031*"constraint" + 0.030*"programming" + 0.024*"logic" + 0.019*"program" + 0.019*"clause" + 0.014*"goal" + 0.011*"language" + 0.010*"mccarthy" + 0.009*"prolog" + 0.009*"literal"
# 2018-08-19 15:28:35,179 : INFO : topic #91 (0.010): 0.148*"cognitive" + 0.115*"memory" + 0.101*"architecture" + 0.086*"consciousness" + 0.037*"conscious" + 0.023*"learning" + 0.022*"working" + 0.017*"agent" + 0.016*"student" + 0.013*"tutor"
# 2018-08-19 15:28:35,184 : INFO : topic diff=inf, rho=0.296650
# 2018-08-19 15:28:37,370 : INFO : -8.093 per-word bound, 273.0 perplexity estimate based on a held-out corpus of 727 documents with 189680 words
# 2018-08-19 15:28:37,370 : INFO : PROGRESS: pass 9, at document #2727/2727
# 2018-08-19 15:28:38,704 : INFO : merging changes from 727 documents into a model of 2727 documents
# 2018-08-19 15:28:38,880 : INFO : topic #47 (0.010): 0.098*"n–" + 0.035*"descriptor" + 0.026*"nwebsite" + 0.025*"good" + 0.025*"nalt" + 0.020*"element" + 0.018*"tense" + 0.017*"construct" + 0.016*"concept" + 0.016*"shape"
# 2018-08-19 15:28:38,881 : INFO : topic #56 (0.010): 0.068*"hazard" + 0.046*"ranking" + 0.031*"lecun" + 0.028*"interactivity" + 0.020*"yann" + 0.019*"safeguarding" + 0.017*"quantifying" + 0.017*"pairwise" + 0.012*"goodman" + 0.012*"concern"
# 2018-08-19 15:28:38,883 : INFO : topic #7 (0.010): 0.022*"mind" + 0.018*"machine" + 0.017*"turing" + 0.013*"would" + 0.011*"argument" + 0.009*"searle" + 0.007*"symbol" + 0.007*"room" + 0.007*"question" + 0.007*"human"
# 2018-08-19 15:28:38,884 : INFO : topic #85 (0.010): 0.090*"in" + 0.086*"evolutionary" + 0.078*"conference" + 0.075*"evolution" + 0.040*"place" + 0.039*"took" + 0.030*"ae" + 0.027*"artificial" + 0.025*"computation" + 0.024*"lncs"
# 2018-08-19 15:28:38,885 : INFO : topic #73 (0.010): 0.025*"programming" + 0.013*"application" + 0.011*"language" + 0.010*"program" + 0.010*"model" + 0.009*"software" + 0.009*"window" + 0.009*"support" + 0.009*"web" + 0.008*"microsoft"
# 2018-08-19 15:28:38,888 : INFO : topic diff=inf, rho=0.296650

# %% [markdown]
# * Let's print 10 of the topics

# %%
lda.print_topics(10)
# Out:
# 2018-08-19 15:28:38,916 : INFO : topic #4 (0.010): 0.046*"ai" + 0.041*"human" + 0.029*"intelligence" + 0.016*"artificial" + 0.016*"machine" + 0.015*"would" + 0.009*"singularity" + 0.008*"intelligent" + 0.008*"goal" + 0.007*"could"
# 2018-08-19 15:28:38,917 : INFO : topic #10 (0.010): 0.062*"robot" + 0.020*"control" + 0.019*"robotic" + 0.014*"material" + 0.012*"robotics" + 0.011*"mechanical" + 0.011*"human" + 0.009*"body" + 0.009*"designed" + 0.009*"arm"
# 2018-08-19 15:28:38,918 : INFO : topic #51 (0.010): 0.354*"user" + 0.121*"design" + 0.072*"interface" + 0.053*"usability" + 0.046*"designer" + 0.037*"task" + 0.024*"factor" + 0.022*"product" + 0.015*"visual" + 0.012*"prototype"
# 2018-08-19 15:28:38,919 : INFO : topic #66 (0.010): 0.025*"node" + 0.020*"tree" + 0.013*"variable" + 0.012*"number" + 0.012*"weight" + 0.011*"input" + 0.010*"network" + 0.009*"vector" + 0.009*"linear" + 0.008*"output"
# 2018-08-19 15:28:38,920 : INFO : topic #58 (0.010): 0.027*"conference" + 0.026*"proceeding" + 0.019*"vol" + 0.019*"international" + 0.015*"probability" + 0.015*"information" + 0.014*"in" + 0.013*"learning" + 0.013*"ieee" + 0.012*"science"
# 2018-08-19 15:28:38,922 : INFO : topic #89 (0.010): 0.049*"test" + 0.046*"turing" + 0.025*"human" + 0.024*"machine" + 0.014*"intelligence" + 0.011*"game" + 0.011*"interrogator" + 0.007*"intelligent" + 0.007*"player" + 0.006*"would"
# 2018-08-19 15:28:38,923 : INFO : topic #9 (0.010): 0.030*"action" + 0.028*"participant" + 0.016*"condition" + 0.014*"embodied" + 0.014*"cognition" + 0.014*"state" + 0.011*"word" + 0.010*"positive" + 0.009*"object" + 0.009*"block"
# 2018-08-19 15:28:38,925 : INFO : topic #25 (0.010): 0.055*"et" + 0.047*"stylewidth" + 0.046*"scopecol" + 0.030*"al" + 0.022*"ieee" + 0.019*"recognition" + 0.019*"conference" + 0.016*"international" + 0.011*"dataset" + 0.011*"feature"
# 2018-08-19 15:28:38,926 : INFO : topic #2 (0.010): 0.010*"research" + 0.008*"intelligence" + 0.007*"technology" + 0.007*"artificial" + 0.007*"kurzweil" + 0.006*"university" + 0.006*"science" + 0.005*"book" + 0.005*"project" + 0.005*"many"
# 2018-08-19 15:28:38,927 : INFO : topic #60 (0.010): 0.057*"data" + 0.039*"learning" + 0.039*"network" + 0.031*"neural" + 0.016*"machine" + 0.015*"model" + 0.012*"feature" + 0.012*"input" + 0.011*"recognition" + 0.011*"layer"
# [(4,
#   '0.046*"ai" + 0.041*"human" + 0.029*"intelligence" + 0.016*"artificial" + 0.016*"machine" + 0.015*"would" + 0.009*"singularity" + 0.008*"intelligent" + 0.008*"goal" + 0.007*"could"'),
#  (10,
#   '0.062*"robot" + 0.020*"control" + 0.019*"robotic" + 0.014*"material" + 0.012*"robotics" + 0.011*"mechanical" + 0.011*"human" + 0.009*"body" + 0.009*"designed" + 0.009*"arm"'),
#  (51,
#   '0.354*"user" + 0.121*"design" + 0.072*"interface" + 0.053*"usability" + 0.046*"designer" + 0.037*"task" + 0.024*"factor" + 0.022*"product" + 0.015*"visual" + 0.012*"prototype"'),
#  (66,
#   '0.025*"node" + 0.020*"tree" + 0.013*"variable" + 0.012*"number" + 0.012*"weight" + 0.011*"input" + 0.010*"network" + 0.009*"vector" + 0.009*"linear" + 0.008*"output"'),
#  (58,
#   '0.027*"conference" + 0.026*"proceeding" + 0.019*"vol" + 0.019*"international" + 0.015*"probability" + 0.015*"information" + 0.014*"in" + 0.013*"learning" + 0.013*"ieee" + 0.012*"science"'),
#  (89,
#   '0.049*"test" + 0.046*"turing" + 0.025*"human" + 0.024*"machine" + 0.014*"intelligence" + 0.011*"game" + 0.011*"interrogator" + 0.007*"intelligent" + 0.007*"player" + 0.006*"would"'),
#  (9,
#   '0.030*"action" + 0.028*"participant" + 0.016*"condition" + 0.014*"embodied" + 0.014*"cognition" + 0.014*"state" + 0.011*"word" + 0.010*"positive" + 0.009*"object" + 0.009*"block"'),
#  (25,
#   '0.055*"et" + 0.047*"stylewidth" + 0.046*"scopecol" + 0.030*"al" + 0.022*"ieee" + 0.019*"recognition" + 0.019*"conference" + 0.016*"international" + 0.011*"dataset" + 0.011*"feature"'),
#  (2,
#   '0.010*"research" + 0.008*"intelligence" + 0.007*"technology" + 0.007*"artificial" + 0.007*"kurzweil" + 0.006*"university" + 0.006*"science" + 0.005*"book" + 0.005*"project" + 0.005*"many"'),
#  (60,
#   '0.057*"data" + 0.039*"learning" + 0.039*"network" + 0.031*"neural" + 0.016*"machine" + 0.015*"model" + 0.012*"feature" + 0.012*"input" + 0.011*"recognition" + 0.011*"layer"')]

# %% [markdown]
# * And now let's save our model and dictionary

# %%
lda.save('../data/lda_model')
with open('../data/dictionary', "wb") as fp:
    pickle.dump(dictionary, fp)
fp.close()
# Out:
# 2018-08-19 15:28:39,101 : INFO : saving LdaState object under ../lda_model.state, separately None
# 2018-08-19 15:28:39,161 : INFO : saved ../lda_model.state
# 2018-08-19 15:28:39,177 : INFO : saving LdaModel object under ../lda_model, separately ['expElogbeta', 'sstats']
# 2018-08-19 15:28:39,178 : INFO : storing np array 'expElogbeta' to ../lda_model.expElogbeta.npy
# 2018-08-19 15:28:39,206 : INFO : not storing attribute state
# 2018-08-19 15:28:39,207 : INFO : not storing attribute dispatcher
# 2018-08-19 15:28:39,208 : INFO : not storing attribute id2word
# 2018-08-19 15:28:39,212 : INFO : saved ../lda_model

# %% [markdown]
# ### Now let's query our dataset to find related documents
#
# * Let's start by creating a get_similarity() function

# %%
def get_similarity(lda, q_vec):
    index = similarities.MatrixSimilarity(lda[corpus])
    sims = index[q_vec]
    return sims
    #return set(sims)

# %% [markdown]
# * Let's manually create a subject we want to query the dataset for

# %%
query = "using deep learning for computer vision in real time"

# %% [markdown]
# * And see how our LDA model interprets this
#
# Remember, we hare passing this through the same text cleaning functionality as the documents, so punctuation, stop words, etc. will all be removed.
#
# This leaves us with the statistically important related words from our dictionary

# %%
bow = dictionary.doc2bow(get_cleaned_text(query).split())
words = [word for word in bow]
for word in words:
    print('{}: {}'.format(word[0], dictionary[word[0]]))
# Out:
# 443: deep
# 966: learning
# 1394: real
# 1715: time
# 1797: using
# 2194: vision

# %% [markdown]
# * Now let's query our LDA model based on this bag of words
#
# This will give us a vector based on our model for our query above. Note that LDA uses some randomisation and therefore you may appear to get different vectors output here if you run this multiple times.  However, the results below are generally consistent.

# %%
q_vec = lda[bow]
print(q_vec)
# Out:
# [(44, 0.4024969), (60, 0.45750308)]

# %% [markdown]
# * Let's view the details for the LDA topic relating to the query above

# %%
print(lda.print_topic(max(q_vec, key=lambda item: item[1])[0]))
# Out:
# 0.057*"data" + 0.039*"learning" + 0.039*"network" + 0.031*"neural" + 0.016*"machine" + 0.015*"model" + 0.012*"feature" + 0.012*"input" + 0.011*"recognition" + 0.011*"layer"

# %% [markdown]
# * Now let's get the similarity of this query vector to the document vectors and sort in high-to-low order

# %%
sims = get_similarity(lda, q_vec)
sims = sorted(enumerate(sims), key=lambda item: -item[1])
# Out:
# 2018-08-19 15:29:16,572 : WARNING : scanning corpus to determine the number of features (consider setting `num_features` explicitly)
# 2018-08-19 15:29:23,458 : INFO : creating matrix with 2727 documents and 100 features
# /root/anaconda3/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):

# %% [markdown]
# * Now render the results
#
# The gensim MatrixSimilarity function used above doesn't always give unique values, hence we can't just print the top n results.  If we do, we occasionally get duplication.

# %%
idx=0
pids=[]
result = 10
while result > 0:
    pageid = page_ids[sims[idx][0]]
    if pageid not in pids:
        pids.append(pageid)
        #print(pageid)
        print('Page ID {}: {}'.format(pageid[0], content.get_page_url_by_id(pageid)[0]))
        result -= 1
    idx += 1
# Out:
# Page ID 54033657: https://en.wikipedia.org/wiki/Labeled_data
# Page ID 6838895: https://en.wikipedia.org/wiki/N-jet
# Page ID 5104401: https://en.wikipedia.org/wiki/Outline_of_computer_vision
# Page ID 1222568: https://en.wikipedia.org/wiki/Helmholtz_machine
# Page ID 2070605: https://en.wikipedia.org/wiki/Stochastic_neural_network
# Page ID 55375136: https://en.wikipedia.org/wiki/Highway_network
# Page ID 24286785: https://en.wikipedia.org/wiki/3D_data_acquisition_and_object_reconstruction
# Page ID 470314: https://en.wikipedia.org/wiki/Instantaneously_trained_neural_networks
# Page ID 50568903: https://en.wikipedia.org/wiki/Alex_Graves_(computer_scientist)
# Page ID 40409788: https://en.wikipedia.org/wiki/Convolutional_neural_network
