# %% [markdown]
# # Using Wikipedia API to get Artificial Intelligence articles

# %%
import sqlite3
import wptools
import re
from bs4 import BeautifulSoup

# %%
category = 'Category:Artificial_intelligence'
depth = 2
members = []

# %%
class crawl_wikipedia:
    def __init__(self, db_file):
        self.categories=[]
        #self.pageids=[]
        self.count=0
        # Create db
        self.conn = sqlite3.connect(db_file)
        c = self.conn.cursor()
        c.execute('''CREATE TABLE IF NOT EXISTS content
            (pageid text, url text, content text)''')
        self.conn.commit()
        self.cursor = self.conn.cursor()
     
    def save_page_content(pageid, url, content):
        self.cursor.execute("INSERT INTO content VALUES (?,?,?)",
            (pageid, url, content))
        self.conn.commit()
        
    def get_categories_and_members(self, category, depth):
        print('Checking for subcategories of {} at depth {}'.format(category, depth))
        if depth:
            cat = wptools.category(category)
            cat_members = cat.get_members()
            # First let's save any members (pages) for this category
            if 'members' in cat_members.data.keys():
                for cat_member in cat_members.data['members']:
                    # print('Appending {} to pageids'.format(cat_member['pageid']))                   
                    #self.pageids.append(cat_member['pageid'])
                    page = wptools.page(pageid=cat_member['pageid']).get_parse()
                    # Remove <ref> and other HTML syntax
                    text = BeautifulSoup(page.data['wikitext'], 'html.parser').get_text()
                    # Remove other markup such as [[...]] and {{...}}
                    clean_content = re.sub(r"\s*{.*}\s*|\s*\[.*\]\s*", " ", text)
                    # Get URL in wikipedia
                    url = page.get_query().data['url']
                    # Now store
                    self.save_page_content(pageid, url, clean_content)
            # Now iterate through any subcategories
            if 'subcategories' in cat_members.data.keys():
                subcats = cat_members.data['subcategories']               
                for subcat in subcats: 
                    self.categories.append(subcat)
                    self.count += 1
                    #print('Appending {} / count = {}'.format(subcat['title'], self.count))
                    self.get_categories_and_members(subcat['title'], depth - 1)

# %%
crawler = crawl_wikipedia()
crawler.get_categories_and_members(category, depth)
# Out:
# Checking for subcategories of Category:Artificial_intelligence at depth 2
# en.wikipedia.org (categorymembers) Category:Artificial_intelligence
# Category:Artificial intelligence (en) data
# {
#   members: <list(326)> {'pageid': 1164, 'ns': 0, 'title': 'Artific...
#   requests: <list(1)> category
#   subcategories: <list(37)> {'pageid': 46305725, 'ns': 14, 'title'...
# }
# en.wikipedia.org (categorymembers) Category:Affective computing
# Appending 1164 to pageids
# Appending 6585513 to pageids
# Appending 2142 to pageids
# Appending 23886619 to pageids
# Appending 43470933 to pageids
# Appending 34668189 to pageids
# Appending 1548772 to pageids
# Appending 25277457 to pageids
# Appending 5033373 to pageids
# Appending 11338826 to pageids
# Appending 42042198 to pageids
# Appending 14273658 to pageids
# Appending 6983799 to pageids
# Appending 142224 to pageids
# Appending 2862 to pageids
# Appending 52642349 to pageids
# Appending 43681495 to pageids
# Appending 57638150 to pageids
# Appending 402688 to pageids
# Appending 21417543 to pageids
# Appending 57812996 to pageids
# Appending 57040423 to pageids
# Appending 12379384 to pageids
# Appending 24571654 to pageids
# Appending 1126216 to pageids
# Appending 24238010 to pageids
# Appending 9025771 to pageids
# Appending 15893057 to pageids
# Appending 21577031 to pageids
# Appending 35457079 to pageids
# Appending 1908395 to pageids
# Appending 195552 to pageids
# Appending 51023476 to pageids
# Appending 586357 to pageids
# Appending 14842794 to pageids
# Appending 56127293 to pageids
# Appending 48653319 to pageids
# Appending 57024219 to pageids
# Appending 16167377 to pageids
# Appending 7872324 to pageids
# Appending 25765920 to pageids
# Appending 33529387 to pageids
# Appending 18402617 to pageids
# Appending 56072531 to pageids
# Appending 2376785 to pageids
# Appending 13911207 to pageids
# Appending 47580669 to pageids
# Appending 23423534 to pageids
# Appending 11230690 to pageids
# Appending 55843837 to pageids
# Appending 253279 to pageids
# Appending 34591537 to pageids
# Appending 2884728 to pageids
# Appending 658223 to pageids
# Appending 5389390 to pageids
# Appending 1456626 to pageids
# Appending 27759167 to pageids
# Appending 43480298 to pageids
# Appending 37291130 to pageids
# Appending 43688273 to pageids
# Appending 568967 to pageids
# Appending 57222123 to pageids
# Appending 40888645 to pageids
# Appending 50285983 to pageids
# Appending 43097038 to pageids
# Appending 3280462 to pageids
# Appending 361157 to pageids
# Appending 1355398 to pageids
# Appending 40257392 to pageids
# Appending 57318939 to pageids
# Appending 13494976 to pageids
# Appending 39182554 to pageids
# Appending 8160211 to pageids
# Appending 26032317 to pageids
# Appending 290634 to pageids
# Appending 56024845 to pageids
# Appending 43420196 to pageids
# Appending 44628427 to pageids
# Appending 52649487 to pageids
# Appending 5477824 to pageids
# Appending 39177819 to pageids
# Appending 42581062 to pageids
# Appending 30306484 to pageids
# Appending 9124629 to pageids
# Appending 2934910 to pageids
# Appending 821197 to pageids
# Appending 20756850 to pageids
# Appending 8205445 to pageids
# Appending 34600216 to pageids
# Appending 9583985 to pageids
# Appending 996026 to pageids
# Appending 15893225 to pageids
# Appending 16300571 to pageids
# Appending 44104564 to pageids
# Appending 54690679 to pageids
# Appending 14760591 to pageids
# Appending 1563306 to pageids
# Appending 39278567 to pageids
# Appending 9536113 to pageids
# Appending 6596 to pageids
# Appending 2840305 to pageids
# Appending 19835689 to pageids
# Appending 27928333 to pageids
# Appending 5421193 to pageids
# Appending 2368264 to pageids
# Appending 6417891 to pageids
# Appending 34641430 to pageids
# Appending 56900114 to pageids
# Appending 49316492 to pageids
# Appending 1124646 to pageids
# Appending 1065253 to pageids
# Appending 16934252 to pageids
# Appending 36298401 to pageids
# Appending 19317802 to pageids
# Appending 43342432 to pageids
# Appending 47332350 to pageids
# Appending 183503 to pageids
# Appending 5837233 to pageids
# Appending 37431577 to pageids
# Appending 52036598 to pageids
# Appending 253284 to pageids
# Appending 237629 to pageids
# Appending 53644736 to pageids
# Appending 34413019 to pageids
# Appending 33623429 to pageids
# Appending 48791499 to pageids
# Appending 2730882 to pageids
# Appending 6338699 to pageids
# Appending 25340765 to pageids
# Appending 44718002 to pageids
# Appending 27669989 to pageids
# Appending 43306489 to pageids
# Appending 3827197 to pageids
# Appending 25264546 to pageids
# Appending 30667214 to pageids
# Appending 10136 to pageids
# Appending 54575571 to pageids
# Appending 4832828 to pageids
# Appending 51885204 to pageids
# Appending 54683549 to pageids
# Appending 485226 to pageids
# Appending 11306 to pageids
# Appending 8703473 to pageids
# Appending 2710755 to pageids
# Appending 1028978 to pageids
# Appending 49180 to pageids
# Appending 19835615 to pageids
# Appending 11924 to pageids
# Appending 35685954 to pageids
# Appending 12142270 to pageids
# Appending 56586969 to pageids
# Appending 50336055 to pageids
# Appending 26424742 to pageids
# Appending 50672378 to pageids
# Appending 1092923 to pageids
# Appending 55443695 to pageids
# Appending 54073206 to pageids
# Appending 21342168 to pageids
# Appending 15291723 to pageids
# Appending 36831006 to pageids
# Appending 40196540 to pageids
# Appending 53322329 to pageids
# Appending 2932246 to pageids
# Appending 3907217 to pageids
# Appending 3070989 to pageids
# Appending 53639854 to pageids
# Appending 2088095 to pageids
# Appending 24241139 to pageids
# Appending 28803763 to pageids
# Appending 41644056 to pageids
# Appending 54008163 to pageids
# Appending 23997153 to pageids
# Appending 383162 to pageids
# Appending 2174928 to pageids
# Appending 43591208 to pageids
# Appending 46222904 to pageids
# Appending 2711317 to pageids
# Appending 741104 to pageids
# Appending 8514669 to pageids
# Appending 16070200 to pageids
# Appending 21428998 to pageids
# Appending 30729045 to pageids
# Appending 35456221 to pageids
# Appending 57690733 to pageids
# Appending 1499475 to pageids
# Appending 37394465 to pageids
# Appending 23048428 to pageids
# Appending 17188 to pageids
# Appending 43249770 to pageids
# Appending 41555934 to pageids
# Appending 18313661 to pageids
# Appending 610757 to pageids
# Appending 28443302 to pageids
# Appending 43274058 to pageids
# Appending 1377612 to pageids
# Appending 39903059 to pageids
# Appending 23762260 to pageids
# Appending 5349640 to pageids
# Appending 56391079 to pageids
# Appending 54329238 to pageids
# Appending 7539196 to pageids
# Appending 37447771 to pageids
# Appending 48718351 to pageids
# Appending 24870679 to pageids
# Appending 57265177 to pageids
# Appending 49082762 to pageids
# Appending 238725 to pageids
# Appending 45567903 to pageids
# Appending 53587467 to pageids
# Appending 11920671 to pageids
# Appending 37044578 to pageids
# Appending 41780237 to pageids
# Appending 34053961 to pageids
# Appending 44195492 to pageids
# Appending 6278094 to pageids
# Appending 49294877 to pageids
# Appending 39242563 to pageids
# Appending 11081176 to pageids
# Appending 419463 to pageids
# Appending 51291103 to pageids
# Appending 40267442 to pageids
# Appending 2708995 to pageids
# Appending 53210461 to pageids
# Appending 12476035 to pageids
# Appending 33527843 to pageids
# Appending 55690224 to pageids
# Appending 31068176 to pageids
# Appending 21659435 to pageids
# Appending 50231947 to pageids
# Appending 57653528 to pageids
# Appending 21652 to pageids
# Appending 98778 to pageids
# Appending 33818014 to pageids
# Appending 56643213 to pageids
# Appending 3630374 to pageids
# Appending 19208664 to pageids
# Appending 2715076 to pageids
# Appending 12994741 to pageids
# Appending 55567666 to pageids
# Appending 32856741 to pageids
# Appending 11298926 to pageids
# Appending 52918812 to pageids
# Appending 20400528 to pageids
# Appending 11053817 to pageids
# Appending 53673334 to pageids
# Appending 46504825 to pageids
# Appending 55507995 to pageids
# Appending 7879921 to pageids
# Appending 22837841 to pageids
# Appending 17953841 to pageids
# Appending 56748872 to pageids
# Appending 14893994 to pageids
# Appending 47336626 to pageids
# Appending 3709680 to pageids
# Appending 57030262 to pageids
# Appending 37339876 to pageids
# Appending 24251211 to pageids
# Appending 25733398 to pageids
# Appending 56982762 to pageids
# Appending 11848927 to pageids
# Appending 30405742 to pageids
# Appending 43723774 to pageids
# Appending 562827 to pageids
# Appending 637434 to pageids
# Appending 19890479 to pageids
# Appending 1467948 to pageids
# Appending 16598232 to pageids
# Appending 57719367 to pageids
# Appending 14659967 to pageids
# Appending 19442735 to pageids
# Appending 41732818 to pageids
# Appending 19614447 to pageids
# Appending 1187268 to pageids
# Appending 31103500 to pageids
# Appending 1706303 to pageids
# Appending 43705185 to pageids
# Appending 54625345 to pageids
# Appending 48760514 to pageids
# Appending 50562089 to pageids
# Appending 3291080 to pageids
# Appending 19768799 to pageids
# Appending 35713574 to pageids
# Appending 51295111 to pageids
# Appending 46803936 to pageids
# Appending 8271663 to pageids
# Appending 57468086 to pageids
# Appending 657145 to pageids
# Appending 35494317 to pageids
# Appending 25011536 to pageids
# Appending 36347200 to pageids
# Appending 27370978 to pageids
# Appending 3479720 to pageids
# Appending 16794474 to pageids
# Appending 6216524 to pageids
# Appending 201158 to pageids
# Appending 430106 to pageids
# Appending 7347241 to pageids
# Appending 26269089 to pageids
# Appending 4678739 to pageids
# Appending 43658678 to pageids
# Appending 40647601 to pageids
# Appending 637857 to pageids
# Appending 339417 to pageids
# Appending 12018606 to pageids
# Appending 34130293 to pageids
# Appending 57316019 to pageids
# Appending 49138450 to pageids
# Appending 33591382 to pageids
# Appending 21171254 to pageids
# Appending 55725939 to pageids
# Appending 430976 to pageids
# Appending 47228422 to pageids
# Appending 866256 to pageids
# Appending 49239240 to pageids
# Appending 42349326 to pageids
# Appending 47018111 to pageids
# Appending 27726566 to pageids
# Appending 40615979 to pageids
# Appending 1648132 to pageids
# Appending 22113059 to pageids
# Appending 23402053 to pageids
# Appending 41255201 to pageids
# Appending 44391058 to pageids
# Appending 52968552 to pageids
# Appending 51237053 to pageids
# Appending 9460224 to pageids
# Appending Category:Affective computing / count = 1
# Checking for subcategories of Category:Affective computing at depth 1
# Category:Affective computing (en) data
# {
#   members: <list(8)> {'pageid': 233942, 'ns': 0, 'title': 'Affecti...
#   requests: <list(1)> category
#   subcategories: <list(1)> {'pageid': 31996622, 'ns': 14, 'title':...
# }
# en.wikipedia.org (categorymembers) Category:AI accelerators
# Appending 233942 to pageids
# Appending 38411570 to pageids
# Appending 51023476 to pageids
# Appending 14199008 to pageids
# Appending 57687371 to pageids
# Appending 56649828 to pageids
# Appending 6435232 to pageids
# Appending 53571766 to pageids
# Appending Category:Social robots / count = 2
# Checking for subcategories of Category:Social robots at depth 0
# Appending Category:AI accelerators / count = 3
# Checking for subcategories of Category:AI accelerators at depth 1
# Category:AI accelerators (en) data
# {
#   members: <list(10)> {'pageid': 50827978, 'ns': 0, 'title': 'AI a...
#   requests: <list(1)> category
# }
# en.wikipedia.org (categorymembers) Category:Artificial intelligen...
# Appending 50827978 to pageids
# Appending 453086 to pageids
# Appending 49982604 to pageids
# Appending 50362874 to pageids
# Appending 50858569 to pageids
# Appending 35891416 to pageids
# Appending 50673241 to pageids
# Appending 44297493 to pageids
# Appending 50228744 to pageids
# Appending 45639654 to pageids
# Appending Category:Artificial intelligence applications / count = 4
# Checking for subcategories of Category:Artificial intelligence applications at depth 1
# Category:Artificial intelligence applications (en) data
# {
#   members: <list(102)> {'pageid': 15893057, 'ns': 0, 'title': 'App...
#   requests: <list(1)> category
#   subcategories: <list(15)> {'pageid': 21145129, 'ns': 14, 'title'...
# }
# en.wikipedia.org (categorymembers) Category:Artificial immune systems
# Appending 15893057 to pageids
# Appending 2142 to pageids
# Appending 49238421 to pageids
# Appending 15795950 to pageids
# Appending 25910473 to pageids
# Appending 52642349 to pageids
# Appending 28139201 to pageids
# Appending 49242352 to pageids
# Appending 55572262 to pageids
# Appending 55981499 to pageids
# Appending 14842794 to pageids
# Appending 13234913 to pageids
# Appending 33529387 to pageids
# Appending 40218456 to pageids
# Appending 51404222 to pageids
# Appending 53070037 to pageids
# Appending 1931185 to pageids
# Appending 1657551 to pageids
# Appending 45396428 to pageids
# Appending 54249476 to pageids
# Appending 45001424 to pageids
# Appending 8006328 to pageids
# Appending 28650287 to pageids
# Appending 2368154 to pageids
# Appending 52649487 to pageids
# Appending 6898858 to pageids
# Appending 743971 to pageids
# Appending 18629502 to pageids
# Appending 16021556 to pageids
# Appending 23392007 to pageids
# Appending 1191600 to pageids
# Appending 2090992 to pageids
# Appending 4903304 to pageids
# Appending 52345508 to pageids
# Appending 48198256 to pageids
# Appending 2961998 to pageids
# Appending 34340886 to pageids
# Appending 28539183 to pageids
# Appending 463838 to pageids
# Appending 20638403 to pageids
# Appending 22717006 to pageids
# Appending 18015568 to pageids
# Appending 52840911 to pageids
# Appending 53207980 to pageids
# Appending 19089876 to pageids
# Appending 203619 to pageids
# Appending 52588198 to pageids
# Appending 22419840 to pageids
# Appending 3666033 to pageids
# Appending 34937796 to pageids
# Appending 36987204 to pageids
# Appending 56596980 to pageids
# Appending 23762260 to pageids
# Appending 8642422 to pageids
# Appending 19980 to pageids
# Appending 8642531 to pageids
# Appending 35591037 to pageids
# Appending 15874732 to pageids
# Appending 30285715 to pageids
# Appending 57388949 to pageids
# Appending 20405957 to pageids
# Appending 38143080 to pageids
# Appending 5559076 to pageids
# Appending 33527843 to pageids
# Appending 56195203 to pageids
# Appending 18863997 to pageids
# Appending 5410176 to pageids
# Appending 47961606 to pageids
# Appending 3712924 to pageids
# Appending 52202762 to pageids
# Appending 6026708 to pageids
# Appending 42129549 to pageids
# Appending 4960888 to pageids
# Appending 40031725 to pageids
# Appending 49091 to pageids
# Appending 439697 to pageids
# Appending 2539154 to pageids
# Appending 2760602 to pageids
# Appending 19852067 to pageids
# Appending 41732818 to pageids
# Appending 14477647 to pageids
# Appending 360030 to pageids
# Appending 52404701 to pageids
# Appending 29069615 to pageids
# Appending 8168237 to pageids
# Appending 44374849 to pageids
# Appending 1741558 to pageids
# Appending 26603942 to pageids
# Appending 38350839 to pageids
# Appending 8227051 to pageids
# Appending 23951451 to pageids
# Appending 13111724 to pageids
# Appending 42799 to pageids
# Appending 7271261 to pageids
# Appending 50779447 to pageids
# Appending 318439 to pageids
# Appending 6006314 to pageids
# Appending 8252994 to pageids
# Appending 6773335 to pageids
# Appending 24175540 to pageids
# Appending 33233256 to pageids
# Appending 18849138 to pageids
# Appending Category:Agent-based software / count = 5
# Checking for subcategories of Category:Agent-based software at depth 0
# Appending Category:Applied data mining / count = 6
# Checking for subcategories of Category:Applied data mining at depth 0
# Appending Category:Applied machine learning / count = 7
# Checking for subcategories of Category:Applied machine learning at depth 0
# Appending Category:Automated planning and scheduling / count = 8
# Checking for subcategories of Category:Automated planning and scheduling at depth 0
# Appending Category:Computer vision software / count = 9
# Checking for subcategories of Category:Computer vision software at depth 0
# Appending Category:Expert systems / count = 10
# Checking for subcategories of Category:Expert systems at depth 0
# Appending Category:Face recognition / count = 11
# Checking for subcategories of Category:Face recognition at depth 0
# Appending Category:Free artificial intelligence applications / count = 12
# Checking for subcategories of Category:Free artificial intelligence applications at depth 0
# Appending Category:Handwriting recognition / count = 13
# Checking for subcategories of Category:Handwriting recognition at depth 0
# Appending Category:Natural language processing / count = 14
# Checking for subcategories of Category:Natural language processing at depth 0
# Appending Category:Natural language processing software / count = 15
# Checking for subcategories of Category:Natural language processing software at depth 0
# Appending Category:Neural network software / count = 16
# Checking for subcategories of Category:Neural network software at depth 0
# Appending Category:Optical character recognition / count = 17
# Checking for subcategories of Category:Optical character recognition at depth 0
# Appending Category:Speech recognition / count = 18
# Checking for subcategories of Category:Speech recognition at depth 0
# Appending Category:Voice technology / count = 19
# Checking for subcategories of Category:Voice technology at depth 0
# Appending Category:Artificial immune systems / count = 20
# Checking for subcategories of Category:Artificial immune systems at depth 1
# Category:Artificial immune systems (en) data
# {
#   members: <list(4)> {'pageid': 1589987, 'ns': 0, 'title': 'Artifi...
#   requests: <list(1)> category
# }
# en.wikipedia.org (categorymembers) Category:Artificial intelligen...
# Appending 1589987 to pageids
# Appending 20434643 to pageids
# Appending 12468879 to pageids
# Appending 25532348 to pageids
# Appending Category:Artificial intelligence associations / count = 21
# Checking for subcategories of Category:Artificial intelligence associations at depth 1
# Category:Artificial intelligence associations (en) data
# {
#   members: <list(16)> {'pageid': 35782731, 'ns': 0, 'title': 'Alle...
#   requests: <list(1)> category
#   subcategories: <list(1)> {'pageid': 38733908, 'ns': 14, 'title':...
# }
# en.wikipedia.org (categorymembers) Category:Automated reasoning
# Appending 35782731 to pageids
# Appending 3558615 to pageids
# Appending 13234913 to pageids
# Appending 534794 to pageids
# Appending 49803819 to pageids
# Appending 7101688 to pageids
# Appending 19172663 to pageids
# Appending 42912557 to pageids
# Appending 30292113 to pageids
# Appending 56382262 to pageids
# Appending 38857256 to pageids
# Appending 44299306 to pageids
# Appending 732167 to pageids
# Appending 48795986 to pageids
# Appending 51792164 to pageids
# Appending 9855223 to pageids
# Appending Category:Association for the Advancement of Artificial Intelligence / count = 22
# Checking for subcategories of Category:Association for the Advancement of Artificial Intelligence at depth 0
# Appending Category:Automated reasoning / count = 23
# Checking for subcategories of Category:Automated reasoning at depth 1
# Category:Automated reasoning (en) data
# {
#   members: <list(10)> {'pageid': 3446141, 'ns': 0, 'title': 'Assoc...
#   requests: <list(1)> category
#   subcategories: <list(1)> {'pageid': 8387931, 'ns': 14, 'title': ...
# }
# en.wikipedia.org (categorymembers) Category:Chatterbots
# Appending 3446141 to pageids
# Appending 2884728 to pageids
# Appending 568967 to pageids
# Appending 996026 to pageids
# Appending 8402579 to pageids
# Appending 16920 to pageids
# Appending 2708995 to pageids
# Appending 26313930 to pageids
# Appending 31103500 to pageids
# Appending 13536810 to pageids
# Appending Category:Automated theorem proving / count = 24
# Checking for subcategories of Category:Automated theorem proving at depth 0
# Appending Category:Chatterbots / count = 25
# Checking for subcategories of Category:Chatterbots at depth 1
# Category:Chatterbots (en) data
# {
#   members: <list(38)> {'pageid': 148349, 'ns': 0, 'title': 'Chatbo...
#   requests: <list(1)> category
# }
# en.wikipedia.org (categorymembers) Category:Cloud robotics
# Appending 148349 to pageids
# Appending 1705011 to pageids
# Appending 3075657 to pageids
# Appending 26032317 to pageids
# Appending 28650287 to pageids
# Appending 2090992 to pageids
# Appending 10235 to pageids
# Appending 19902679 to pageids
# Appending 51171662 to pageids
# Appending 8703473 to pageids
# Appending 33026100 to pageids
# Appending 25455946 to pageids
# Appending 22202872 to pageids
# Appending 705605 to pageids
# Appending 21826200 to pageids
# Appending 8703613 to pageids
# Appending 238725 to pageids
# Appending 174091 to pageids
# Appending 4478746 to pageids
# Appending 41246558 to pageids
# Appending 43021739 to pageids
# Appending 52202762 to pageids
# Appending 48723464 to pageids
# Appending 405447 to pageids
# Appending 453427 to pageids
# Appending 56428662 to pageids
# Appending 34882875 to pageids
# Appending 946226 to pageids
# Appending 57210608 to pageids
# Appending 2809681 to pageids
# Appending 42722041 to pageids
# Appending 49933350 to pageids
# Appending 30131890 to pageids
# Appending 6773335 to pageids
# Appending 19024298 to pageids
# Appending 6383171 to pageids
# Appending 47861066 to pageids
# Appending 53277123 to pageids
# Appending Category:Cloud robotics / count = 26
# Checking for subcategories of Category:Cloud robotics at depth 1
# Category:Cloud robotics (en) data
# {
#   members: <list(4)> {'pageid': 44628427, 'ns': 0, 'title': 'Cloud...
#   requests: <list(1)> category
# }
# en.wikipedia.org (categorymembers) Category:Cognitive architecture
# Appending 44628427 to pageids
# Appending 34643983 to pageids
# Appending 38776364 to pageids
# Appending 38782554 to pageids
# Appending Category:Cognitive architecture / count = 27
# Checking for subcategories of Category:Cognitive architecture at depth 1
# Category:Cognitive architecture (en) data
# {
#   members: <list(34)> {'pageid': 1700176, 'ns': 0, 'title': 'Cogni...
#   requests: <list(1)> category
# }
# en.wikipedia.org (categorymembers) Category:Computer vision
# Appending 1700176 to pageids
# Appending 23882349 to pageids
# Appending 821071 to pageids
# Appending 6456832 to pageids
# Appending 12632281 to pageids
# Appending 13550938 to pageids
# Appending 13030638 to pageids
# Appending 25256781 to pageids
# Appending 1757239 to pageids
# Appending 6874 to pageids
# Appending 36298401 to pageids
# Appending 33548913 to pageids
# Appending 3559731 to pageids
# Appending 12838512 to pageids
# Appending 31462536 to pageids
# Appending 1847118 to pageids
# Appending 24870679 to pageids
# Appending 41780237 to pageids
# Appending 22912887 to pageids
# Appending 57720057 to pageids
# Appending 446606 to pageids
# Appending 2311118 to pageids
# Appending 8233911 to pageids
# Appending 15311631 to pageids
# Appending 7827235 to pageids
# Appending 31103500 to pageids
# Appending 32043571 to pageids
# Appending 6216524 to pageids
# Appending 729751 to pageids
# Appending 23572558 to pageids
# Appending 33547203 to pageids
# Appending 50568976 to pageids
# Appending 83552 to pageids
# Appending 14241792 to pageids
# Appending Category:Computer vision / count = 28
# Checking for subcategories of Category:Computer vision at depth 1
# Category:Computer vision (en) data
# {
#   members: <list(89)> {'pageid': 6596, 'ns': 0, 'title': 'Computer...
#   requests: <list(1)> category
#   subcategories: <list(21)> {'pageid': 2700744, 'ns': 14, 'title':...
# }
# en.wikipedia.org (categorymembers) Category:Artificial intelligen...
# Appending 6596 to pageids
# Appending 5104401 to pageids
# Appending 44534652 to pageids
# Appending 53065847 to pageids
# Appending 24286785 to pageids
# Appending 25860534 to pageids
# Appending 34668189 to pageids
# Appending 56084743 to pageids
# Appending 5717580 to pageids
# Appending 12555662 to pageids
# Appending 2288302 to pageids
# Appending 15375961 to pageids
# Appending 289860 to pageids
# Appending 13274389 to pageids
# Appending 27395982 to pageids
# Appending 38561540 to pageids
# Appending 9170159 to pageids
# Appending 16741381 to pageids
# Appending 230834 to pageids
# Appending 474813 to pageids
# Appending 35026656 to pageids
# Appending 1571780 to pageids
# Appending 7174467 to pageids
# Appending 34641430 to pageids
# Appending 40409788 to pageids
# Appending 33512934 to pageids
# Appending 39922027 to pageids
# Appending 10019306 to pageids
# Appending 97922 to pageids
# Appending 34413019 to pageids
# Appending 51396023 to pageids
# Appending 56249073 to pageids
# Appending 348692 to pageids
# Appending 33270868 to pageids
# Appending 47319644 to pageids
# Appending 48661480 to pageids
# Appending 54397496 to pageids
# Appending 474939 to pageids
# Appending 4163064 to pageids
# Appending 10531718 to pageids
# Appending 48411649 to pageids
# Appending 346382 to pageids
# Appending 33870490 to pageids
# Appending 10416897 to pageids
# Appending 2132859 to pageids
# Appending 155555 to pageids
# Appending 28803763 to pageids
# Appending 12989981 to pageids
# Appending 21610688 to pageids
# Appending 8755061 to pageids
# Appending 37412518 to pageids
# Appending 44632031 to pageids
# Appending 172088 to pageids
# Appending 10999922 to pageids
# Appending 5491440 to pageids
# Appending 6838895 to pageids
# Appending 7095986 to pageids
# Appending 44390264 to pageids
# Appending 2997502 to pageids
# Appending 39799223 to pageids
# Appending 13038078 to pageids
# Appending 1290557 to pageids
# Appending 22714727 to pageids
# Appending 19132709 to pageids
# Appending 12265304 to pageids
# Appending 40374554 to pageids
# Appending 3145356 to pageids
# Appending 15966023 to pageids
# Appending 27169328 to pageids
# Appending 4081616 to pageids
# Appending 48715673 to pageids
# Appending 1703661 to pageids
# Appending 5477059 to pageids
# Appending 5481404 to pageids
# Appending 54655906 to pageids
# Appending 15281107 to pageids
# Appending 8707155 to pageids
# Appending 8210422 to pageids
# Appending 16373249 to pageids
# Appending 42003835 to pageids
# Appending 54637700 to pageids
# Appending 33512861 to pageids
# Appending 40671192 to pageids
# Appending 44722153 to pageids
# Appending 26592482 to pageids
# Appending 40914533 to pageids
# Appending 14669989 to pageids
# Appending 11591518 to pageids
# Appending 16928506 to pageids
# Appending Category:3D imaging / count = 29
# Checking for subcategories of Category:3D imaging at depth 0
# Appending Category:Applications of computer vision / count = 30
# Checking for subcategories of Category:Applications of computer vision at depth 0
# Appending Category:Commercial computer vision systems / count = 31
# Checking for subcategories of Category:Commercial computer vision systems at depth 0
# Appending Category:Computer vision research infrastructure / count = 32
# Checking for subcategories of Category:Computer vision research infrastructure at depth 0
# Appending Category:Datasets in computer vision / count = 33
# Checking for subcategories of Category:Datasets in computer vision at depth 0
# Appending Category:Digital geometry / count = 34
# Checking for subcategories of Category:Digital geometry at depth 0
# Appending Category:Feature detection (computer vision) / count = 35
# Checking for subcategories of Category:Feature detection (computer vision) at depth 0
# Appending Category:Geometry in computer vision / count = 36
# Checking for subcategories of Category:Geometry in computer vision at depth 0
# Appending Category:Geometry processing / count = 37
# Checking for subcategories of Category:Geometry processing at depth 0
# Appending Category:Image noise reduction techniques / count = 38
# Checking for subcategories of Category:Image noise reduction techniques at depth 0
# Appending Category:Image processing / count = 39
# Checking for subcategories of Category:Image processing at depth 0
# Appending Category:Image segmentation / count = 40
# Checking for subcategories of Category:Image segmentation at depth 0
# Appending Category:Image sensor technology in computer vision / count = 41
# Checking for subcategories of Category:Image sensor technology in computer vision at depth 0
# Appending Category:Learning in computer vision / count = 42
# Checking for subcategories of Category:Learning in computer vision at depth 0
# Appending Category:Machine vision / count = 43
# Checking for subcategories of Category:Machine vision at depth 0
# Appending Category:Mathematical morphology / count = 44
# Checking for subcategories of Category:Mathematical morphology at depth 0
# Appending Category:Motion in computer vision / count = 45
# Checking for subcategories of Category:Motion in computer vision at depth 0
# Appending Category:Object recognition and categorization / count = 46
# Checking for subcategories of Category:Object recognition and categorization at depth 0
# Appending Category:Photogrammetry / count = 47
# Checking for subcategories of Category:Photogrammetry at depth 0
# Appending Category:Computer vision researchers / count = 48
# Checking for subcategories of Category:Computer vision researchers at depth 0
# Appending Category:Computer vision software / count = 49
# Checking for subcategories of Category:Computer vision software at depth 0
# Appending Category:Artificial intelligence conferences / count = 50
# Checking for subcategories of Category:Artificial intelligence conferences at depth 1
# Category:Artificial intelligence conferences (en) data
# {
#   members: <list(18)> {'pageid': 24714635, 'ns': 0, 'title': 'AAAI...
#   requests: <list(1)> category
# }
# en.wikipedia.org (categorymembers) Category:Signal processing con...
# Appending 24714635 to pageids
# Appending 57562297 to pageids
# Appending 27562454 to pageids
# Appending 57094780 to pageids
# Appending 38629606 to pageids
# Appending 22663171 to pageids
# Appending 1175156 to pageids
# Appending 1124646 to pageids
# Appending 19834151 to pageids
# Appending 3358541 to pageids
# Appending 56416028 to pageids
# Appending 18586449 to pageids
# Appending 56417628 to pageids
# Appending 2614944 to pageids
# Appending 39758073 to pageids
# Appending 30401716 to pageids
# Appending 36494971 to pageids
# Appending 27898066 to pageids
# Appending Category:Signal processing conferences / count = 51
# Checking for subcategories of Category:Signal processing conferences at depth 1
# Category:Signal processing conferences (en) data
# {
#   members: <list(4)> {'pageid': 24073428, 'ns': 0, 'title': 'Confe...
#   requests: <list(1)> category
# }
# en.wikipedia.org (categorymembers) Category:Evolutionary computation
# Appending 24073428 to pageids
# Appending 1175156 to pageids
# Appending 22318852 to pageids
# Appending 23376109 to pageids
# Appending Category:Evolutionary computation / count = 52
# Checking for subcategories of Category:Evolutionary computation at depth 1
# Category:Evolutionary computation (en) data
# {
#   members: <list(25)> {'pageid': 268020, 'ns': 0, 'title': 'Evolut...
#   requests: <list(1)> category
#   subcategories: <list(4)> {'pageid': 811694, 'ns': 14, 'title': '...
# }
# en.wikipedia.org (categorymembers) Category:Artificial Intelligen...
# Appending 268020 to pageids
# Appending 25839999 to pageids
# Appending 44636079 to pageids
# Appending 1514142 to pageids
# Appending 26536158 to pageids
# Appending 39447416 to pageids
# Appending 418075 to pageids
# Appending 3062637 to pageids
# Appending 15702071 to pageids
# Appending 30035652 to pageids
# Appending 1050195 to pageids
# Appending 1098818 to pageids
# Appending 49305019 to pageids
# Appending 5751182 to pageids
# Appending 21573718 to pageids
# Appending 4483084 to pageids
# Appending 901162 to pageids
# Appending 12836631 to pageids
# Appending 6548718 to pageids
# Appending 1514566 to pageids
# Appending 34542671 to pageids
# Appending 344922 to pageids
# Appending 1346015 to pageids
# Appending 25056220 to pageids
# Appending 36089423 to pageids
# Appending Category:Artificial life / count = 53
# Checking for subcategories of Category:Artificial life at depth 0
# Appending Category:Digital organisms / count = 54
# Checking for subcategories of Category:Digital organisms at depth 0
# Appending Category:Evolutionary algorithms / count = 55
# Checking for subcategories of Category:Evolutionary algorithms at depth 0
# Appending Category:Interactive evolutionary computation / count = 56
# Checking for subcategories of Category:Interactive evolutionary computation at depth 0
# Appending Category:Artificial Intelligence existential risk / count = 57
# Checking for subcategories of Category:Artificial Intelligence existential risk at depth 1
# Category:Artificial Intelligence existential risk (en) data
# {
#   members: <list(18)> {'pageid': 31641770, 'ns': 0, 'title': 'AI b...
#   requests: <list(1)> category
# }
# en.wikipedia.org (categorymembers) Category:Artificial intelligen...
# Appending 31641770 to pageids
# Appending 50785023 to pageids
# Appending 813176 to pageids
# Appending 57638150 to pageids
# Appending 36747851 to pageids
# Appending 46583121 to pageids
# Appending 42912557 to pageids
# Appending 43591208 to pageids
# Appending 46577193 to pageids
# Appending 48718351 to pageids
# Appending 55090826 to pageids
# Appending 732167 to pageids
# Appending 46504825 to pageids
# Appending 48795986 to pageids
# Appending 40930229 to pageids
# Appending 726659 to pageids
# Appending 43427948 to pageids
# Appending 54245 to pageids
# Appending Category:Artificial intelligence in fiction / count = 58
# Checking for subcategories of Category:Artificial intelligence in fiction at depth 1
# Category:Artificial intelligence in fiction (en) data
# {
#   members: <list(180)> {'pageid': 11746227, 'ns': 0, 'title': 'Art...
#   requests: <list(1)> category
#   subcategories: <list(13)> {'pageid': 41037406, 'ns': 14, 'title'...
# }
# en.wikipedia.org (categorymembers) Category:Fictional artificial ...
# Appending 11746227 to pageids
# Appending 11750751 to pageids
# Appending 240931 to pageids
# Appending 39350301 to pageids
# Appending 1660387 to pageids
# Appending 54532744 to pageids
# Appending 2233223 to pageids
# Appending 40008467 to pageids
# Appending 49635999 to pageids
# Appending 50178216 to pageids
# Appending 636502 to pageids
# Appending 41476698 to pageids
# Appending 39171154 to pageids
# Appending 47431252 to pageids
# Appending 23903477 to pageids
# Appending 12524432 to pageids
# Appending 7491122 to pageids
# Appending 39516319 to pageids
# Appending 12690765 to pageids
# Appending 44449 to pageids
# Appending 1963048 to pageids
# Appending 990322 to pageids
# Appending 5584041 to pageids
# Appending 4742 to pageids
# Appending 184211 to pageids
# Appending 600721 to pageids
# Appending 42122348 to pageids
# Appending 55503282 to pageids
# Appending 855981 to pageids
# Appending 2989163 to pageids
# Appending 753201 to pageids
# Appending 54799795 to pageids
# Appending 6790509 to pageids
# Appending 1594929 to pageids
# Appending 4923077 to pageids
# Appending 158313 to pageids
# Appending 11283085 to pageids
# Appending 52224 to pageids
# Appending 51076359 to pageids
# Appending 26608591 to pageids
# Appending 47154962 to pageids
# Appending 759653 to pageids
# Appending 55566422 to pageids
# Appending 2313733 to pageids
# Appending 16243392 to pageids
# Appending 24175989 to pageids
# Appending 1449930 to pageids
# Appending 12481557 to pageids
# Appending 9664 to pageids
# Appending 4339740 to pageids
# Appending 3093574 to pageids
# Appending 30523683 to pageids
# Appending 9740710 to pageids
# Appending 47174426 to pageids
# Appending 34017673 to pageids
# Appending 15060954 to pageids
# Appending 101888 to pageids
# Appending 8623677 to pageids
# Appending 7643234 to pageids
# Appending 14335246 to pageids
# Appending 43456819 to pageids
# Appending 4907813 to pageids
# Appending 3786846 to pageids
# Appending 6112811 to pageids
# Appending 1739150 to pageids
# Appending 3547088 to pageids
# Appending 5443066 to pageids
# Appending 45032290 to pageids
# Appending 44194870 to pageids
# Appending 21125507 to pageids
# Appending 23444690 to pageids
# Appending 1744298 to pageids
# Appending 922920 to pageids
# Appending 45007298 to pageids
# Appending 46663255 to pageids
# Appending 593138 to pageids
# Appending 31440066 to pageids
# Appending 220116 to pageids
# Appending 1233605 to pageids
# Appending 38599961 to pageids
# Appending 51294071 to pageids
# Appending 37444669 to pageids
# Appending 14171143 to pageids
# Appending 13351690 to pageids
# Appending 35196753 to pageids
# Appending 2037128 to pageids
# Appending 295393 to pageids
# Appending 9785797 to pageids
# Appending 2364379 to pageids
# Appending 9839076 to pageids
# Appending 34067800 to pageids
# Appending 4746861 to pageids
# Appending 7214247 to pageids
# Appending 2645494 to pageids
# Appending 38077394 to pageids
# Appending 1672978 to pageids
# Appending 23048594 to pageids
# Appending 2933388 to pageids
# Appending 8663950 to pageids
# Appending 453075 to pageids
# Appending 2106669 to pageids
# Appending 40782061 to pageids
# Appending 45047 to pageids
# Appending 379018 to pageids
# Appending 595618 to pageids
# Appending 1575603 to pageids
# Appending 23060942 to pageids
# Appending 6198415 to pageids
# Appending 8135269 to pageids
# Appending 53597 to pageids
# Appending 4827986 to pageids
# Appending 21725 to pageids
# Appending 3991062 to pageids
# Appending 37984303 to pageids
# Appending 2731321 to pageids
# Appending 803898 to pageids
# Appending 3514689 to pageids
# Appending 54182440 to pageids
# Appending 48106641 to pageids
# Appending 181203 to pageids
# Appending 31770697 to pageids
# Appending 68857 to pageids
# Appending 12247642 to pageids
# Appending 5956143 to pageids
# Appending 15888290 to pageids
# Appending 367519 to pageids
# Appending 1780477 to pageids
# Appending 751104 to pageids
# Appending 37386 to pageids
# Appending 47443133 to pageids
# Appending 54197501 to pageids
# Appending 8659983 to pageids
# Appending 9454227 to pageids
# Appending 32017367 to pageids
# Appending 60134 to pageids
# Appending 1593741 to pageids
# Appending 47062438 to pageids
# Appending 47059991 to pageids
# Appending 47062439 to pageids
# Appending 47251933 to pageids
# Appending 47227529 to pageids
# Appending 47251964 to pageids
# Appending 47281679 to pageids
# Appending 47281685 to pageids
# Appending 46185063 to pageids
# Appending 32235455 to pageids
# Appending 365182 to pageids
# Appending 12230556 to pageids
# Appending 650483 to pageids
# Appending 34548693 to pageids
# Appending 277006 to pageids
# Appending 3411516 to pageids
# Appending 33879786 to pageids
# Appending 40085495 to pageids
# Appending 1025819 to pageids
# Appending 15888626 to pageids
# Appending 8551237 to pageids
# Appending 33270508 to pageids
# Appending 44618143 to pageids
# Appending 57267998 to pageids
# Appending 44611557 to pageids
# Appending 7957691 to pageids
# Appending 21548766 to pageids
# Appending 15565698 to pageids
# Appending 1696606 to pageids
# Appending 305596 to pageids
# Appending 28547427 to pageids
# Appending 627206 to pageids
# Appending 1021270 to pageids
# Appending 32423997 to pageids
# Appending 54773502 to pageids
# Appending 40229030 to pageids
# Appending 33409691 to pageids
# Appending 6842333 to pageids
# Appending 38418560 to pageids
# Appending 3758205 to pageids
# Appending 358057 to pageids
# Appending 38418573 to pageids
# Appending 32457804 to pageids
# Appending 25992553 to pageids
# Appending Category:Android (robot) fiction / count = 59
# Checking for subcategories of Category:Android (robot) fiction at depth 0
# Appending Category:Android (robot) films / count = 60
# Checking for subcategories of Category:Android (robot) films at depth 0
# Appending Category:Fictional androids / count = 61
# Checking for subcategories of Category:Fictional androids at depth 0
# Appending Category:Artificial intelligence characters in video games / count = 62
# Checking for subcategories of Category:Artificial intelligence characters in video games at depth 0
# Appending Category:Code Lyoko / count = 63
# Checking for subcategories of Category:Code Lyoko at depth 0
# Appending Category:Destination: Void universe / count = 64
# Checking for subcategories of Category:Destination: Void universe at depth 0
# Appending Category:Fictional artificial intelligences / count = 65
# Checking for subcategories of Category:Fictional artificial intelligences at depth 0
# Appending Category:Films about artificial intelligence / count = 66
# Checking for subcategories of Category:Films about artificial intelligence at depth 0
# Appending Category:Knight Rider / count = 67
# Checking for subcategories of Category:Knight Rider at depth 0
# Appending Category:The Matrix (franchise) / count = 68
# Checking for subcategories of Category:The Matrix (franchise) at depth 0
# Appending Category:Fictional robots / count = 69
# Checking for subcategories of Category:Fictional robots at depth 0
# Appending Category:Terminator (franchise) / count = 70
# Checking for subcategories of Category:Terminator (franchise) at depth 0
# Appending Category:Tom Clancy's Net Force / count = 71
# Checking for subcategories of Category:Tom Clancy's Net Force at depth 0
# Appending Category:Fictional artificial intelligences / count = 72
# Checking for subcategories of Category:Fictional artificial intelligences at depth 1
# Category:Fictional artificial intelligences (en) data
# {
#   members: <list(89)> {'pageid': 626913, 'ns': 0, 'title': 'Adam (...
#   requests: <list(1)> category
#   subcategories: <list(4)> {'pageid': 11305939, 'ns': 14, 'title':...
# }
# en.wikipedia.org (categorymembers) Category:Fuzzy logic
# Appending 626913 to pageids
# Appending 6422674 to pageids
# Appending 1216187 to pageids
# Appending 297146 to pageids
# Appending 10330695 to pageids
# Appending 805753 to pageids
# Appending 27867111 to pageids
# Appending 681260 to pageids
# Appending 32891878 to pageids
# Appending 2937935 to pageids
# Appending 623280 to pageids
# Appending 525160 to pageids
# Appending 853152 to pageids
# Appending 22233770 to pageids
# Appending 13388109 to pageids
# Appending 2123542 to pageids
# Appending 1115033 to pageids
# Appending 7708467 to pageids
# Appending 6073394 to pageids
# Appending 47676 to pageids
# Appending 54442191 to pageids
# Appending 28039836 to pageids
# Appending 27076 to pageids
# Appending 8412 to pageids
# Appending 232212 to pageids
# Appending 990490 to pageids
# Appending 693362 to pageids
# Appending 5523115 to pageids
# Appending 302789 to pageids
# Appending 50660484 to pageids
# Appending 575649 to pageids
# Appending 24102946 to pageids
# Appending 1171000 to pageids
# Appending 3177898 to pageids
# Appending 26468301 to pageids
# Appending 14384 to pageids
# Appending 1847159 to pageids
# Appending 8963881 to pageids
# Appending 645784 to pageids
# Appending 45007298 to pageids
# Appending 1145262 to pageids
# Appending 2006761 to pageids
# Appending 22765352 to pageids
# Appending 44762961 to pageids
# Appending 1941189 to pageids
# Appending 1086142 to pageids
# Appending 1829947 to pageids
# Appending 625067 to pageids
# Appending 189709 to pageids
# Appending 13312775 to pageids
# Appending 983919 to pageids
# Appending 3654272 to pageids
# Appending 838479 to pageids
# Appending 6038232 to pageids
# Appending 14543705 to pageids
# Appending 447827 to pageids
# Appending 53597 to pageids
# Appending 45641474 to pageids
# Appending 236091 to pageids
# Appending 477591 to pageids
# Appending 1086248 to pageids
# Appending 6621560 to pageids
# Appending 33786758 to pageids
# Appending 10059711 to pageids
# Appending 5545068 to pageids
# Appending 2421352 to pageids
# Appending 5524246 to pageids
# Appending 22311313 to pageids
# Appending 82295 to pageids
# Appending 1353257 to pageids
# Appending 4085384 to pageids
# Appending 29991 to pageids
# Appending 5438477 to pageids
# Appending 10054112 to pageids
# Appending 7970736 to pageids
# Appending 318466 to pageids
# Appending 8718532 to pageids
# Appending 244338 to pageids
# Appending 47176071 to pageids
# Appending 43946713 to pageids
# Appending 39458232 to pageids
# Appending 786916 to pageids
# Appending 3120057 to pageids
# Appending 1340384 to pageids
# Appending 709267 to pageids
# Appending 972072 to pageids
# Appending 1548724 to pageids
# Appending 752484 to pageids
# Appending 32457804 to pageids
# Appending Category:Dungeons & Dragons constructs / count = 73
# Checking for subcategories of Category:Dungeons & Dragons constructs at depth 0
# Appending Category:Fictional androids / count = 74
# Checking for subcategories of Category:Fictional androids at depth 0
# Appending Category:Fictional gynoids / count = 75
# Checking for subcategories of Category:Fictional gynoids at depth 0
# Appending Category:Artificial intelligence characters in video games / count = 76
# Checking for subcategories of Category:Artificial intelligence characters in video games at depth 0
# Appending Category:Fuzzy logic / count = 77
# Checking for subcategories of Category:Fuzzy logic at depth 1
# Category:Fuzzy logic (en) data
# {
#   members: <list(56)> {'pageid': 1028978, 'ns': 0, 'title': 'Combs...
#   requests: <list(1)> category
#   subcategories: <list(1)> {'pageid': 15522913, 'ns': 14, 'title':...
# }
# en.wikipedia.org (categorymembers) Category:Game artificial intel...
# Appending 1028978 to pageids
# Appending 1973470 to pageids
# Appending 49180 to pageids
# Appending 46948278 to pageids
# Appending 31663887 to pageids
# Appending 30692142 to pageids
# Appending 16991824 to pageids
# Appending 9823717 to pageids
# Appending 1035745 to pageids
# Appending 537311 to pageids
# Appending 28232105 to pageids
# Appending 33876751 to pageids
# Appending 1028755 to pageids
# Appending 28492170 to pageids
# Appending 11270885 to pageids
# Appending 971690 to pageids
# Appending 48660 to pageids
# Appending 1958097 to pageids
# Appending 22506808 to pageids
# Appending 35890194 to pageids
# Appending 14075975 to pageids
# Appending 1626494 to pageids
# Appending 22506723 to pageids
# Appending 21787029 to pageids
# Appending 8373333 to pageids
# Appending 16415639 to pageids
# Appending 56601 to pageids
# Appending 1651811 to pageids
# Appending 20814025 to pageids
# Appending 8018271 to pageids
# Appending 15639656 to pageids
# Appending 33922707 to pageids
# Appending 54036086 to pageids
# Appending 13649912 to pageids
# Appending 11001950 to pageids
# Appending 1808639 to pageids
# Appending 10464507 to pageids
# Appending 31730014 to pageids
# Appending 2483815 to pageids
# Appending 14893994 to pageids
# Appending 25733398 to pageids
# Appending 1504425 to pageids
# Appending 285109 to pageids
# Appending 18943927 to pageids
# Appending 12435391 to pageids
# Appending 2483542 to pageids
# Appending 3291080 to pageids
# Appending 36544526 to pageids
# Appending 2099179 to pageids
# Appending 13727501 to pageids
# Appending 33591382 to pageids
# Appending 21171254 to pageids
# Appending 25962276 to pageids
# Appending 25075497 to pageids
# Appending 38008439 to pageids
# Appending 32369 to pageids
# Appending Category:Predicate logic / count = 78
# Checking for subcategories of Category:Predicate logic at depth 0
# Appending Category:Game artificial intelligence / count = 79
# Checking for subcategories of Category:Game artificial intelligence at depth 1
# Category:Game artificial intelligence (en) data
# {
#   members: <list(48)> {'pageid': 1654769, 'ns': 0, 'title': 'Artif...
#   requests: <list(1)> category
#   subcategories: <list(10)> {'pageid': 47893983, 'ns': 14, 'title'...
# }
# en.wikipedia.org (categorymembers) Category:History of artificial...
# Appending 1654769 to pageids
# Appending 100558 to pageids
# Appending 159501 to pageids
# Appending 452582 to pageids
# Appending 14993828 to pageids
# Appending 284528 to pageids
# Appending 7249174 to pageids
# Appending 8539064 to pageids
# Appending 207188 to pageids
# Appending 39278567 to pageids
# Appending 6172005 to pageids
# Appending 68367 to pageids
# Appending 227021 to pageids
# Appending 64187 to pageids
# Appending 501462 to pageids
# Appending 19496019 to pageids
# Appending 41755648 to pageids
# Appending 159513 to pageids
# Appending 1153192 to pageids
# Appending 27164904 to pageids
# Appending 28134188 to pageids
# Appending 6476399 to pageids
# Appending 7408685 to pageids
# Appending 46519807 to pageids
# Appending 253556 to pageids
# Appending 2256654 to pageids
# Appending 904345 to pageids
# Appending 42146944 to pageids
# Appending 173889 to pageids
# Appending 23762260 to pageids
# Appending 1074656 to pageids
# Appending 25681069 to pageids
# Appending 19589 to pageids
# Appending 54451950 to pageids
# Appending 1732703 to pageids
# Appending 2426057 to pageids
# Appending 3509077 to pageids
# Appending 2292305 to pageids
# Appending 396118 to pageids
# Appending 23073520 to pageids
# Appending 7724220 to pageids
# Appending 287939 to pageids
# Appending 10809677 to pageids
# Appending 25191227 to pageids
# Appending 242748 to pageids
# Appending 14819817 to pageids
# Appending 233463 to pageids
# Appending 1963880 to pageids
# Appending Category:Behavior modelling / count = 80
# Checking for subcategories of Category:Behavior modelling at depth 0
# Appending Category:Card game video games / count = 81
# Checking for subcategories of Category:Card game video games at depth 0
# Appending Category:Computer chess / count = 82
# Checking for subcategories of Category:Computer chess at depth 0
# Appending Category:Computer Go / count = 83
# Checking for subcategories of Category:Computer Go at depth 0
# Appending Category:Computer olympiads / count = 84
# Checking for subcategories of Category:Computer olympiads at depth 0
# Appending Category:Computer poker players / count = 85
# Checking for subcategories of Category:Computer poker players at depth 0
# ...
# Checking for subcategories of Category:Robot architectures at depth 0
# Appending Category:Articulated robotics / count = 210
# Checking for subcategories of Category:Articulated robotics at depth 0
# Appending Category:BEAM robotics / count = 211
# Checking for subcategories of Category:BEAM robotics at depth 0
# Appending Category:Biorobotics / count = 212
# Checking for subcategories of Category:Biorobotics at depth 0
# Appending Category:Cloud robotics / count = 213
# Checking for subcategories of Category:Cloud robotics at depth 0
# Appending Category:Robotic concepts / count = 214
# Checking for subcategories of Category:Robotic concepts at depth 0
# Appending Category:Robot control / count = 215
# Checking for subcategories of Category:Robot control at depth 0
# Appending Category:Cyborgs / count = 216
# Checking for subcategories of Category:Cyborgs at depth 0
# Appending Category:Entertainment robotics / count = 217
# Checking for subcategories of Category:Entertainment robotics at depth 0
# Appending Category:Robotics events / count = 218
# Checking for subcategories of Category:Robotics events at depth 0
# Appending Category:Robotics hardware / count = 219
# Checking for subcategories of Category:Robotics hardware at depth 0
# Appending Category:Healthcare robotics / count = 220
# Checking for subcategories of Category:Healthcare robotics at depth 0
# Appending Category:Home automation / count = 221
# Checking for subcategories of Category:Home automation at depth 0
# Appending Category:Industrial robotics / count = 222
# Checking for subcategories of Category:Industrial robotics at depth 0
# Appending Category:Laws of robotics / count = 223
# Checking for subcategories of Category:Laws of robotics at depth 0
# Appending Category:Robotics lists / count = 224
# Checking for subcategories of Category:Robotics lists at depth 0
# Appending Category:Machine vision / count = 225
# Checking for subcategories of Category:Machine vision at depth 0
# Appending Category:Robotic manipulation / count = 226
# Checking for subcategories of Category:Robotic manipulation at depth 0
# Appending Category:Medical robotics / count = 227
# Checking for subcategories of Category:Medical robotics at depth 0
# Appending Category:Military robotics / count = 228
# Checking for subcategories of Category:Military robotics at depth 0
# Appending Category:Multi-robot systems / count = 229
# Checking for subcategories of Category:Multi-robot systems at depth 0
# Appending Category:Robotics organizations / count = 230
# Checking for subcategories of Category:Robotics organizations at depth 0
# Appending Category:Physical computing / count = 231
# Checking for subcategories of Category:Physical computing at depth 0
# Appending Category:Robotics projects / count = 232
# Checking for subcategories of Category:Robotics projects at depth 0
# Appending Category:Robotic art / count = 233
# Checking for subcategories of Category:Robotic art at depth 0
# Appending Category:Roboticists / count = 234
# Checking for subcategories of Category:Roboticists at depth 0
# Appending Category:Robotics software / count = 235
# Checking for subcategories of Category:Robotics software at depth 0
# Appending Category:Works about robotics / count = 236
# Checking for subcategories of Category:Works about robotics at depth 0
# Appending Category:Robotics stubs / count = 237
# Checking for subcategories of Category:Robotics stubs at depth 0
# Appending Category:Robots / count = 238
# Checking for subcategories of Category:Robots at depth 1
# Category:Robots (en) data
# {
#   members: <list(35)> {'pageid': 25781, 'ns': 0, 'title': 'Robot'}...
#   requests: <list(1)> category
#   subcategories: <list(38)> {'pageid': 41247177, 'ns': 14, 'title'...
# }
# en.wikipedia.org (categorymembers) Category:Rule engines
# Appending 25781 to pageids
# Appending 11005995 to pageids
# Appending 2938409 to pageids
# Appending 48049 to pageids
# Appending 11559431 to pageids
# Appending 2999200 to pageids
# Appending 6724915 to pageids
# Appending 3808074 to pageids
# Appending 2245058 to pageids
# Appending 3926040 to pageids
# Appending 7501487 to pageids
# Appending 14716135 to pageids
# Appending 57638150 to pageids
# Appending 713 to pageids
# Appending 37663509 to pageids
# Appending 56349200 to pageids
# Appending 46434772 to pageids
# Appending 43046621 to pageids
# Appending 48050589 to pageids
# Appending 47133704 to pageids
# Appending 57790317 to pageids
# Appending 5115708 to pageids
# Appending 43616041 to pageids
# Appending 44195492 to pageids
# Appending 48560508 to pageids
# Appending 22259308 to pageids
# Appending 50571328 to pageids
# Appending 42943542 to pageids
# Appending 56428662 to pageids
# Appending 7068605 to pageids
# Appending 55790714 to pageids
# Appending 57375524 to pageids
# Appending 39338990 to pageids
# Appending 47502544 to pageids
# Appending 39129580 to pageids
# Appending Category:Robots in fiction / count = 239
# Checking for subcategories of Category:Robots in fiction at depth 0
# Appending Category:Robots by country / count = 240
# Checking for subcategories of Category:Robots by country at depth 0
# Appending Category:Robots by date / count = 241
# Checking for subcategories of Category:Robots by date at depth 0
# Appending Category:Robots by environment / count = 242
# Checking for subcategories of Category:Robots by environment at depth 0
# Appending Category:Robots by fuel / count = 243
# Checking for subcategories of Category:Robots by fuel at depth 0
# Appending Category:Fictional robots / count = 244
# Checking for subcategories of Category:Fictional robots at depth 0
# Appending Category:Android (robot) / count = 245
# Checking for subcategories of Category:Android (robot) at depth 0
# Appending Category:Automata (mechanical) / count = 246
# Checking for subcategories of Category:Automata (mechanical) at depth 0
# Appending Category:Autonomous cars / count = 247
# Checking for subcategories of Category:Autonomous cars at depth 0
# Appending Category:Autonomous ships / count = 248
# Checking for subcategories of Category:Autonomous ships at depth 0
# Appending Category:Ecological robots / count = 249
# Checking for subcategories of Category:Ecological robots at depth 0
# Appending Category:Educational robots / count = 250
# Checking for subcategories of Category:Educational robots at depth 0
# Appending Category:Entertainment robots / count = 251
# Checking for subcategories of Category:Entertainment robots at depth 0
# Appending Category:Handling robots / count = 252
# Checking for subcategories of Category:Handling robots at depth 0
# Appending Category:Healthcare robotics / count = 253
# Checking for subcategories of Category:Healthcare robotics at depth 0
# Appending Category:Historical robots / count = 254
# Checking for subcategories of Category:Historical robots at depth 0
# Appending Category:Hobbyist robots / count = 255
# Checking for subcategories of Category:Hobbyist robots at depth 0
# Appending Category:Individual robots / count = 256
# Checking for subcategories of Category:Individual robots at depth 0
# Appending Category:Industrial robots / count = 257
# Checking for subcategories of Category:Industrial robots at depth 0
# Appending Category:Medical robots / count = 258
# Checking for subcategories of Category:Medical robots at depth 0
# Appending Category:Micro robots / count = 259
# Checking for subcategories of Category:Micro robots at depth 0
# Appending Category:Military robots / count = 260
# Checking for subcategories of Category:Military robots at depth 0
# Appending Category:Online robots / count = 261
# Checking for subcategories of Category:Online robots at depth 0
# Appending Category:Open-source robots / count = 262
# Checking for subcategories of Category:Open-source robots at depth 0
# Appending Category:Robot parts / count = 263
# Checking for subcategories of Category:Robot parts at depth 0
# Appending Category:Personal assistant robots / count = 264
# Checking for subcategories of Category:Personal assistant robots at depth 0
# Appending Category:Prototype robots / count = 265
# Checking for subcategories of Category:Prototype robots at depth 0
# Appending Category:Rescue and protection robots / count = 266
# Checking for subcategories of Category:Rescue and protection robots at depth 0
# Appending Category:Robotic exoskeletons / count = 267
# Checking for subcategories of Category:Robotic exoskeletons at depth 0
# Appending Category:Service robots / count = 268
# Checking for subcategories of Category:Service robots at depth 0
# Appending Category:Sex robots / count = 269
# Checking for subcategories of Category:Sex robots at depth 0
# Appending Category:Social robots / count = 270
# Checking for subcategories of Category:Social robots at depth 0
# Appending Category:Robot sports / count = 271
# Checking for subcategories of Category:Robot sports at depth 0
# Appending Category:Sports robots / count = 272
# Checking for subcategories of Category:Sports robots at depth 0
# Appending Category:Telepresence robots / count = 273
# Checking for subcategories of Category:Telepresence robots at depth 0
# Appending Category:Robotic telescopes / count = 274
# Checking for subcategories of Category:Robotic telescopes at depth 0
# Appending Category:Unmanned vehicles / count = 275
# Checking for subcategories of Category:Unmanned vehicles at depth 0
# Appending Category:Works about robots / count = 276
# Checking for subcategories of Category:Works about robots at depth 0
# Appending Category:Rule engines / count = 277
# Checking for subcategories of Category:Rule engines at depth 1
# Category:Rule engines (en) data
# {
#   members: <list(21)> {'pageid': 13536810, 'ns': 0, 'title': 'Sema...
#   requests: <list(1)> category
#   subcategories: <list(1)> {'pageid': 5679660, 'ns': 14, 'title': ...
# }
# en.wikipedia.org (categorymembers) Category:Turing tests
# Appending 13536810 to pageids
# Appending 2271744 to pageids
# Appending 1867853 to pageids
# Appending 2052570 to pageids
# Appending 15900338 to pageids
# Appending 5421193 to pageids
# Appending 25260147 to pageids
# Appending 35281629 to pageids
# Appending 44425089 to pageids
# Appending 10706365 to pageids
# Appending 9519016 to pageids
# Appending 41442396 to pageids
# Appending 37091 to pageids
# Appending 2645943 to pageids
# Appending 29749471 to pageids
# Appending 14996462 to pageids
# Appending 5006904 to pageids
# Appending 31103500 to pageids
# Appending 19768799 to pageids
# Appending 1568414 to pageids
# Appending 1254288 to pageids
# Appending Category:Expert systems / count = 278
# Checking for subcategories of Category:Expert systems at depth 0
# Appending Category:Turing tests / count = 279
# Checking for subcategories of Category:Turing tests at depth 1
# Category:Turing tests (en) data
# {
#   members: <list(11)> {'pageid': 21391751, 'ns': 0, 'title': 'Turi...
#   requests: <list(1)> category
#   subcategories: <list(1)> {'pageid': 8735377, 'ns': 14, 'title': ...
# }
# en.wikipedia.org (categorymembers) Category:Virtual assistants
# Appending 21391751 to pageids
# Appending 230834 to pageids
# Appending 19451459 to pageids
# Appending 16795043 to pageids
# Appending 3897595 to pageids
# Appending 28037152 to pageids
# Appending 11451897 to pageids
# Appending 723435 to pageids
# Appending 3682165 to pageids
# Appending 48589354 to pageids
# Appending 44391058 to pageids
# Appending Category:Chatterbots / count = 280
# Checking for subcategories of Category:Chatterbots at depth 0
# Appending Category:Virtual assistants / count = 281
# Checking for subcategories of Category:Virtual assistants at depth 1
# Category:Virtual assistants (en) data
# {
#   members: <list(27)> {'pageid': 19024298, 'ns': 0, 'title': 'Virt...
#   requests: <list(1)> category
# }
# en.wikipedia.org (categorymembers) Category:Artificial intelligen...
# Appending 19024298 to pageids
# Appending 55531461 to pageids
# Appending 56366274 to pageids
# Appending 51060375 to pageids
# Appending 43144075 to pageids
# Appending 53639024 to pageids
# Appending 13494976 to pageids
# Appending 39791384 to pageids
# Appending 56327946 to pageids
# Appending 42119832 to pageids
# Appending 50575063 to pageids
# Appending 36279735 to pageids
# Appending 55726033 to pageids
# Appending 44969076 to pageids
# Appending 52396698 to pageids
# Appending 42370155 to pageids
# Appending 53802682 to pageids
# Appending 43236335 to pageids
# Appending 50231947 to pageids
# Appending 35713574 to pageids
# Appending 38350839 to pageids
# Appending 26086272 to pageids
# Appending 17540116 to pageids
# Appending 50491264 to pageids
# Appending 40615979 to pageids
# Appending 21903944 to pageids
# Appending 56885536 to pageids
# Appending Category:Artificial intelligence stubs / count = 282
# Checking for subcategories of Category:Artificial intelligence stubs at depth 1
# Appending 31663887 to pageids
# Appending 4510677 to pageids
# Appending 24109330 to pageids
# Appending 56366274 to pageids
# Appending 57094780 to pageids
# Appending 33900354 to pageids
# Appending 52411579 to pageids
# Appending 13911207 to pageids
# Appending 55843837 to pageids
# Appending 46465898 to pageids
# Appending 57222123 to pageids
# Appending 47893974 to pageids
# Appending 2995827 to pageids
# Appending 45001424 to pageids
# Appending 305850 to pageids
# Appending 9081999 to pageids
# Appending 527621 to pageids
# Appending 8908590 to pageids
# Appending 1532719 to pageids
# Appending 3326075 to pageids
# Appending 38629606 to pageids
# Appending 33512934 to pageids
# Appending 36298401 to pageids
# Appending 2714979 to pageids
# Appending 19317802 to pageids
# Appending 56785877 to pageids
# Appending 2634860 to pageids
# Appending 1234327 to pageids
# Appending 47349395 to pageids
# Appending 10747995 to pageids
# Appending 33096342 to pageids
# Appending 8887731 to pageids
# Appending 27141248 to pageids
# Appending 3358541 to pageids
# Appending 7101688 to pageids
# Appending 3070571 to pageids
# Appending 5581645 to pageids
# Appending 2229040 to pageids
# Appending 2897576 to pageids
# Appending 2710755 to pageids
# Appending 16415639 to pageids
# Appending 162046 to pageids
# Appending 49305019 to pageids
# Appending 1222568 to pageids
# Appending 55375136 to pageids
# Appending 55725219 to pageids
# Appending 33762888 to pageids
# Appending 2174928 to pageids
# Appending 22589574 to pageids
# Appending 2736877 to pageids
# Appending 7437547 to pageids
# Appending 18586449 to pageids
# Appending 23958572 to pageids
# Appending 4855682 to pageids
# Appending 18313661 to pageids
# Appending 7539196 to pageids
# Appending 57754824 to pageids
# Appending 15299080 to pageids
# Appending 1899829 to pageids
# Appending 17627465 to pageids
# Appending 2645943 to pageids
# Appending 1053030 to pageids
# Appending 49830146 to pageids
# Appending 5260477 to pageids
# Appending 2708995 to pageids
# Appending 43517179 to pageids
# Appending 47623626 to pageids
# Appending 26266844 to pageids
# Appending 6092601 to pageids
# Appending 3691953 to pageids
# Appending 8892368 to pageids
# Appending 7092991 to pageids
# Appending 20420396 to pageids
# Appending 26313930 to pageids
# Appending 9756006 to pageids
# Appending 2311118 to pageids
# Appending 1514696 to pageids
# Appending 27395879 to pageids
# Appending 24251211 to pageids
# Appending 13186557 to pageids
# Appending 6219184 to pageids
# Appending 1346015 to pageids
# Appending 11360852 to pageids
# Appending 9605764 to pageids
# Appending 20352269 to pageids
# Appending 41929726 to pageids
# Appending 19614447 to pageids
# Appending 43705185 to pageids
# Appending 14772851 to pageids
# Appending 26400591 to pageids
# Appending 35713574 to pageids
# Appending 34882875 to pageids
# Appending 933471 to pageids
# Appending 9855223 to pageids
# Appending 4941061 to pageids
# Appending 546075 to pageids
# Appending 385879 to pageids
# Appending 2722089 to pageids
# Appending 37652061 to pageids
# Appending 2070605 to pageids
# Appending 26269089 to pageids
# Appending 247601 to pageids
# Appending 339417 to pageids
# Appending 3326018 to pageids
# Appending 33512861 to pageids
# Appending 312212 to pageids
# Appending 371724 to pageids
# Appending 1869181 to pageids
# Appending 866256 to pageids
# Appending 47893766 to pageids
# Appending 42349326 to pageids
# Appending 36472550 to pageids
# Appending 509166 to pageids
# Appending 2885828 to pageids
# Appending 3326019 to pageids
# Appending 49541331 to pageids
# Category:Artificial intelligence stubs (en) data
# {
#   members: <list(116)> {'pageid': 31663887, 'ns': 0, 'title': 'Ada...
#   requests: <list(1)> category
# }

# %%
len(crawler.categories)
# Out:
# 282

# %%
len(crawler.pageids)
# Out:
# 2714

# %%
page = wptools.page(pageid=1648132).get_parse()
# Out:
# en.wikipedia.org (parse) 1648132
# Weak AI (en) data
# {
#   pageid: 1648132
#   parsetree: <str(3573)> <root><template><title>Use dmy dates</tit...
#   requests: <list(1)> parse
#   title: Weak AI
#   wikibase: Q17097955
#   wikidata_url: https://www.wikidata.org/wiki/Q17097955
#   wikitext: <str(2870)> {{Use dmy dates|date=January 2015}}'''Weak...
# }

# %%
page.get_parse()
# Out:
# + parse results in cache

# %%
text = page.data['wikitext']

# %%
page.get_query().data['url']
# Out:
# en.wikipedia.org (query) Weak AI
# Weak AI (en) data
# {
#   WARNINGS: <dict(1)> extracts
#   assessments: <dict(5)> Linguistics, Systems, Computing, Technolo...
#   extext: <str(1261)> **Weak artificial intelligence** ( **weak AI...
#   extract: <str(1305)> <p><b>Weak artificial intelligence</b> (<b>...
#   label: Weak AI
#   length: 2,893
#   links: <list(13)> Artificial general intelligence, Artificial in...
#   modified: <dict(1)> page
#   pageid: 1648132
#   parsetree: <str(3573)> <root><template><title>Use dmy dates</tit...
#   random: Arturo Mas
#   redirects: <list(4)> {'pageid': 7869823, 'ns': 0, 'title': 'Weak...
#   requests: <list(2)> parse, query
#   title: Weak AI
#   url: https://en.wikipedia.org/wiki/Weak_AI
#   url_raw: https://en.wikipedia.org/wiki/Weak_AI?action=raw
#   watchers: 33
#   wikibase: Q17097955
#   wikidata_url: https://www.wikidata.org/wiki/Q17097955
#   wikitext: <str(2870)> {{Use dmy dates|date=January 2015}}'''Weak...
# }
# 'https://en.wikipedia.org/wiki/Weak_AI'

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(text, 'html.parser')

# %%
txt2 = soup.get_text()

# %%
import re
re.sub(r"\s*{.*}\s*|\s*\[.*\]\s*", " ", txt2)
# Out:
# ' \'\'\'Weak artificial intelligence\'\'\' (\'\'\'weak AI\'\'\'), also known as \'\'\'narrow AI\'\'\',io9.com mentions narrow AI. Published 1 April 2013, retrieved 16 February 2014: http://io9.com/how-much-longer-before-our-first-ai-catastrophe-464043243AI researcher Ben Goertzel explains why he became interested in AGI instead of narrow AI. Published 18 Oct 2013. Retrieved 16 February 2014. http://intelligence.org/2013/10/18/ben-goertzel/TechCrunch discusses AI App building regarding Narrow AI. Published 16 Oct 2015, retrieved 17 Oct 2015. https://techcrunch.com/2015/10/15/machine-learning-its-the-hard-problems-that-are-valuable/ is (a machine with the ability to apply intelligence to any problem, rather than just one specific problem). All currently existing systems considered artificial intelligence of any sort are weak AI at most. , on his blog in 2010, stated Siri was "VERY narrow and brittle" evidenced by annoying results if you ask questions outside the limits of the application.Ben Goertzel blog-post retrieved 16 February 2014. Published 6 February 2010. http://multiverseaccordingtoben.blogspot.com/2010/02/siri-new-iphone-personal-assistant-some.html\n\nSome commentators think weak AI could be dangerous. Weak AI could cause disruptions in the electric grid, damage nuclear power plants, cause global economic problems, and misdirect autonomous vehicles. Retrieved 16 February 2014. http://io9.com/how-much-longer-before-our-first-ai-catastrophe-464043243 In 2010, weak AI trading algorithms led to a “flash crash,” causing a temporary but significant dip in the market.Retrieved 16 February 2014. http://cyberlaw.stanford.edu/blog/2011/08/sorcerers-apprentice-or-why-weak-ai-interesting-enough\n\n==See also==\n* * * * * * ==References==   '
